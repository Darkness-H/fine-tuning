# %% [markdown]
# ## Quality Processes for Images

# %%
# Importing useful dependencies
import io
import os
import boto3
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 1919, in _run_once
#     handle._run()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\zmqshell.py", line 577, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\SakuraSnow\AppData\Local\Temp\ipykernel_25420\3604144064.py", line 6, in <module>
#     import pandas as pd
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py", line 61, in <module>
#     from pandas.core.api import (
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\arrow\array.py", line 52, in <module>
#     from pandas.core import (
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\SakuraSnow\AppData\Local\Programs\Python\Python311\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %% [markdown]
# Before preparing/cleaning the data for exploitation zone, we have to perform a quality analysis of the images stored in the Trusted Zone (Copied from the Formatted Zone). For that purpose, firstly we are going to extract data from each of our images.

# %%
# Given a bucket and a prefix, the function returns a list of data of each image in the target path
def get_data_images(bucket, prefix=""):

    data = []
    etags=set()
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):
            duplicate = False
            key = obj["Key"]

            size = obj["Size"]
            etag = obj["ETag"].strip('"')
            if size == 0 and key.endswith("/"):
                continue

            # duplication check
            sig = (etag, size)
            if sig in etags:
                duplicate = True
            else:
                etags.add(sig)

            # Download the image
            resp = s3.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()
        
            with Image.open(io.BytesIO(body)) as img:
                width, height = img.size
                mode = img.mode
                n_channels = len(mode) if mode in ["RGB","RGBA","L","CMYK"] else None
        
            data.append({
                "file_name": key,
                "file_size": obj['Size'] / 1024, # B -> KB
                "width": width,
                "height": height,
                "aspect_ratio": round(width/height, 2) if height > 0 else None, # proportional relationship between image width and height
                "mode": mode, # how pixel values are stored
                "channels": n_channels, # number of color channels in the image
                "duplicated": duplicate
            })

    return data

# %%
# Get data from the bucket
data = get_data_images(bucket = "trusted-zone", prefix = "images")

# %%
# Convert the data into a dataFrame
df_data = pd.DataFrame(data)
display(df_data.head(5))
# Out:
#                         file_name   file_size  width  height  aspect_ratio  \
# 0  images/image_1762966866790.png  209.694336    460     215          2.14
# 1  images/image_1762966866959.png  165.176758    460     215          2.14
# 2  images/image_1762966867034.png  184.975586    460     215          2.14
# 3  images/image_1762966867095.png   19.867188    460     215          2.14
# 4  images/image_1762966867157.png   84.223633    460     215          2.14
#
#   mode  channels  duplicated
# 0  RGB         3       False
# 1  RGB         3       False
# 2  RGB         3       False
# 3  RGB         3       False
# 4  RGB         3       False

# %%
# Have a quick summary of the data
df_data.describe(include="all")
# Out:
#                              file_name     file_size        width  \
# count                              500    500.000000   500.000000
# unique                             500           NaN          NaN
# top     images/image_1762966926490.png           NaN          NaN
# freq                                 1           NaN          NaN
# mean                               NaN   1835.112623  1310.470000
# std                                NaN   4924.188930  1114.936292
# min                                NaN     10.204102   460.000000
# 25%                                NaN    150.345215   460.000000
# 50%                                NaN    221.721191   528.500000
# 75%                                NaN   2149.757812  1920.000000
# max                                NaN  90275.804688  9990.000000
#
#              height  aspect_ratio mode    channels duplicated
# count    500.000000    500.000000  500  500.000000        500
# unique          NaN           NaN    2         NaN          1
# top             NaN           NaN  RGB         NaN      False
# freq            NaN           NaN  499         NaN        500
# mean     739.942000      1.943220  NaN    2.996000        NaN
# std      715.251096      0.257014  NaN    0.089443        NaN
# min      215.000000      0.890000  NaN    1.000000        NaN
# 25%      215.000000      1.780000  NaN    3.000000        NaN
# 50%      257.500000      2.140000  NaN    3.000000        NaN
# 75%     1080.000000      2.140000  NaN    3.000000        NaN
# max     7940.000000      3.100000  NaN    3.000000        NaN

# %%
# Unique values for mode
pd.unique(df_data['mode'])
# Out:
# array(['RGB', 'L'], dtype=object)

# %% [markdown]
# Looking at the table shown above, the images we have are around 2MB (mean/1024) in size. In fact, the first 75% of the data are around that size. However, then we have that the maximum file size is around 100MB. On the other hand, we have different distributions in both width and height columns, which suggests the images are not square and this implies varied aspect ratio for the images. When it comes to the mode, the most of our images are RGB (3 channels) and the remaining ones are L (8-bit grayscale image).
#
# Next, we show some plots to better illustrate the characteristics of our images.

# %% [markdown]
# **Distribution of File Sizes**

# %%
sns.histplot(df_data["file_size"], bins=50)
plt.xlabel("File size (KB)")
plt.ylabel("Count")
plt.title("Distribution of file sizes")
plt.show()

# %% [markdown]
# Most images are small, around 1MB (1024KB). But there are some outliers like the ones that are around 40000KB and 100000KB.

# %% [markdown]
# **Width vs Height of Images**

# %%
sns.scatterplot(x="width", y="height", data=df_data, alpha=0.5)
plt.xlabel("Width (px)")
plt.ylabel("Height (px)")
plt.title("Width vs Height of Images")
plt.show()

# %% [markdown]
# Like we mentioned before, there are some outliers, big images that exceed the rest of the images, in our dataset.

# %% [markdown]
# **Aspect Ratio Distribution**

# %%
sns.histplot(df_data["aspect_ratio"].dropna(), bins=50)
plt.xlabel("Aspect Ratio (W/H)")
plt.title("Aspect Ratio Distribution")
plt.show()

# %% [markdown]
# Here, we provide another perspective to analyze the size of the images. The aspect ratio is computed by dividing the width by the height of an image. This metric does not directly measure the file size, but rather the shape and proportions of the image.
#
# Most of the images have an aspect ratio around 2, which suggests that they are approximately twice as wide as they are tall. In other words, the dataset is dominated by horizontally oriented (landscape) images.

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# As observed in the previous quality analysis, most of our images are already in RGB format (3 channels). Although it is possible to convert them into RGBA (4 channels), doing so would introduce unnecessary complexity without providing any real benefit for our use case. Since these images will later be converted into embeddings, it is more practical to keep them in RGB (3 channels). This approach ensures consistency across the dataset, avoids the overhead of an unused alpha channel, and aligns with the input requirements of most machine learning models.
#
# On the other hand, we want to normalize the images to a fixed resolution, for example 512×512. This ensures uniformity across the dataset, making the embeddings more consistent and comparable, and also optimizes processing efficiency when generating vectors. While we considered removing outliers from the dataset, we preferred to retain all images to preserve the full diversity of the collection. Instead, we decided to handle variations through preprocessing adjustments. After resizing, we can also normalize the pixel values by converting them to a standard range, which helps stabilize the model’s input, improves convergence, and ensures that differences in lighting or color intensity do not disproportionately affect the embeddings.

# %%
def preprocess_image(client ,bucket, prefix="", target_size=(512, 512)):
    """

    client          : obj                   - S3-compatible client (e.g., boto3.client("s3")).
    bucket          : str                   - Target S3/MinIO bucket.
    prefix          : str                   - Optional key prefix (acts like a folder path).
    target_size     :
    """
    """
    data = get_data_images(bucket, prefix=prefix)
    df = pd.DataFrame(data) if not isinstance(data, pd.DataFrame) else data.copy()
    if df.empty:
        raise ValueError("No image data to report.")
    """
    df = df_data
    for row in df.itertuples(index=False):


        # remove empty or duplicated image
        if row.duplicated:
            client.delete_object(Bucket=bucket, Key=row.key)
            continue

        # get image name
        key = row.file_name

        try:
            # Get object metadata to check size
            head = client.head_object(Bucket=bucket, Key=key)
            if head['ContentLength'] == 0:
                # Delete the null image (size = 0)
                client.delete_object(Bucket=bucket, Key=key)
                continue
        except Exception as e:
            print(e)
            continue

        try:
            # Download the image
            resp = client.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()

            # Load image with Pillow
            img = Image.open(io.BytesIO(body))

            # Convert images into RGB
            if img.mode != 'RGB':
                img = img.convert('RGB')  # 3 channels

            # Resize image
            img = img.resize(target_size, Image.LANCZOS)  # Image.LANCZOS = image smoother

            # Convert to numpy array and normalize pixel values to [0, 1]
            img_array = np.array(img).astype(np.float32) / 255.0
            # Convert back to PIL Image
            img_out = Image.fromarray((img_array * 255).astype(np.uint8))
            buf = io.BytesIO()
            img_out.save(buf, format="PNG")
            buf.seek(0)

            # Upload the image back
            client.upload_fileobj(buf, Bucket=bucket, Key=key, ExtraArgs={"ContentType": "image/png"}) # the old file is overwritten with the new one

            print(f"Normalized: {key}")
        except Exception as e:
            print(e)

# %%
# Standardizing images
preprocess_image(s3, bucket = "trusted-zone", prefix = "images/", target_size = (512,512))
# Out:
# Normalized: images/image_1762966866790.png
# Normalized: images/image_1762966866959.png
# Normalized: images/image_1762966867034.png
# Normalized: images/image_1762966867095.png
# Normalized: images/image_1762966867157.png
# Normalized: images/image_1762966867220.png
# Normalized: images/image_1762966867282.png
# Normalized: images/image_1762966867347.png
# Normalized: images/image_1762966867413.png
# Normalized: images/image_1762966867474.png
# Normalized: images/image_1762966867538.png
# Normalized: images/image_1762966867599.png
# Normalized: images/image_1762966867672.png
# Normalized: images/image_1762966867728.png
# Normalized: images/image_1762966867779.png
# Normalized: images/image_1762966867833.png
# Normalized: images/image_1762966867893.png
# Normalized: images/image_1762966868030.png
# Normalized: images/image_1762966868114.png
# Normalized: images/image_1762966868195.png
# Normalized: images/image_1762966868265.png
# Normalized: images/image_1762966868344.png
# Normalized: images/image_1762966868398.png
# Normalized: images/image_1762966868454.png
# Normalized: images/image_1762966868517.png
# Normalized: images/image_1762966868574.png
# Normalized: images/image_1762966868633.png
# Normalized: images/image_1762966868704.png
# Normalized: images/image_1762966868782.png
# Normalized: images/image_1762966868851.png
# Normalized: images/image_1762966868950.png
# Normalized: images/image_1762966869052.png
# Normalized: images/image_1762966869158.png
# Normalized: images/image_1762966869260.png
# Normalized: images/image_1762966869391.png
# Normalized: images/image_1762966869512.png
# Normalized: images/image_1762966869650.png
# Normalized: images/image_1762966869796.png
# Normalized: images/image_1762966869943.png
# Normalized: images/image_1762966870057.png
# Normalized: images/image_1762966870170.png
# Normalized: images/image_1762966870265.png
# Normalized: images/image_1762966870364.png
# Normalized: images/image_1762966870481.png
# Normalized: images/image_1762966870577.png
# Normalized: images/image_1762966870672.png
# Normalized: images/image_1762966870773.png
# Normalized: images/image_1762966870912.png
# Normalized: images/image_1762966871028.png
# Normalized: images/image_1762966871144.png
# Normalized: images/image_1762966871239.png
# Normalized: images/image_1762966871332.png
# Normalized: images/image_1762966871424.png
# Normalized: images/image_1762966871532.png
# Normalized: images/image_1762966871626.png
# Normalized: images/image_1762966871738.png
# Normalized: images/image_1762966871830.png
# Normalized: images/image_1762966871933.png
# Normalized: images/image_1762966872069.png
# Normalized: images/image_1762966872203.png
# Normalized: images/image_1762966872302.png
# Normalized: images/image_1762966872387.png
# Normalized: images/image_1762966872467.png
# Normalized: images/image_1762966872553.png
# Normalized: images/image_1762966872642.png
# Normalized: images/image_1762966872732.png
# Normalized: images/image_1762966872823.png
# Normalized: images/image_1762966872908.png
# Normalized: images/image_1762966872990.png
# Normalized: images/image_1762966873106.png
# Normalized: images/image_1762966873192.png
# Normalized: images/image_1762966873276.png
# Normalized: images/image_1762966873361.png
# Normalized: images/image_1762966873447.png
# Normalized: images/image_1762966873550.png
# Normalized: images/image_1762966873638.png
# Normalized: images/image_1762966873722.png
# Normalized: images/image_1762966873805.png
# Normalized: images/image_1762966873894.png
# Normalized: images/image_1762966873980.png
# Normalized: images/image_1762966874068.png
# Normalized: images/image_1762966874157.png
# Normalized: images/image_1762966874243.png
# Normalized: images/image_1762966874326.png
# Normalized: images/image_1762966874405.png
# Normalized: images/image_1762966874492.png
# Normalized: images/image_1762966874576.png
# Normalized: images/image_1762966874662.png
# Normalized: images/image_1762966874764.png
# Normalized: images/image_1762966874850.png
# Normalized: images/image_1762966874933.png
# Normalized: images/image_1762966875018.png
# Normalized: images/image_1762966875124.png
# Normalized: images/image_1762966875233.png
# Normalized: images/image_1762966875316.png
# Normalized: images/image_1762966875391.png
# Normalized: images/image_1762966875477.png
# Normalized: images/image_1762966875567.png
# Normalized: images/image_1762966875651.png
# Normalized: images/image_1762966875743.png
# Normalized: images/image_1762966875830.png
# Normalized: images/image_1762966875925.png
# Normalized: images/image_1762966876099.png
# Normalized: images/image_1762966876344.png
# Normalized: images/image_1762966876499.png
# Normalized: images/image_1762966876657.png
# Normalized: images/image_1762966876808.png
# Normalized: images/image_1762966876966.png
# Normalized: images/image_1762966877097.png
# Normalized: images/image_1762966877207.png
# Normalized: images/image_1762966877335.png
# Normalized: images/image_1762966877448.png
# Normalized: images/image_1762966877540.png
# Normalized: images/image_1762966877635.png
# Normalized: images/image_1762966877752.png
# Normalized: images/image_1762966877856.png
# Normalized: images/image_1762966878067.png
# Normalized: images/image_1762966878300.png
# Normalized: images/image_1762966878460.png
# Normalized: images/image_1762966878606.png
# Normalized: images/image_1762966878747.png
# Normalized: images/image_1762966878910.png
# Normalized: images/image_1762966879104.png
# Normalized: images/image_1762966879260.png
# Normalized: images/image_1762966879406.png
# Normalized: images/image_1762966879544.png
# Normalized: images/image_1762966879671.png
# Normalized: images/image_1762966879807.png
# Normalized: images/image_1762966879936.png
# Normalized: images/image_1762966880056.png
# Normalized: images/image_1762966880185.png
# Normalized: images/image_1762966880313.png
# Normalized: images/image_1762966880427.png
# Normalized: images/image_1762966880527.png
# Normalized: images/image_1762966880611.png
# Normalized: images/image_1762966880697.png
# Normalized: images/image_1762966880794.png
# Normalized: images/image_1762966880900.png
# Normalized: images/image_1762966880983.png
# Normalized: images/image_1762966881075.png
# Normalized: images/image_1762966881152.png
# Normalized: images/image_1762966881233.png
# Normalized: images/image_1762966881322.png
# Normalized: images/image_1762966881398.png
# Normalized: images/image_1762966881477.png
# Normalized: images/image_1762966881573.png
# Normalized: images/image_1762966881666.png
# Normalized: images/image_1762966881749.png
# Normalized: images/image_1762966881834.png
# Normalized: images/image_1762966881918.png
# Normalized: images/image_1762966882001.png
# Normalized: images/image_1762966882091.png
# Normalized: images/image_1762966882170.png
# Normalized: images/image_1762966882258.png
# Normalized: images/image_1762966882356.png
# Normalized: images/image_1762966882450.png
# Normalized: images/image_1762966882545.png
# Normalized: images/image_1762966882637.png
# Normalized: images/image_1762966882745.png
# Normalized: images/image_1762966882826.png
# Normalized: images/image_1762966882912.png
# Normalized: images/image_1762966883011.png
# Normalized: images/image_1762966883122.png
# Normalized: images/image_1762966883234.png
# Normalized: images/image_1762966883311.png
# Normalized: images/image_1762966883389.png
# Normalized: images/image_1762966883467.png
# Normalized: images/image_1762966883542.png
# Normalized: images/image_1762966883620.png
# Normalized: images/image_1762966883719.png
# Normalized: images/image_1762966883849.png
# Normalized: images/image_1762966883983.png
# Normalized: images/image_1762966884087.png
# Normalized: images/image_1762966884207.png
# Normalized: images/image_1762966884319.png
# Normalized: images/image_1762966884463.png
# Normalized: images/image_1762966884625.png
# Normalized: images/image_1762966884768.png
# Normalized: images/image_1762966884850.png
# Normalized: images/image_1762966884931.png
# Normalized: images/image_1762966885098.png
# Normalized: images/image_1762966885215.png
# Normalized: images/image_1762966885314.png
# Normalized: images/image_1762966885417.png
# Normalized: images/image_1762966885522.png
# Normalized: images/image_1762966885628.png
# Normalized: images/image_1762966885733.png
# Normalized: images/image_1762966885861.png
# Normalized: images/image_1762966886076.png
# Normalized: images/image_1762966886367.png
# Normalized: images/image_1762966886519.png
# Normalized: images/image_1762966886732.png
# Normalized: images/image_1762966886951.png
# Normalized: images/image_1762966887153.png
# Normalized: images/image_1762966887349.png
# Normalized: images/image_1762966887483.png
# Normalized: images/image_1762966887596.png
# Normalized: images/image_1762966887714.png
# Normalized: images/image_1762966887826.png
# Normalized: images/image_1762966888158.png
# Normalized: images/image_1762966888336.png
# Normalized: images/image_1762966888479.png
# Normalized: images/image_1762966888643.png
# Normalized: images/image_1762966888829.png
# Normalized: images/image_1762966888961.png
# Normalized: images/image_1762966889179.png
# Normalized: images/image_1762966889336.png
# Normalized: images/image_1762966889517.png
# Normalized: images/image_1762966889677.png
# Normalized: images/image_1762966889862.png
# Normalized: images/image_1762966890018.png
# Normalized: images/image_1762966890173.png
# Normalized: images/image_1762966890309.png
# Normalized: images/image_1762966890699.png
# Normalized: images/image_1762966890807.png
# Normalized: images/image_1762966890917.png
# Normalized: images/image_1762966891036.png
# Normalized: images/image_1762966891176.png
# Normalized: images/image_1762966891447.png
# Normalized: images/image_1762966891558.png
# Normalized: images/image_1762966891658.png
# Normalized: images/image_1762966891761.png
# Normalized: images/image_1762966891878.png
# Normalized: images/image_1762966891971.png
# Normalized: images/image_1762966892060.png
# Normalized: images/image_1762966892160.png
# Normalized: images/image_1762966892302.png
# Normalized: images/image_1762966892401.png
# Normalized: images/image_1762966892510.png
# Normalized: images/image_1762966892613.png
# Normalized: images/image_1762966892703.png
# Normalized: images/image_1762966892829.png
# Normalized: images/image_1762966893070.png
# Normalized: images/image_1762966893295.png
# Normalized: images/image_1762966893443.png
# Normalized: images/image_1762966893525.png
# Normalized: images/image_1762966893626.png
# Normalized: images/image_1762966893730.png
# Normalized: images/image_1762966894122.png
# Normalized: images/image_1762966894275.png
# Normalized: images/image_1762966894415.png
# Normalized: images/image_1762966894537.png
# Normalized: images/image_1762966894636.png
# Normalized: images/image_1762966894739.png
# Normalized: images/image_1762966894836.png
# Normalized: images/image_1762966894934.png
# Normalized: images/image_1762966895008.png
# Normalized: images/image_1762966895117.png
# Normalized: images/image_1762966895221.png
# Normalized: images/image_1762966895321.png
# Normalized: images/image_1762966895418.png
# Normalized: images/image_1762966895516.png
# Normalized: images/image_1762966895643.png
# Normalized: images/image_1762966895746.png
# Normalized: images/image_1762966895842.png
# Normalized: images/image_1762966896004.png
# Normalized: images/image_1762966896210.png
# Normalized: images/image_1762966896408.png
# Normalized: images/image_1762966896653.png
# Normalized: images/image_1762966896841.png
# Normalized: images/image_1762966897010.png
# Normalized: images/image_1762966897150.png
# Normalized: images/image_1762966897251.png
# Normalized: images/image_1762966897364.png
# Normalized: images/image_1762966897461.png
# Normalized: images/image_1762966897571.png
# Normalized: images/image_1762966897681.png
# Normalized: images/image_1762966897814.png
# Normalized: images/image_1762966897908.png
# Normalized: images/image_1762966898171.png
# Normalized: images/image_1762966898341.png
# Normalized: images/image_1762966898609.png
# Normalized: images/image_1762966898796.png
# Normalized: images/image_1762966898956.png
# Normalized: images/image_1762966899101.png
# Normalized: images/image_1762966899222.png
# Normalized: images/image_1762966899312.png
# Normalized: images/image_1762966899441.png
# Normalized: images/image_1762966899605.png
# Normalized: images/image_1762966899719.png
# Normalized: images/image_1762966899865.png
# Normalized: images/image_1762966899977.png
# Normalized: images/image_1762966900136.png
# Normalized: images/image_1762966900238.png
# Normalized: images/image_1762966900337.png
# Normalized: images/image_1762966900426.png
# Normalized: images/image_1762966900550.png
# Normalized: images/image_1762966900631.png
# Normalized: images/image_1762966900840.png
# Normalized: images/image_1762966900986.png
# Normalized: images/image_1762966901072.png
# Normalized: images/image_1762966901176.png
# Normalized: images/image_1762966901317.png
# Normalized: images/image_1762966901399.png
# Normalized: images/image_1762966901494.png
# Normalized: images/image_1762966901579.png
# Normalized: images/image_1762966901803.png
# Normalized: images/image_1762966901898.png
# Normalized: images/image_1762966902007.png
# Normalized: images/image_1762966902112.png
# Normalized: images/image_1762966902232.png
# Normalized: images/image_1762966902326.png
# Normalized: images/image_1762966902423.png
# Normalized: images/image_1762966902517.png
# Normalized: images/image_1762966902645.png
# Normalized: images/image_1762966902763.png
# Normalized: images/image_1762966902896.png
# Normalized: images/image_1762966903038.png
# Normalized: images/image_1762966903160.png
# Normalized: images/image_1762966903267.png
# Normalized: images/image_1762966903371.png
# Normalized: images/image_1762966903506.png
# Normalized: images/image_1762966903596.png
# Normalized: images/image_1762966903676.png
# Normalized: images/image_1762966903776.png
# Normalized: images/image_1762966903862.png
# Normalized: images/image_1762966903965.png
# Normalized: images/image_1762966904083.png
# Normalized: images/image_1762966904188.png
# Normalized: images/image_1762966904322.png
# Normalized: images/image_1762966904425.png
# Normalized: images/image_1762966904526.png
# Normalized: images/image_1762966904610.png
# Normalized: images/image_1762966904693.png
# Normalized: images/image_1762966904789.png
# Normalized: images/image_1762966904993.png
# Normalized: images/image_1762966905097.png
# Normalized: images/image_1762966905200.png
# Normalized: images/image_1762966905301.png
# Normalized: images/image_1762966905412.png
# Normalized: images/image_1762966905529.png
# Normalized: images/image_1762966905633.png
# Normalized: images/image_1762966905742.png
# Normalized: images/image_1762966905870.png
# Normalized: images/image_1762966906012.png
# Normalized: images/image_1762966906217.png
# Normalized: images/image_1762966906419.png
# Normalized: images/image_1762966906613.png
# Normalized: images/image_1762966906837.png
# Normalized: images/image_1762966907030.png
# Normalized: images/image_1762966907239.png
# Normalized: images/image_1762966907346.png
# Normalized: images/image_1762966907486.png
# Normalized: images/image_1762966907579.png
# Normalized: images/image_1762966907687.png
# Normalized: images/image_1762966907792.png
# Normalized: images/image_1762966907912.png
# Normalized: images/image_1762966908211.png
# Normalized: images/image_1762966908368.png
# Normalized: images/image_1762966908540.png
# Normalized: images/image_1762966908666.png
# Normalized: images/image_1762966908783.png
# Normalized: images/image_1762966908918.png
# Normalized: images/image_1762966909031.png
# Normalized: images/image_1762966909147.png
# Normalized: images/image_1762966909261.png
# Normalized: images/image_1762966909396.png
# Normalized: images/image_1762966909522.png
# Normalized: images/image_1762966909677.png
# Normalized: images/image_1762966909810.png
# Normalized: images/image_1762966909930.png
# Normalized: images/image_1762966910055.png
# Normalized: images/image_1762966910158.png
# Normalized: images/image_1762966910330.png
# Normalized: images/image_1762966910489.png
# Normalized: images/image_1762966910637.png
# Normalized: images/image_1762966910781.png
# Normalized: images/image_1762966910942.png
# Normalized: images/image_1762966911065.png
# Normalized: images/image_1762966911221.png
# Normalized: images/image_1762966911369.png
# Normalized: images/image_1762966911515.png
# Normalized: images/image_1762966911667.png
# Normalized: images/image_1762966911817.png
# Normalized: images/image_1762966911988.png
# Normalized: images/image_1762966912130.png
# Normalized: images/image_1762966912272.png
# Normalized: images/image_1762966912396.png
# Normalized: images/image_1762966912582.png
# Normalized: images/image_1762966912703.png
# Normalized: images/image_1762966912839.png
# Normalized: images/image_1762966912990.png
# Normalized: images/image_1762966913133.png
# Normalized: images/image_1762966913250.png
# Normalized: images/image_1762966913388.png
# Normalized: images/image_1762966913560.png
# Normalized: images/image_1762966913697.png
# Normalized: images/image_1762966913818.png
# Normalized: images/image_1762966913953.png
# Normalized: images/image_1762966914091.png
# Normalized: images/image_1762966914232.png
# Normalized: images/image_1762966914396.png
# Normalized: images/image_1762966914526.png
# Normalized: images/image_1762966914694.png
# Normalized: images/image_1762966914810.png
# Normalized: images/image_1762966914954.png
# Normalized: images/image_1762966915073.png
# Normalized: images/image_1762966915182.png
# Normalized: images/image_1762966915265.png
# Normalized: images/image_1762966915377.png
# Normalized: images/image_1762966915461.png
# Normalized: images/image_1762966915557.png
# Normalized: images/image_1762966915721.png
# Normalized: images/image_1762966915827.png
# Normalized: images/image_1762966915928.png
# Normalized: images/image_1762966916161.png
# Normalized: images/image_1762966916423.png
# Normalized: images/image_1762966916632.png
# Normalized: images/image_1762966916813.png
# Normalized: images/image_1762966916958.png
# Normalized: images/image_1762966917081.png
# Normalized: images/image_1762966917179.png
# Normalized: images/image_1762966917270.png
# Normalized: images/image_1762966917398.png
# Normalized: images/image_1762966917510.png
# Normalized: images/image_1762966917611.png
# Normalized: images/image_1762966917755.png
# Normalized: images/image_1762966917975.png
# Normalized: images/image_1762966918212.png
# Normalized: images/image_1762966918424.png
# Normalized: images/image_1762966918591.png
# Normalized: images/image_1762966918706.png
# Normalized: images/image_1762966918820.png
# Normalized: images/image_1762966918908.png
# Normalized: images/image_1762966919018.png
# Normalized: images/image_1762966919182.png
# Normalized: images/image_1762966919325.png
# Normalized: images/image_1762966919503.png
# Normalized: images/image_1762966919655.png
# Normalized: images/image_1762966919775.png
# Normalized: images/image_1762966919881.png
# Normalized: images/image_1762966919986.png
# Normalized: images/image_1762966920110.png
# Normalized: images/image_1762966920210.png
# Normalized: images/image_1762966920292.png
# Normalized: images/image_1762966920418.png
# Normalized: images/image_1762966920512.png
# Normalized: images/image_1762966920616.png
# Normalized: images/image_1762966920727.png
# Normalized: images/image_1762966920847.png
# Normalized: images/image_1762966920965.png
# Normalized: images/image_1762966921078.png
# Normalized: images/image_1762966921192.png
# Normalized: images/image_1762966921303.png
# Normalized: images/image_1762966921407.png
# Normalized: images/image_1762966921531.png
# Normalized: images/image_1762966921669.png
# Normalized: images/image_1762966921804.png
# Normalized: images/image_1762966921892.png
# Normalized: images/image_1762966921973.png
# Normalized: images/image_1762966922067.png
# Normalized: images/image_1762966922178.png
# Normalized: images/image_1762966922259.png
# Normalized: images/image_1762966922345.png
# Normalized: images/image_1762966922442.png
# Normalized: images/image_1762966922521.png
# Normalized: images/image_1762966922609.png
# Normalized: images/image_1762966922691.png
# Normalized: images/image_1762966922777.png
# Normalized: images/image_1762966922865.png
# Normalized: images/image_1762966922957.png
# Normalized: images/image_1762966923049.png
# Normalized: images/image_1762966923130.png
# Normalized: images/image_1762966923215.png
# Normalized: images/image_1762966923295.png
# Normalized: images/image_1762966923375.png
# Normalized: images/image_1762966923461.png
# Normalized: images/image_1762966923552.png
# Normalized: images/image_1762966923636.png
# Normalized: images/image_1762966923716.png
# Normalized: images/image_1762966923793.png
# Normalized: images/image_1762966923873.png
# Normalized: images/image_1762966923957.png
# Normalized: images/image_1762966924038.png
# Normalized: images/image_1762966924119.png
# Normalized: images/image_1762966924199.png
# Normalized: images/image_1762966924297.png
# Normalized: images/image_1762966924377.png
# Normalized: images/image_1762966924471.png
# Normalized: images/image_1762966924554.png
# Normalized: images/image_1762966924652.png
# Normalized: images/image_1762966924736.png
# Normalized: images/image_1762966924816.png
# Normalized: images/image_1762966924893.png
# Normalized: images/image_1762966924975.png
# Normalized: images/image_1762966925063.png
# Normalized: images/image_1762966925143.png
# Normalized: images/image_1762966925226.png
# Normalized: images/image_1762966925317.png
# Normalized: images/image_1762966925391.png
# Normalized: images/image_1762966925472.png
# Normalized: images/image_1762966925551.png
# Normalized: images/image_1762966925631.png
# Normalized: images/image_1762966925712.png
# Normalized: images/image_1762966925792.png
# Normalized: images/image_1762966925872.png
# Normalized: images/image_1762966925965.png
# Normalized: images/image_1762966926104.png
# Normalized: images/image_1762966926340.png
# Normalized: images/image_1762966926490.png

# %%
# Get data from the bucket
norm_data = get_data_images(bucket = "trusted-zone", prefix = "images")
# Convert the data into a dataFrame
df_norm_data = pd.DataFrame(norm_data)
df_norm_data.head()
# Have a quick summary of the data
df_norm_data.describe(include="all")
# Out:
#                              file_name   file_size  width  height  \
# count                              500  500.000000  500.0   500.0
# unique                             500         NaN    NaN     NaN
# top     images/image_1762966926490.png         NaN    NaN     NaN
# freq                                 1         NaN    NaN     NaN
# mean                               NaN  339.725186  512.0   512.0
# std                                NaN  109.594834    0.0     0.0
# min                                NaN   17.915039  512.0   512.0
# 25%                                NaN  273.300049  512.0   512.0
# 50%                                NaN  350.678223  512.0   512.0
# 75%                                NaN  421.788330  512.0   512.0
# max                                NaN  573.761719  512.0   512.0
#
#         aspect_ratio mode  channels duplicated
# count          500.0  500     500.0        500
# unique           NaN    1       NaN          1
# top              NaN  RGB       NaN      False
# freq             NaN  500       NaN        500
# mean             1.0  NaN       3.0        NaN
# std              0.0  NaN       0.0        NaN
# min              1.0  NaN       3.0        NaN
# 25%              1.0  NaN       3.0        NaN
# 50%              1.0  NaN       3.0        NaN
# 75%              1.0  NaN       3.0        NaN
# max              1.0  NaN       3.0        NaN
