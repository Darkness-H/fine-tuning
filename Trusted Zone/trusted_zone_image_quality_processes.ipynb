# %% [markdown]
# ## Quality Processes for Images

# %%
# Importing useful dependencies
import io
import os
import boto3
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %% [markdown]
# Before preparing/cleaning the data for exploitation zone, we have to perform a quality analysis of the images stored in the Trusted Zone (Copied from the Formatted Zone). For that purpose, firstly we are going to extract data from each of our images.

# %%
# Given a bucket and a prefix, the function returns a list of data of each image in the target path
def get_data_images(bucket, prefix=""):

    data = []
    etags=set()
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):
            duplicate = False
            key = obj["Key"]

            size = obj["Size"]
            etag = obj["ETag"].strip('"')
            if size == 0 and key.endswith("/"):
                continue

            # duplication check
            sig = (etag, size)
            if sig in etags:
                duplicate = True
            else:
                etags.add(sig)

            # Download the image
            resp = s3.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()
        
            with Image.open(io.BytesIO(body)) as img:
                width, height = img.size
                mode = img.mode
                n_channels = len(mode) if mode in ["RGB","RGBA","L","CMYK"] else None
        
            data.append({
                "file_name": key,
                "file_size": obj['Size'] / 1024, # B -> KB
                "width": width,
                "height": height,
                "aspect_ratio": round(width/height, 2) if height > 0 else None, # proportional relationship between image width and height
                "mode": mode, # how pixel values are stored
                "channels": n_channels, # number of color channels in the image
                "duplicated": duplicate
            })

    return data

# %%
# Get data from the bucket
data = get_data_images(bucket = "trusted-zone", prefix = "images")

# %%
# Convert the data into a dataFrame
df_data = pd.DataFrame(data)
display(df_data.head(5))
# Out:
#                         file_name    file_size  width  height  aspect_ratio  \
# 0  images/image_1766693569364.png   209.694336    460     215          2.14
# 1  images/image_1766693569616.png   165.176758    460     215          2.14
# 2  images/image_1766693569885.png  1279.625977   1360     655          2.08
# 3  images/image_1766693570122.png   207.320312    460     215          2.14
# 4  images/image_1766693570263.png   185.140625    460     215          2.14
#
#   mode  channels  duplicated
# 0  RGB         3       False
# 1  RGB         3       False
# 2  RGB         3       False
# 3  RGB         3       False
# 4  RGB         3       False

# %%
# Have a quick summary of the data
df_data.describe(include="all")
# Out:
#                              file_name     file_size        width  \
# count                              500    500.000000   500.000000
# unique                             500           NaN          NaN
# top     images/image_1766693569364.png           NaN          NaN
# freq                                 1           NaN          NaN
# mean                               NaN   1835.187193  1310.470000
# std                                NaN   4924.317678  1114.936292
# min                                NaN     10.209961   460.000000
# 25%                                NaN    150.345215   460.000000
# 50%                                NaN    221.721191   528.500000
# 75%                                NaN   2149.866699  1920.000000
# max                                NaN  90278.363281  9990.000000
#
#              height  aspect_ratio mode    channels duplicated
# count    500.000000    500.000000  500  500.000000        500
# unique          NaN           NaN    2         NaN          1
# top             NaN           NaN  RGB         NaN      False
# freq            NaN           NaN  499         NaN        500
# mean     739.942000      1.943220  NaN    2.996000        NaN
# std      715.251096      0.257014  NaN    0.089443        NaN
# min      215.000000      0.890000  NaN    1.000000        NaN
# 25%      215.000000      1.780000  NaN    3.000000        NaN
# 50%      257.500000      2.140000  NaN    3.000000        NaN
# 75%     1080.000000      2.140000  NaN    3.000000        NaN
# max     7940.000000      3.100000  NaN    3.000000        NaN

# %%
# Unique values for mode
pd.unique(df_data['mode'])
# Out:
# array(['RGB', 'L'], dtype=object)

# %% [markdown]
# Looking at the table shown above, the images we have are around 2MB (mean/1024) in size. In fact, the first 75% of the data are around that size. However, then we have that the maximum file size is around 100MB. On the other hand, we have different distributions in both width and height columns, which suggests the images are not square and this implies varied aspect ratio for the images. When it comes to the mode, the most of our images are RGB (3 channels) and the remaining ones are L (8-bit grayscale image).
#
# Next, we show some plots to better illustrate the characteristics of our images.

# %% [markdown]
# **Distribution of File Sizes**

# %%
sns.histplot(df_data["file_size"], bins=50)
plt.xlabel("File size (KB)")
plt.ylabel("Count")
plt.title("Distribution of file sizes")
plt.show()

# %% [markdown]
# Most images are small, around 1MB (1024KB). But there are some outliers like the ones that are around 40000KB and 100000KB.

# %% [markdown]
# **Width vs Height of Images**

# %%
sns.scatterplot(x="width", y="height", data=df_data, alpha=0.5)
plt.xlabel("Width (px)")
plt.ylabel("Height (px)")
plt.title("Width vs Height of Images")
plt.show()

# %% [markdown]
# Like we mentioned before, there are some outliers, big images that exceed the rest of the images, in our dataset.

# %% [markdown]
# **Aspect Ratio Distribution**

# %%
sns.histplot(df_data["aspect_ratio"].dropna(), bins=50)
plt.xlabel("Aspect Ratio (W/H)")
plt.title("Aspect Ratio Distribution")
plt.show()

# %% [markdown]
# Here, we provide another perspective to analyze the size of the images. The aspect ratio is computed by dividing the width by the height of an image. This metric does not directly measure the file size, but rather the shape and proportions of the image.
#
# Most of the images have an aspect ratio around 2, which suggests that they are approximately twice as wide as they are tall. In other words, the dataset is dominated by horizontally oriented (landscape) images.

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# As observed in the previous quality analysis, most of our images are already in RGB format (3 channels). Although it is possible to convert them into RGBA (4 channels), doing so would introduce unnecessary complexity without providing any real benefit for our use case. Since these images will later be converted into embeddings, it is more practical to keep them in RGB (3 channels). This approach ensures consistency across the dataset, avoids the overhead of an unused alpha channel, and aligns with the input requirements of most machine learning models.
#
# On the other hand, we want to normalize the images to a fixed resolution, for example 512×512. This ensures uniformity across the dataset, making the embeddings more consistent and comparable, and also optimizes processing efficiency when generating vectors. While we considered removing outliers from the dataset, we preferred to retain all images to preserve the full diversity of the collection. Instead, we decided to handle variations through preprocessing adjustments. After resizing, we can also normalize the pixel values by converting them to a standard range, which helps stabilize the model’s input, improves convergence, and ensures that differences in lighting or color intensity do not disproportionately affect the embeddings.

# %%
def preprocess_image(client ,bucket, prefix="", target_size=(512, 512)):
    """

    client          : obj                   - S3-compatible client (e.g., boto3.client("s3")).
    bucket          : str                   - Target S3/MinIO bucket.
    prefix          : str                   - Optional key prefix (acts like a folder path).
    target_size     :
    """
    """
    data = get_data_images(bucket, prefix=prefix)
    df = pd.DataFrame(data) if not isinstance(data, pd.DataFrame) else data.copy()
    if df.empty:
        raise ValueError("No image data to report.")
    """
    df = df_data
    for row in df.itertuples(index=False):


        # remove empty or duplicated image
        if row.duplicated:
            client.delete_object(Bucket=bucket, Key=row.key)
            continue

        # get image name
        key = row.file_name

        try:
            # Get object metadata to check size
            head = client.head_object(Bucket=bucket, Key=key)
            if head['ContentLength'] == 0:
                # Delete the null image (size = 0)
                client.delete_object(Bucket=bucket, Key=key)
                continue
        except Exception as e:
            print(e)
            continue

        try:
            # Download the image
            resp = client.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()

            # Load image with Pillow
            img = Image.open(io.BytesIO(body))

            # Convert images into RGB
            if img.mode != 'RGB':
                img = img.convert('RGB')  # 3 channels

            # Resize image
            img = img.resize(target_size, Image.LANCZOS)  # Image.LANCZOS = image smoother

            # Convert to numpy array and normalize pixel values to [0, 1]
            img_array = np.array(img).astype(np.float32) / 255.0
            # Convert back to PIL Image
            img_out = Image.fromarray((img_array * 255).astype(np.uint8))
            buf = io.BytesIO()
            img_out.save(buf, format="PNG")
            buf.seek(0)

            # Upload the image back
            client.upload_fileobj(buf, Bucket=bucket, Key=key, ExtraArgs={"ContentType": "image/png"}) # the old file is overwritten with the new one

            print(f"Normalized: {key}")
        except Exception as e:
            print(e)

# %%
# Standardizing images
preprocess_image(s3, bucket = "trusted-zone", prefix = "images/", target_size = (512,512))
# Out:
# Normalized: images/image_1766693569364.png
# Normalized: images/image_1766693569616.png
# Normalized: images/image_1766693569885.png
# Normalized: images/image_1766693570122.png
# Normalized: images/image_1766693570263.png
# Normalized: images/image_1766693571070.png
# Normalized: images/image_1766693572518.png
# Normalized: images/image_1766693572922.png
# Normalized: images/image_1766693573444.png
# Normalized: images/image_1766693573781.png
# Normalized: images/image_1766693574019.png
# Normalized: images/image_1766693574351.png
# Normalized: images/image_1766693574937.png
# Normalized: images/image_1766693575261.png
# Normalized: images/image_1766693575489.png
# Normalized: images/image_1766693575914.png
# Normalized: images/image_1766693576167.png
# Normalized: images/image_1766693576696.png
# Normalized: images/image_1766693577165.png
# Normalized: images/image_1766693577419.png
# Normalized: images/image_1766693577890.png
# Normalized: images/image_1766693578226.png
# Normalized: images/image_1766693578469.png
# Normalized: images/image_1766693578846.png
# Normalized: images/image_1766693579177.png
# Normalized: images/image_1766693579508.png
# Normalized: images/image_1766693579916.png
# Normalized: images/image_1766693580215.png
# Normalized: images/image_1766693580599.png
# Normalized: images/image_1766693580944.png
# Normalized: images/image_1766693581260.png
# Normalized: images/image_1766693581963.png
# Normalized: images/image_1766693582544.png
# Normalized: images/image_1766693584674.png
# Normalized: images/image_1766693585202.png
# Normalized: images/image_1766693585693.png
# Normalized: images/image_1766693585981.png
# Normalized: images/image_1766693586310.png
# Normalized: images/image_1766693586537.png
# Normalized: images/image_1766693586784.png
# Normalized: images/image_1766693587030.png
# Normalized: images/image_1766693587293.png
# Normalized: images/image_1766693587551.png
# Normalized: images/image_1766693587793.png
# Normalized: images/image_1766693587938.png
# Normalized: images/image_1766693588067.png
# Normalized: images/image_1766693588327.png
# Normalized: images/image_1766693588528.png
# Normalized: images/image_1766693588781.png
# Normalized: images/image_1766693589039.png
# Normalized: images/image_1766693589211.png
# Normalized: images/image_1766693589528.png
# Normalized: images/image_1766693589823.png
# Normalized: images/image_1766693589992.png
# Normalized: images/image_1766693590122.png
# Normalized: images/image_1766693590301.png
# Normalized: images/image_1766693590442.png
# Normalized: images/image_1766693590695.png
# Normalized: images/image_1766693591077.png
# Normalized: images/image_1766693591454.png
# Normalized: images/image_1766693591878.png
# Normalized: images/image_1766693592221.png
# Normalized: images/image_1766693592444.png
# Normalized: images/image_1766693592946.png
# Normalized: images/image_1766693593383.png
# Normalized: images/image_1766693593876.png
# Normalized: images/image_1766693594125.png
# Normalized: images/image_1766693595330.png
# Normalized: images/image_1766693596501.png
# Normalized: images/image_1766693596874.png
# Normalized: images/image_1766693597260.png
# Normalized: images/image_1766693597551.png
# Normalized: images/image_1766693597714.png
# Normalized: images/image_1766693597987.png
# Normalized: images/image_1766693598217.png
# Normalized: images/image_1766693598609.png
# Normalized: images/image_1766693599027.png
# Normalized: images/image_1766693599349.png
# Normalized: images/image_1766693599637.png
# Normalized: images/image_1766693599838.png
# Normalized: images/image_1766693600048.png
# Normalized: images/image_1766693600412.png
# Normalized: images/image_1766693600775.png
# Normalized: images/image_1766693601107.png
# Normalized: images/image_1766693601354.png
# Normalized: images/image_1766693601690.png
# Normalized: images/image_1766693601925.png
# Normalized: images/image_1766693602160.png
# Normalized: images/image_1766693602521.png
# Normalized: images/image_1766693602891.png
# Normalized: images/image_1766693603205.png
# Normalized: images/image_1766693603585.png
# Normalized: images/image_1766693603852.png
# Normalized: images/image_1766693604109.png
# Normalized: images/image_1766693604426.png
# Normalized: images/image_1766693604773.png
# Normalized: images/image_1766693605303.png
# Normalized: images/image_1766693605548.png
# Normalized: images/image_1766693605899.png
# Normalized: images/image_1766693606206.png
# Normalized: images/image_1767028840733.png
# Normalized: images/image_1767028840956.png
# Normalized: images/image_1767028841157.png
# Normalized: images/image_1767028841350.png
# Normalized: images/image_1767028841528.png
# Normalized: images/image_1767028841729.png
# Normalized: images/image_1767028841982.png
# Normalized: images/image_1767028842345.png
# Normalized: images/image_1767028843201.png
# Normalized: images/image_1767028844209.png
# Normalized: images/image_1767028844565.png
# Normalized: images/image_1767028844777.png
# Normalized: images/image_1767028845056.png
# Normalized: images/image_1767028845438.png
# Normalized: images/image_1767028846415.png
# Normalized: images/image_1767028846726.png
# Normalized: images/image_1767028846958.png
# Normalized: images/image_1767028847207.png
# Normalized: images/image_1767028847448.png
# Normalized: images/image_1767028847787.png
# Normalized: images/image_1767028848251.png
# Normalized: images/image_1767028848752.png
# Normalized: images/image_1767028849133.png
# Normalized: images/image_1767028849547.png
# Normalized: images/image_1767028849863.png
# Normalized: images/image_1767028850213.png
# Normalized: images/image_1767028850496.png
# Normalized: images/image_1767028850837.png
# Normalized: images/image_1767028851096.png
# Normalized: images/image_1767028851474.png
# Normalized: images/image_1767028851864.png
# Normalized: images/image_1767028852160.png
# Normalized: images/image_1767028852469.png
# Normalized: images/image_1767028853320.png
# Normalized: images/image_1767028854102.png
# Normalized: images/image_1767028854403.png
# Normalized: images/image_1767028854628.png
# Normalized: images/image_1767028854757.png
# Normalized: images/image_1767028854888.png
# Normalized: images/image_1767028855098.png
# Normalized: images/image_1767028855213.png
# Normalized: images/image_1767028855586.png
# Normalized: images/image_1767028856338.png
# Normalized: images/image_1767028856681.png
# Normalized: images/image_1767028856882.png
# Normalized: images/image_1767028857096.png
# Normalized: images/image_1767028857305.png
# Normalized: images/image_1767028857524.png
# Normalized: images/image_1767028857698.png
# Normalized: images/image_1767028857876.png
# Normalized: images/image_1767028857961.png
# Normalized: images/image_1767028858181.png
# Normalized: images/image_1767028858434.png
# Normalized: images/image_1767028858578.png
# Normalized: images/image_1767028858751.png
# Normalized: images/image_1767028859033.png
# Normalized: images/image_1767028859145.png
# Normalized: images/image_1767028859427.png
# Normalized: images/image_1767028859583.png
# Normalized: images/image_1767028859821.png
# Normalized: images/image_1767028859949.png
# Normalized: images/image_1767028860164.png
# Normalized: images/image_1767028860248.png
# Normalized: images/image_1767028860380.png
# Normalized: images/image_1767028860511.png
# Normalized: images/image_1767028860710.png
# Normalized: images/image_1767028860966.png
# Normalized: images/image_1767028861213.png
# Normalized: images/image_1767028861420.png
# Normalized: images/image_1767028861632.png
# Normalized: images/image_1767028861728.png
# Normalized: images/image_1767028861867.png
# Normalized: images/image_1767028862028.png
# Normalized: images/image_1767028862177.png
# Normalized: images/image_1767028862284.png
# Normalized: images/image_1767028862437.png
# Normalized: images/image_1767028863175.png
# Normalized: images/image_1767028863407.png
# Normalized: images/image_1767028864194.png
# Normalized: images/image_1767028864432.png
# Normalized: images/image_1767028864639.png
# Normalized: images/image_1767028864854.png
# Normalized: images/image_1767028865024.png
# Normalized: images/image_1767028865171.png
# Normalized: images/image_1767028865279.png
# Normalized: images/image_1767028865448.png
# Normalized: images/image_1767028866147.png
# Normalized: images/image_1767028866422.png
# Normalized: images/image_1767028866619.png
# Normalized: images/image_1767028866852.png
# Normalized: images/image_1767028867013.png
# Normalized: images/image_1767028867149.png
# Normalized: images/image_1767028867254.png
# Normalized: images/image_1767028867326.png
# Normalized: images/image_1767028867455.png
# Normalized: images/image_1767028867686.png
# Normalized: images/image_1767028867794.png
# Normalized: images/image_1767028867959.png
# Normalized: images/image_1767028868082.png
# Normalized: images/image_1767028868333.png
# Normalized: images/image_1767028868533.png
# Normalized: images/image_1767028868670.png
# Normalized: images/image_1767028868816.png
# Normalized: images/image_1767028868960.png
# Normalized: images/image_1767028869055.png
# Normalized: images/image_1767028869163.png
# Normalized: images/image_1767028869269.png
# Normalized: images/image_1767028869386.png
# Normalized: images/image_1767028869536.png
# Normalized: images/image_1767028869699.png
# Normalized: images/image_1767028869778.png
# Normalized: images/image_1767028869913.png
# Normalized: images/image_1767028870071.png
# Normalized: images/image_1767028870171.png
# Normalized: images/image_1767028870291.png
# Normalized: images/image_1767028870525.png
# Normalized: images/image_1767028870680.png
# Normalized: images/image_1767028870891.png
# Normalized: images/image_1767028871088.png
# Normalized: images/image_1767028871241.png
# Normalized: images/image_1767028871451.png
# Normalized: images/image_1767028871680.png
# Normalized: images/image_1767028871951.png
# Normalized: images/image_1767028872170.png
# Normalized: images/image_1767028872323.png
# Normalized: images/image_1767028872877.png
# Normalized: images/image_1767028873319.png
# Normalized: images/image_1767028874386.png
# Normalized: images/image_1767028874653.png
# Normalized: images/image_1767028874897.png
# Normalized: images/image_1767028875036.png
# Normalized: images/image_1767028875199.png
# Normalized: images/image_1767028875346.png
# Normalized: images/image_1767028876023.png
# Normalized: images/image_1767028876423.png
# Normalized: images/image_1767028876629.png
# Normalized: images/image_1767028876838.png
# Normalized: images/image_1767028877051.png
# Normalized: images/image_1767028877175.png
# Normalized: images/image_1767028877405.png
# Normalized: images/image_1767028877571.png
# Normalized: images/image_1767028877823.png
# Normalized: images/image_1767028878127.png
# Normalized: images/image_1767028878381.png
# Normalized: images/image_1767028878591.png
# Normalized: images/image_1767028878756.png
# Normalized: images/image_1767028878938.png
# Normalized: images/image_1767028879145.png
# Normalized: images/image_1767028879338.png
# Normalized: images/image_1767028879649.png
# Normalized: images/image_1767028879853.png
# Normalized: images/image_1767028880024.png
# Normalized: images/image_1767028880253.png
# Normalized: images/image_1767028880369.png
# Normalized: images/image_1767028880584.png
# Normalized: images/image_1767028880765.png
# Normalized: images/image_1767028880895.png
# Normalized: images/image_1767028880984.png
# Normalized: images/image_1767028881265.png
# Normalized: images/image_1767028881579.png
# Normalized: images/image_1767028881859.png
# Normalized: images/image_1767028882017.png
# Normalized: images/image_1767028882256.png
# Normalized: images/image_1767028882390.png
# Normalized: images/image_1767028883049.png
# Normalized: images/image_1767028883323.png
# Normalized: images/image_1767028884179.png
# Normalized: images/image_1767028884641.png
# Normalized: images/image_1767028884835.png
# Normalized: images/image_1767028885162.png
# Normalized: images/image_1767028885413.png
# Normalized: images/image_1767028885919.png
# Normalized: images/image_1767028886458.png
# Normalized: images/image_1767028886707.png
# Normalized: images/image_1767028886967.png
# Normalized: images/image_1767028887123.png
# Normalized: images/image_1767028887225.png
# Normalized: images/image_1767028887517.png
# Normalized: images/image_1767028887780.png
# Normalized: images/image_1767028887940.png
# Normalized: images/image_1767028888134.png
# Normalized: images/image_1767028888343.png
# Normalized: images/image_1767028888545.png
# Normalized: images/image_1767028888856.png
# Normalized: images/image_1767028889034.png
# Normalized: images/image_1767028889431.png
# Normalized: images/image_1767028889598.png
# Normalized: images/image_1767028889788.png
# Normalized: images/image_1767028890062.png
# Normalized: images/image_1767028890199.png
# Normalized: images/image_1767028890302.png
# Normalized: images/image_1767028890461.png
# Normalized: images/image_1767028890644.png
# Normalized: images/image_1767028890873.png
# Normalized: images/image_1767028890997.png
# Normalized: images/image_1767028891218.png
# Normalized: images/image_1767028891370.png
# Normalized: images/image_1767028891611.png
# Normalized: images/image_1767028891882.png
# Normalized: images/image_1767028892065.png
# Normalized: images/image_1767028892236.png
# Normalized: images/image_1767028892363.png
# Normalized: images/image_1767028892847.png
# Normalized: images/image_1767028893323.png
# Normalized: images/image_1767028893636.png
# Normalized: images/image_1767028894273.png
# Normalized: images/image_1767028894590.png
# Normalized: images/image_1767028894746.png
# Normalized: images/image_1767028894990.png
# Normalized: images/image_1767028895227.png
# Normalized: images/image_1767028895523.png
# Normalized: images/image_1767028896245.png
# Normalized: images/image_1767028896521.png
# Normalized: images/image_1767028896721.png
# Normalized: images/image_1767028896978.png
# Normalized: images/image_1767028897165.png
# Normalized: images/image_1767028897331.png
# Normalized: images/image_1767028897491.png
# Normalized: images/image_1767028897693.png
# Normalized: images/image_1767028897985.png
# Normalized: images/image_1767028898190.png
# Normalized: images/image_1767028898337.png
# Normalized: images/image_1767028898512.png
# Normalized: images/image_1767028898620.png
# Normalized: images/image_1767028898723.png
# Normalized: images/image_1767028898905.png
# Normalized: images/image_1767028899167.png
# Normalized: images/image_1767028899359.png
# Normalized: images/image_1767028899706.png
# Normalized: images/image_1767028900000.png
# Normalized: images/image_1767028900148.png
# Normalized: images/image_1767028900377.png
# Normalized: images/image_1767028900474.png
# Normalized: images/image_1767028900698.png
# Normalized: images/image_1767028900842.png
# Normalized: images/image_1767028901015.png
# Normalized: images/image_1767028901282.png
# Normalized: images/image_1767028901501.png
# Normalized: images/image_1767028901676.png
# Normalized: images/image_1767028901903.png
# Normalized: images/image_1767028902165.png
# Normalized: images/image_1767028902380.png
# Normalized: images/image_1767028902648.png
# Normalized: images/image_1767028903498.png
# Normalized: images/image_1767028904463.png
# Normalized: images/image_1767028904758.png
# Normalized: images/image_1767028904929.png
# Normalized: images/image_1767028905158.png
# Normalized: images/image_1767028905445.png
# Normalized: images/image_1767028906175.png
# Normalized: images/image_1767028906491.png
# Normalized: images/image_1767028906756.png
# Normalized: images/image_1767028907054.png
# Normalized: images/image_1767028907336.png
# Normalized: images/image_1767028907605.png
# Normalized: images/image_1767028907886.png
# Normalized: images/image_1767028908165.png
# Normalized: images/image_1767028908369.png
# Normalized: images/image_1767028908635.png
# Normalized: images/image_1767028908906.png
# Normalized: images/image_1767028909137.png
# Normalized: images/image_1767028909461.png
# Normalized: images/image_1767028909720.png
# Normalized: images/image_1767028909986.png
# Normalized: images/image_1767028910278.png
# Normalized: images/image_1767028910541.png
# Normalized: images/image_1767028910732.png
# Normalized: images/image_1767028911040.png
# Normalized: images/image_1767028911246.png
# Normalized: images/image_1767028911513.png
# Normalized: images/image_1767028911801.png
# Normalized: images/image_1767028912056.png
# Normalized: images/image_1767028912253.png
# Normalized: images/image_1767028912573.png
# Normalized: images/image_1767028913768.png
# Normalized: images/image_1767028914691.png
# Normalized: images/image_1767028914942.png
# Normalized: images/image_1767028915239.png
# Normalized: images/image_1767028915682.png
# Normalized: images/image_1767028916586.png
# Normalized: images/image_1767028916957.png
# Normalized: images/image_1767028917321.png
# Normalized: images/image_1767028917713.png
# Normalized: images/image_1767028917933.png
# Normalized: images/image_1767028918229.png
# Normalized: images/image_1767028918505.png
# Normalized: images/image_1767028918807.png
# Normalized: images/image_1767028919049.png
# Normalized: images/image_1767028919391.png
# Normalized: images/image_1767028919667.png
# Normalized: images/image_1767028920058.png
# Normalized: images/image_1767028920477.png
# Normalized: images/image_1767028920911.png
# Normalized: images/image_1767028921240.png
# Normalized: images/image_1767028921684.png
# Normalized: images/image_1767028921958.png
# Normalized: images/image_1767028922432.png
# Normalized: images/image_1767028923375.png
# Normalized: images/image_1767028924523.png
# Normalized: images/image_1767028924776.png
# Normalized: images/image_1767028925103.png
# Normalized: images/image_1767028925332.png
# Normalized: images/image_1767028926032.png
# Normalized: images/image_1767028926550.png
# Normalized: images/image_1767028926909.png
# Normalized: images/image_1767028927215.png
# Normalized: images/image_1767028927494.png
# Normalized: images/image_1767028927776.png
# Normalized: images/image_1767028928061.png
# Normalized: images/image_1767028928354.png
# Normalized: images/image_1767028928636.png
# Normalized: images/image_1767028928948.png
# Normalized: images/image_1767028929115.png
# Normalized: images/image_1767028929378.png
# Normalized: images/image_1767028929617.png
# Normalized: images/image_1767028929940.png
# Normalized: images/image_1767028930186.png
# Normalized: images/image_1767028930442.png
# Normalized: images/image_1767028930682.png
# Normalized: images/image_1767028930963.png
# Normalized: images/image_1767028931183.png
# Normalized: images/image_1767028931407.png
# Normalized: images/image_1767028931553.png
# Normalized: images/image_1767028931669.png
# Normalized: images/image_1767028931881.png
# Normalized: images/image_1767028932112.png
# Normalized: images/image_1767028932351.png
# Normalized: images/image_1767028932495.png
# Normalized: images/image_1767028933426.png
# Normalized: images/image_1767028934256.png
# Normalized: images/image_1767028934677.png
# Normalized: images/image_1767028934867.png
# Normalized: images/image_1767028935152.png
# Normalized: images/image_1767028935461.png
# Normalized: images/image_1767028936201.png
# Normalized: images/image_1767028936505.png
# Normalized: images/image_1767028936845.png
# Normalized: images/image_1767028937061.png
# Normalized: images/image_1767028937258.png
# Normalized: images/image_1767028937376.png
# Normalized: images/image_1767028937530.png
# Normalized: images/image_1767028937704.png
# Normalized: images/image_1767028937889.png
# Normalized: images/image_1767028938077.png
# Normalized: images/image_1767028938206.png
# Normalized: images/image_1767028938352.png
# Normalized: images/image_1767028938436.png
# Normalized: images/image_1767028938562.png
# Normalized: images/image_1767028938721.png
# Normalized: images/image_1767028938923.png
# Normalized: images/image_1767028939051.png
# Normalized: images/image_1767028939138.png
# Normalized: images/image_1767028939408.png
# Normalized: images/image_1767028939594.png
# Normalized: images/image_1767028939834.png
# Normalized: images/image_1767028939984.png
# Normalized: images/image_1767028940072.png
# Normalized: images/image_1767028940252.png
# Normalized: images/image_1767028940465.png
# Normalized: images/image_1767028940587.png
# Normalized: images/image_1767028940761.png
# Normalized: images/image_1767028940881.png
# Normalized: images/image_1767028941008.png
# Normalized: images/image_1767028941304.png
# Normalized: images/image_1767028941408.png
# Normalized: images/image_1767028941736.png
# Normalized: images/image_1767028941920.png
# Normalized: images/image_1767028942067.png
# Normalized: images/image_1767028942200.png
# Normalized: images/image_1767028942398.png
# Normalized: images/image_1767028942523.png
# Normalized: images/image_1767028943258.png
# Normalized: images/image_1767028943542.png
# Normalized: images/image_1767028944333.png
# Normalized: images/image_1767028944638.png
# Normalized: images/image_1767028944765.png
# Normalized: images/image_1767028944962.png
# Normalized: images/image_1767028945126.png
# Normalized: images/image_1767028945311.png
# Normalized: images/image_1767028945516.png
# Normalized: images/image_1767028946326.png
# Normalized: images/image_1767028946584.png
# Normalized: images/image_1767028946806.png
# Normalized: images/image_1767028947049.png
# Normalized: images/image_1767028947275.png
# Normalized: images/image_1767028947488.png
# Normalized: images/image_1767028947705.png
# Normalized: images/image_1767028947940.png
# Normalized: images/image_1767028948135.png
# Normalized: images/image_1767028948352.png
# Normalized: images/image_1767028948569.png
# Normalized: images/image_1767028948762.png
# Normalized: images/image_1767028948976.png
# Normalized: images/image_1767028949235.png
# Normalized: images/image_1767028949444.png
# Normalized: images/image_1767028949607.png
# Normalized: images/image_1767028949819.png
# Normalized: images/image_1767028949973.png
# Normalized: images/image_1767028950180.png
# Normalized: images/image_1767028950362.png

# %%
# Get data from the bucket
norm_data = get_data_images(bucket = "trusted-zone", prefix = "images")
# Convert the data into a dataFrame
df_norm_data = pd.DataFrame(norm_data)
df_norm_data.head()
# Have a quick summary of the data
df_norm_data.describe(include="all")
# Out:
#                              file_name   file_size  width  height  \
# count                              500  500.000000  500.0   500.0
# unique                             500         NaN    NaN     NaN
# top     images/image_1766693569364.png         NaN    NaN     NaN
# freq                                 1         NaN    NaN     NaN
# mean                               NaN  339.728502  512.0   512.0
# std                                NaN  109.590487    0.0     0.0
# min                                NaN   17.937500  512.0   512.0
# 25%                                NaN  273.310303  512.0   512.0
# 50%                                NaN  350.678223  512.0   512.0
# 75%                                NaN  421.788330  512.0   512.0
# max                                NaN  573.761719  512.0   512.0
#
#         aspect_ratio mode  channels duplicated
# count          500.0  500     500.0        500
# unique           NaN    1       NaN          1
# top              NaN  RGB       NaN      False
# freq             NaN  500       NaN        500
# mean             1.0  NaN       3.0        NaN
# std              0.0  NaN       0.0        NaN
# min              1.0  NaN       3.0        NaN
# 25%              1.0  NaN       3.0        NaN
# 50%              1.0  NaN       3.0        NaN
# 75%              1.0  NaN       3.0        NaN
# max              1.0  NaN       3.0        NaN
