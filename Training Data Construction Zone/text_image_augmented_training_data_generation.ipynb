# %% [markdown]
# ## Training Data Generation (Augmented Text & Image Data)

# %%
# Importing useful dependencies
import random
import re
import io
from io import BytesIO
from typing import List
import boto3
import nltk
import numpy as np
import open_clip
import requests
import torch
from PIL import Image
from torchvision import transforms
import torchvision.transforms.functional as TF

# Download the corpus
nltk.download('wordnet')
from nltk.corpus import wordnet

# Set a seed for reproducibility
SEED = 10721
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\SakuraSnow\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# We create a new Bucket in Min-IO to store our augmented training data

# List existing buckets
buckets = [b["Name"] for b in s3.list_buckets()["Buckets"]]

# Function that given a name, creates a bucket
def createBucket(name, list_buckets):
    if name in list_buckets:
        print(f"Bucket '{name}' already exists!")
    else:
        s3.create_bucket(Bucket=name)
        print(f"Created bucket: {name}")

# Create a bucket named landing_zone
createBucket("training-data-construction-zone", buckets)
# Sub-bucket: Baseline Training Data
s3.put_object(Bucket="training-data-construction-zone", Key="text_image_augmented-training-data/")
# Out:
# Bucket 'training-data-construction-zone' already exists!
# {'ResponseMetadata': {'RequestId': '187A6635E1FD8D25',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '187A6635E1FD8D25',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '2101',
#    'x-ratelimit-remaining': '2101',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Sat, 22 Nov 2025 18:03:05 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}

# %% [markdown]
# In this notebook, we create an augmented dataset by applying augmentation techniques to both the text and image data. In the following cell we implement the functions we used before.

# %%
# A simple tokenizer to split the text into a list of tokens (words in this case)
def simple_tokenize(text: str) -> List[str]:
    return re.findall(r"\w+|[^\w\s]", text, re.UNICODE)

# Delete each token with probability p.
def random_deletion(tokens: List[str], p: float = 0.1) -> List[str]:
    if len(tokens) == 1:
        return tokens

    kept = [t for t in tokens if random.random() > p]
    if not kept:
        kept.append(random.choice(tokens))
    return kept
    
# Randomly swap a small portion of tokens.
def random_swap(tokens: List[str], ratio: float = 0.05) -> list[str]:
    n = len(tokens)
    if n < 2:
        return tokens

    n_swaps = max(1, int(ratio * n))

    for _ in range(n_swaps):
        i, j = random.sample(range(n), 2)
        tokens[i], tokens[j] = tokens[j], tokens[i]
    return tokens

# Introduce a simple spelling error in a single word
def corrupt_word(word: str) -> str:
    if len(word) == 0:
        return word

    ALPHABET = "abcdefghijklmnopqrstuvwxyz"

    op = random.choice(["delete", "substitute", "duplicate"])

    if op == "delete" and len(word) > 1:
        pos = random.randrange(len(word))
        return word[:pos] + word[pos+1:]

    if op == "substitute":
        pos = random.randrange(len(word))
        new_char = random.choice(ALPHABET)
        return word[:pos] + new_char + word[pos+1:]

    if op == "duplicate":
        pos = random.randrange(len(word))
        return word[:pos] + word[pos] + word[pos:]

    return word

# For each alphabetical token, apply a spelling error with probability p.
def random_spelling_error(tokens: List[str], p: float = 0.1) -> List[str]:
    new_tokens = []
    for t in tokens:
        if t.isalpha() and random.random() < p:
            new_tokens.append(corrupt_word(t))
        else:
            new_tokens.append(t)
    return new_tokens

# Collect synonyms from WordNet
def get_synonyms(word: str) -> List[str]:
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            lemma_name = lemma.name().replace("_", " ")
            if lemma_name.lower() != word.lower():
                synonyms.add(lemma_name)
    return list(synonyms)

# Randomly choose a small portion of tokens and replace them with synonyms.
def random_synonym_replacement(tokens: List[str], ratio: float = 0.05) -> List[str]:
    n = len(tokens)
    n_replacements = max(1, int(ratio * n))
    candidate_indices = [
        i for i, t in enumerate(tokens)
        if t.isalpha() and len(t) > 2 # skip punctuation & very short tokens
    ]
    if not candidate_indices:
        return tokens

    indices = random.sample(candidate_indices, n_replacements)

    for idx in indices:
        word = tokens[idx]
        syns = get_synonyms(word)
        if syns:
            tokens[idx] = random.choice(syns)
    return tokens
###########################################################################

# This function applies an image augmentation technique to the given image
def augment_image(image: Image.Image, transformer, suffix: str = "crop"):

    if (suffix not in ["crop", "flip-x", "flip-y", "blur"]):
        return image
    
    # Apply the augmentation to the input image
    if suffix == "crop":
        
        # For random crops we sample a region per image, so we capture the crop parameters to know exactly what was applied.
        i, j, h, w = transformer.get_params(image, output_size=transformer.size) # sample crop parameters
        # Apply crop manually
        aug_image = TF.crop(image, i, j, h, w)
        # Resize back to 512x512
        resize_to_512 = transforms.Resize((512, 512))  # resize image to 512x512 pixels # resize helper used after cropping
        aug_image = resize_to_512(aug_image)
        
    else: # "flip-x", "flip-y", "blur"

        # Apply augmentation technique
        aug_image = transformer(image)
    
    return aug_image

# %% [markdown]
# In the following cells, we will construct a dataset that includes both augmented images and augmented text. Since we applied four augmentation techniques to each data type, this notebook will organize and store every generated sample according to the specific technique used. For illustration, an image produced with a horizontal flip will be paired with a text augmented using random word deletion, while an image generated with a vertical flip will be paired with a text created through random word swapping, and so on.

# %%
# We can use this function to retrieve an text from our bucket
def get_text(bucket, key):
    resp = s3.get_object(Bucket=bucket, Key=key)
    body = resp["Body"].read()
    text = body.decode("utf-8")
    return text

# We can use this function to retrieve an image from our bucket in PIL Image format
def get_image(bucket, key):
    resp = s3.get_object(Bucket=bucket, Key=key)
    body = resp["Body"].read()
    img = Image.open(BytesIO(body))
    return img

# %%
# This function generates augmented data for both texs and images in the baseline training data
def augmented_training_data(src_bucket, dest_bucket, dest_prefix="text_image_augmented-training-data/"):

    # Define image transformers
    hflip_transform = transforms.RandomHorizontalFlip(p=1.0) # always flip image horizontally (left-right)
    vflip_transform = transforms.RandomVerticalFlip(p=1.0) # always flip image vertically (top-bottom)
    crop_transform = transforms.RandomCrop(400) # randomly crop a 400x400 patch from the original image
    blur_transform = transforms.GaussianBlur(kernel_size=11, sigma=(1.0, 3.0)) # random sigma in this range of sigma
    
    paginator = s3.get_paginator("list_objects_v2") # It returns objects in pages and not all at once.
    for page in paginator.paginate(Bucket=src_bucket, Prefix="baseline-training-data/"):

        for obj in page.get("Contents", []):
            key = obj["Key"]

            if obj['Size'] == 0 and key.endswith("/"): # skip the folder itself
                continue

            # Add new prefixes
            key_1 = dest_prefix + "aug1" + "_" + key.split("/")[1]
            key_2 = dest_prefix + "aug2" + "_" + key.split("/")[1]
            key_3 = dest_prefix + "aug3" + "_" + key.split("/")[1]
            key_4 = dest_prefix + "aug4" + "_" + key.split("/")[1]

            # New key for original text and image file
            new_key = dest_prefix + key.split("/")[1]

            if "text" in key:

                # Get the description
                description = get_text(src_bucket, key)

                # Get augmented descriptions
                str1 = " ".join(random_deletion(simple_tokenize(description)))
                str2 = " ".join(random_swap(simple_tokenize(description)))
                str3 = " ".join(random_spelling_error(simple_tokenize(description)))
                str4 = " ".join(random_synonym_replacement(simple_tokenize(description)))

                # Copy objects without top-level folder and rename them
                copy_source_text = {"Bucket": src_bucket, "Key": key}
                s3.copy_object(Bucket=dest_bucket, Key=new_key, CopySource=copy_source_text)
                s3.put_object(Bucket=dest_bucket, Key=key_1, Body=io.BytesIO(str1.encode("utf-8")),ContentType="text/plain")
                s3.put_object(Bucket=dest_bucket, Key=key_2, Body=io.BytesIO(str2.encode("utf-8")),ContentType="text/plain")
                s3.put_object(Bucket=dest_bucket, Key=key_3, Body=io.BytesIO(str3.encode("utf-8")),ContentType="text/plain")
                s3.put_object(Bucket=dest_bucket, Key=key_4, Body=io.BytesIO(str4.encode("utf-8")),ContentType="text/plain")
                
            elif "image" in key:

                # Get the image
                img = get_image(src_bucket, key)

                # Get image buffer
                def get_buffer(image):
                    buffer = io.BytesIO()
                    image.save(buffer, format="PNG")
                    buffer.seek(0)
                    return buffer

                # Get augmented images
                aug_img1 = get_buffer(augment_image(img, hflip_transform, suffix = "flip-x"))
                aug_img2 = get_buffer(augment_image(img, vflip_transform, suffix = "flip-y"))
                aug_img3 = get_buffer(augment_image(img, crop_transform, suffix = "crop"))
                aug_img4 = get_buffer(augment_image(img, blur_transform, suffix = "blur"))

                # Copy objects without top-level folder and rename them
                copy_source_image = {"Bucket": src_bucket, "Key": key}
                s3.copy_object(Bucket=dest_bucket, Key=new_key, CopySource=copy_source_image)
                s3.upload_fileobj(Fileobj=aug_img1, Bucket=dest_bucket, Key=key_1, ExtraArgs={"ContentType": "image/png"})
                s3.upload_fileobj(Fileobj=aug_img2, Bucket=dest_bucket, Key=key_2, ExtraArgs={"ContentType": "image/png"})
                s3.upload_fileobj(Fileobj=aug_img3, Bucket=dest_bucket, Key=key_3, ExtraArgs={"ContentType": "image/png"})
                s3.upload_fileobj(Fileobj=aug_img4, Bucket=dest_bucket, Key=key_4, ExtraArgs={"ContentType": "image/png"})

            print(f"✅ Augmented data for #{key.split('/')[1]} created successfully.")

    print(f"✅ All augmented image data have been successfully uploaded.")

# %%
# Create augmented training dataset
augmented_training_data(src_bucket = "training-data-construction-zone", dest_bucket = "training-data-construction-zone")
# Out:
# ✅ Augmented data for #image_000001.png created successfully.
# ✅ Augmented data for #image_000002.png created successfully.
# ✅ Augmented data for #image_000003.png created successfully.
# ✅ Augmented data for #image_000004.png created successfully.
# ✅ Augmented data for #image_000005.png created successfully.
# ✅ Augmented data for #image_000006.png created successfully.
# ✅ Augmented data for #image_000007.png created successfully.
# ✅ Augmented data for #image_000008.png created successfully.
# ✅ Augmented data for #image_000009.png created successfully.
# ✅ Augmented data for #image_000010.png created successfully.
# ✅ Augmented data for #image_000011.png created successfully.
# ✅ Augmented data for #image_000012.png created successfully.
# ✅ Augmented data for #image_000013.png created successfully.
# ✅ Augmented data for #image_000014.png created successfully.
# ✅ Augmented data for #image_000015.png created successfully.
# ✅ Augmented data for #image_000016.png created successfully.
# ✅ Augmented data for #image_000017.png created successfully.
# ✅ Augmented data for #image_000018.png created successfully.
# ✅ Augmented data for #image_000019.png created successfully.
# ✅ Augmented data for #image_000020.png created successfully.
# ✅ Augmented data for #image_000021.png created successfully.
# ✅ Augmented data for #image_000022.png created successfully.
# ✅ Augmented data for #image_000023.png created successfully.
# ✅ Augmented data for #image_000024.png created successfully.
# ✅ Augmented data for #image_000025.png created successfully.
# ✅ Augmented data for #image_000026.png created successfully.
# ✅ Augmented data for #image_000027.png created successfully.
# ✅ Augmented data for #image_000028.png created successfully.
# ✅ Augmented data for #image_000029.png created successfully.
# ✅ Augmented data for #image_000030.png created successfully.
# ✅ Augmented data for #image_000031.png created successfully.
# ✅ Augmented data for #image_000032.png created successfully.
# ✅ Augmented data for #image_000033.png created successfully.
# ✅ Augmented data for #image_000034.png created successfully.
# ✅ Augmented data for #image_000035.png created successfully.
# ✅ Augmented data for #image_000036.png created successfully.
# ✅ Augmented data for #image_000037.png created successfully.
# ✅ Augmented data for #image_000038.png created successfully.
# ✅ Augmented data for #image_000039.png created successfully.
# ✅ Augmented data for #image_000040.png created successfully.
# ✅ Augmented data for #image_000041.png created successfully.
# ✅ Augmented data for #image_000042.png created successfully.
# ✅ Augmented data for #image_000043.png created successfully.
# ✅ Augmented data for #image_000044.png created successfully.
# ✅ Augmented data for #image_000045.png created successfully.
# ✅ Augmented data for #image_000046.png created successfully.
# ✅ Augmented data for #image_000047.png created successfully.
# ✅ Augmented data for #image_000048.png created successfully.
# ✅ Augmented data for #image_000049.png created successfully.
# ✅ Augmented data for #image_000050.png created successfully.
# ✅ Augmented data for #image_000051.png created successfully.
# ✅ Augmented data for #image_000052.png created successfully.
# ✅ Augmented data for #image_000053.png created successfully.
# ✅ Augmented data for #image_000054.png created successfully.
# ✅ Augmented data for #image_000055.png created successfully.
# ✅ Augmented data for #image_000056.png created successfully.
# ✅ Augmented data for #image_000057.png created successfully.
# ✅ Augmented data for #image_000058.png created successfully.
# ✅ Augmented data for #image_000059.png created successfully.
# ✅ Augmented data for #image_000060.png created successfully.
# ✅ Augmented data for #image_000061.png created successfully.
# ✅ Augmented data for #image_000062.png created successfully.
# ✅ Augmented data for #image_000063.png created successfully.
# ✅ Augmented data for #image_000064.png created successfully.
# ✅ Augmented data for #image_000065.png created successfully.
# ✅ Augmented data for #image_000066.png created successfully.
# ✅ Augmented data for #image_000067.png created successfully.
# ✅ Augmented data for #image_000068.png created successfully.
# ✅ Augmented data for #image_000069.png created successfully.
# ✅ Augmented data for #image_000070.png created successfully.
# ✅ Augmented data for #image_000071.png created successfully.
# ✅ Augmented data for #image_000072.png created successfully.
# ✅ Augmented data for #image_000073.png created successfully.
# ✅ Augmented data for #image_000074.png created successfully.
# ✅ Augmented data for #image_000075.png created successfully.
# ✅ Augmented data for #image_000076.png created successfully.
# ✅ Augmented data for #image_000077.png created successfully.
# ✅ Augmented data for #image_000078.png created successfully.
# ✅ Augmented data for #image_000079.png created successfully.
# ✅ Augmented data for #image_000080.png created successfully.
# ✅ Augmented data for #image_000081.png created successfully.
# ✅ Augmented data for #image_000082.png created successfully.
# ✅ Augmented data for #image_000083.png created successfully.
# ✅ Augmented data for #image_000084.png created successfully.
# ✅ Augmented data for #image_000085.png created successfully.
# ✅ Augmented data for #image_000086.png created successfully.
# ✅ Augmented data for #image_000087.png created successfully.
# ✅ Augmented data for #image_000088.png created successfully.
# ✅ Augmented data for #image_000089.png created successfully.
# ✅ Augmented data for #image_000090.png created successfully.
# ✅ Augmented data for #image_000091.png created successfully.
# ✅ Augmented data for #image_000092.png created successfully.
# ✅ Augmented data for #image_000093.png created successfully.
# ✅ Augmented data for #image_000094.png created successfully.
# ✅ Augmented data for #image_000095.png created successfully.
# ✅ Augmented data for #image_000096.png created successfully.
# ✅ Augmented data for #image_000097.png created successfully.
# ✅ Augmented data for #image_000098.png created successfully.
# ✅ Augmented data for #image_000099.png created successfully.
# ✅ Augmented data for #image_000100.png created successfully.
# ✅ Augmented data for #image_000101.png created successfully.
# ✅ Augmented data for #image_000102.png created successfully.
# ✅ Augmented data for #image_000103.png created successfully.
# ✅ Augmented data for #image_000104.png created successfully.
# ✅ Augmented data for #image_000105.png created successfully.
# ✅ Augmented data for #image_000106.png created successfully.
# ✅ Augmented data for #image_000107.png created successfully.
# ✅ Augmented data for #image_000108.png created successfully.
# ✅ Augmented data for #image_000109.png created successfully.
# ✅ Augmented data for #image_000110.png created successfully.
# ✅ Augmented data for #image_000111.png created successfully.
# ✅ Augmented data for #image_000112.png created successfully.
# ✅ Augmented data for #image_000113.png created successfully.
# ✅ Augmented data for #image_000114.png created successfully.
# ✅ Augmented data for #image_000115.png created successfully.
# ✅ Augmented data for #image_000116.png created successfully.
# ✅ Augmented data for #image_000117.png created successfully.
# ✅ Augmented data for #image_000118.png created successfully.
# ✅ Augmented data for #image_000119.png created successfully.
# ✅ Augmented data for #image_000120.png created successfully.
# ✅ Augmented data for #image_000121.png created successfully.
# ✅ Augmented data for #image_000122.png created successfully.
# ✅ Augmented data for #image_000123.png created successfully.
# ✅ Augmented data for #image_000124.png created successfully.
# ✅ Augmented data for #image_000125.png created successfully.
# ✅ Augmented data for #image_000126.png created successfully.
# ✅ Augmented data for #image_000127.png created successfully.
# ✅ Augmented data for #image_000128.png created successfully.
# ✅ Augmented data for #image_000129.png created successfully.
# ✅ Augmented data for #image_000130.png created successfully.
# ✅ Augmented data for #image_000131.png created successfully.
# ✅ Augmented data for #image_000132.png created successfully.
# ✅ Augmented data for #image_000133.png created successfully.
# ✅ Augmented data for #image_000134.png created successfully.
# ✅ Augmented data for #image_000135.png created successfully.
# ✅ Augmented data for #image_000136.png created successfully.
# ✅ Augmented data for #image_000137.png created successfully.
# ✅ Augmented data for #image_000138.png created successfully.
# ✅ Augmented data for #image_000139.png created successfully.
# ✅ Augmented data for #image_000140.png created successfully.
# ✅ Augmented data for #image_000141.png created successfully.
# ✅ Augmented data for #image_000142.png created successfully.
# ✅ Augmented data for #image_000143.png created successfully.
# ✅ Augmented data for #image_000144.png created successfully.
# ✅ Augmented data for #image_000145.png created successfully.
# ✅ Augmented data for #image_000146.png created successfully.
# ✅ Augmented data for #image_000147.png created successfully.
# ✅ Augmented data for #image_000148.png created successfully.
# ✅ Augmented data for #image_000149.png created successfully.
# ✅ Augmented data for #image_000150.png created successfully.
# ✅ Augmented data for #image_000151.png created successfully.
# ✅ Augmented data for #image_000152.png created successfully.
# ✅ Augmented data for #image_000153.png created successfully.
# ✅ Augmented data for #image_000154.png created successfully.
# ✅ Augmented data for #image_000155.png created successfully.
# ✅ Augmented data for #image_000156.png created successfully.
# ✅ Augmented data for #image_000157.png created successfully.
# ✅ Augmented data for #image_000158.png created successfully.
# ✅ Augmented data for #image_000159.png created successfully.
# ✅ Augmented data for #image_000160.png created successfully.
# ✅ Augmented data for #image_000161.png created successfully.
# ✅ Augmented data for #image_000162.png created successfully.
# ✅ Augmented data for #image_000163.png created successfully.
# ✅ Augmented data for #image_000164.png created successfully.
# ✅ Augmented data for #image_000165.png created successfully.
# ✅ Augmented data for #image_000166.png created successfully.
# ✅ Augmented data for #image_000167.png created successfully.
# ✅ Augmented data for #image_000168.png created successfully.
# ✅ Augmented data for #image_000169.png created successfully.
# ✅ Augmented data for #image_000170.png created successfully.
# ✅ Augmented data for #image_000171.png created successfully.
# ✅ Augmented data for #image_000172.png created successfully.
# ✅ Augmented data for #image_000173.png created successfully.
# ✅ Augmented data for #image_000174.png created successfully.
# ✅ Augmented data for #image_000175.png created successfully.
# ✅ Augmented data for #image_000176.png created successfully.
# ✅ Augmented data for #image_000177.png created successfully.
# ✅ Augmented data for #image_000178.png created successfully.
# ✅ Augmented data for #image_000179.png created successfully.
# ✅ Augmented data for #image_000180.png created successfully.
# ✅ Augmented data for #image_000181.png created successfully.
# ✅ Augmented data for #image_000182.png created successfully.
# ✅ Augmented data for #image_000183.png created successfully.
# ✅ Augmented data for #image_000184.png created successfully.
# ✅ Augmented data for #image_000185.png created successfully.
# ✅ Augmented data for #image_000186.png created successfully.
# ✅ Augmented data for #image_000187.png created successfully.
# ✅ Augmented data for #image_000188.png created successfully.
# ✅ Augmented data for #image_000189.png created successfully.
# ✅ Augmented data for #image_000190.png created successfully.
# ✅ Augmented data for #image_000191.png created successfully.
# ✅ Augmented data for #image_000192.png created successfully.
# ✅ Augmented data for #image_000193.png created successfully.
# ✅ Augmented data for #image_000194.png created successfully.
# ✅ Augmented data for #image_000195.png created successfully.
# ✅ Augmented data for #image_000196.png created successfully.
# ✅ Augmented data for #image_000197.png created successfully.
# ✅ Augmented data for #image_000198.png created successfully.
# ✅ Augmented data for #image_000199.png created successfully.
# ✅ Augmented data for #image_000200.png created successfully.
# ✅ Augmented data for #image_000201.png created successfully.
# ✅ Augmented data for #image_000202.png created successfully.
# ✅ Augmented data for #image_000203.png created successfully.
# ✅ Augmented data for #image_000204.png created successfully.
# ✅ Augmented data for #image_000205.png created successfully.
# ✅ Augmented data for #image_000206.png created successfully.
# ✅ Augmented data for #image_000207.png created successfully.
# ✅ Augmented data for #image_000208.png created successfully.
# ✅ Augmented data for #image_000209.png created successfully.
# ✅ Augmented data for #image_000210.png created successfully.
# ✅ Augmented data for #image_000211.png created successfully.
# ✅ Augmented data for #image_000212.png created successfully.
# ✅ Augmented data for #image_000213.png created successfully.
# ✅ Augmented data for #image_000214.png created successfully.
# ✅ Augmented data for #image_000215.png created successfully.
# ✅ Augmented data for #image_000216.png created successfully.
# ✅ Augmented data for #image_000217.png created successfully.
# ✅ Augmented data for #image_000218.png created successfully.
# ✅ Augmented data for #image_000219.png created successfully.
# ✅ Augmented data for #image_000220.png created successfully.
# ✅ Augmented data for #image_000221.png created successfully.
# ✅ Augmented data for #image_000222.png created successfully.
# ✅ Augmented data for #image_000223.png created successfully.
# ✅ Augmented data for #image_000224.png created successfully.
# ✅ Augmented data for #image_000225.png created successfully.
# ✅ Augmented data for #image_000226.png created successfully.
# ✅ Augmented data for #image_000227.png created successfully.
# ✅ Augmented data for #image_000228.png created successfully.
# ✅ Augmented data for #image_000229.png created successfully.
# ✅ Augmented data for #image_000230.png created successfully.
# ✅ Augmented data for #image_000231.png created successfully.
# ✅ Augmented data for #image_000232.png created successfully.
# ✅ Augmented data for #image_000233.png created successfully.
# ✅ Augmented data for #image_000234.png created successfully.
# ✅ Augmented data for #image_000235.png created successfully.
# ✅ Augmented data for #image_000236.png created successfully.
# ✅ Augmented data for #image_000237.png created successfully.
# ✅ Augmented data for #image_000238.png created successfully.
# ✅ Augmented data for #image_000239.png created successfully.
# ✅ Augmented data for #image_000240.png created successfully.
# ✅ Augmented data for #image_000241.png created successfully.
# ✅ Augmented data for #image_000242.png created successfully.
# ✅ Augmented data for #image_000243.png created successfully.
# ✅ Augmented data for #image_000244.png created successfully.
# ✅ Augmented data for #image_000245.png created successfully.
# ✅ Augmented data for #image_000246.png created successfully.
# ✅ Augmented data for #image_000247.png created successfully.
# ✅ Augmented data for #image_000248.png created successfully.
# ✅ Augmented data for #image_000249.png created successfully.
# ✅ Augmented data for #image_000250.png created successfully.
# ✅ Augmented data for #image_000251.png created successfully.
# ✅ Augmented data for #image_000252.png created successfully.
# ✅ Augmented data for #image_000253.png created successfully.
# ✅ Augmented data for #image_000254.png created successfully.
# ✅ Augmented data for #image_000255.png created successfully.
# ✅ Augmented data for #image_000256.png created successfully.
# ✅ Augmented data for #image_000257.png created successfully.
# ✅ Augmented data for #image_000258.png created successfully.
# ✅ Augmented data for #image_000259.png created successfully.
# ✅ Augmented data for #image_000260.png created successfully.
# ✅ Augmented data for #image_000261.png created successfully.
# ✅ Augmented data for #image_000262.png created successfully.
# ✅ Augmented data for #image_000263.png created successfully.
# ✅ Augmented data for #image_000264.png created successfully.
# ✅ Augmented data for #image_000265.png created successfully.
# ✅ Augmented data for #image_000266.png created successfully.
# ✅ Augmented data for #image_000267.png created successfully.
# ✅ Augmented data for #image_000268.png created successfully.
# ✅ Augmented data for #image_000269.png created successfully.
# ✅ Augmented data for #image_000270.png created successfully.
# ✅ Augmented data for #image_000271.png created successfully.
# ✅ Augmented data for #image_000272.png created successfully.
# ✅ Augmented data for #image_000273.png created successfully.
# ✅ Augmented data for #image_000274.png created successfully.
# ✅ Augmented data for #image_000275.png created successfully.
# ✅ Augmented data for #image_000276.png created successfully.
# ✅ Augmented data for #image_000277.png created successfully.
# ✅ Augmented data for #image_000278.png created successfully.
# ✅ Augmented data for #image_000279.png created successfully.
# ✅ Augmented data for #image_000280.png created successfully.
# ✅ Augmented data for #image_000281.png created successfully.
# ✅ Augmented data for #image_000282.png created successfully.
# ✅ Augmented data for #image_000283.png created successfully.
# ✅ Augmented data for #image_000284.png created successfully.
# ✅ Augmented data for #image_000285.png created successfully.
# ✅ Augmented data for #image_000286.png created successfully.
# ✅ Augmented data for #image_000287.png created successfully.
# ✅ Augmented data for #image_000288.png created successfully.
# ✅ Augmented data for #image_000289.png created successfully.
# ✅ Augmented data for #image_000290.png created successfully.
# ✅ Augmented data for #image_000291.png created successfully.
# ✅ Augmented data for #image_000292.png created successfully.
# ✅ Augmented data for #image_000293.png created successfully.
# ✅ Augmented data for #image_000294.png created successfully.
# ✅ Augmented data for #image_000295.png created successfully.
# ✅ Augmented data for #image_000296.png created successfully.
# ✅ Augmented data for #image_000297.png created successfully.
# ✅ Augmented data for #image_000298.png created successfully.
# ✅ Augmented data for #image_000299.png created successfully.
# ✅ Augmented data for #image_000300.png created successfully.
# ✅ Augmented data for #image_000301.png created successfully.
# ✅ Augmented data for #image_000302.png created successfully.
# ✅ Augmented data for #image_000303.png created successfully.
# ✅ Augmented data for #image_000304.png created successfully.
# ✅ Augmented data for #image_000305.png created successfully.
# ✅ Augmented data for #image_000306.png created successfully.
# ✅ Augmented data for #image_000307.png created successfully.
# ✅ Augmented data for #image_000308.png created successfully.
# ✅ Augmented data for #image_000309.png created successfully.
# ✅ Augmented data for #image_000310.png created successfully.
# ✅ Augmented data for #image_000311.png created successfully.
# ✅ Augmented data for #image_000312.png created successfully.
# ✅ Augmented data for #image_000313.png created successfully.
# ✅ Augmented data for #image_000314.png created successfully.
# ✅ Augmented data for #image_000315.png created successfully.
# ✅ Augmented data for #image_000316.png created successfully.
# ✅ Augmented data for #image_000317.png created successfully.
# ✅ Augmented data for #image_000318.png created successfully.
# ✅ Augmented data for #image_000319.png created successfully.
# ✅ Augmented data for #image_000320.png created successfully.
# ✅ Augmented data for #image_000321.png created successfully.
# ✅ Augmented data for #image_000322.png created successfully.
# ✅ Augmented data for #image_000323.png created successfully.
# ✅ Augmented data for #image_000324.png created successfully.
# ✅ Augmented data for #image_000325.png created successfully.
# ✅ Augmented data for #image_000326.png created successfully.
# ✅ Augmented data for #image_000327.png created successfully.
# ✅ Augmented data for #image_000328.png created successfully.
# ✅ Augmented data for #image_000329.png created successfully.
# ✅ Augmented data for #image_000330.png created successfully.
# ✅ Augmented data for #image_000331.png created successfully.
# ✅ Augmented data for #image_000332.png created successfully.
# ✅ Augmented data for #image_000333.png created successfully.
# ✅ Augmented data for #image_000334.png created successfully.
# ✅ Augmented data for #image_000335.png created successfully.
# ✅ Augmented data for #image_000336.png created successfully.
# ✅ Augmented data for #image_000337.png created successfully.
# ✅ Augmented data for #image_000338.png created successfully.
# ✅ Augmented data for #image_000339.png created successfully.
# ✅ Augmented data for #image_000340.png created successfully.
# ✅ Augmented data for #image_000341.png created successfully.
# ✅ Augmented data for #image_000342.png created successfully.
# ✅ Augmented data for #image_000343.png created successfully.
# ✅ Augmented data for #image_000344.png created successfully.
# ✅ Augmented data for #image_000345.png created successfully.
# ✅ Augmented data for #image_000346.png created successfully.
# ✅ Augmented data for #image_000347.png created successfully.
# ✅ Augmented data for #image_000348.png created successfully.
# ✅ Augmented data for #image_000349.png created successfully.
# ✅ Augmented data for #image_000350.png created successfully.
# ✅ Augmented data for #image_000351.png created successfully.
# ✅ Augmented data for #image_000352.png created successfully.
# ✅ Augmented data for #image_000353.png created successfully.
# ✅ Augmented data for #image_000354.png created successfully.
# ✅ Augmented data for #image_000355.png created successfully.
# ✅ Augmented data for #image_000356.png created successfully.
# ✅ Augmented data for #image_000357.png created successfully.
# ✅ Augmented data for #image_000358.png created successfully.
# ✅ Augmented data for #image_000359.png created successfully.
# ✅ Augmented data for #image_000360.png created successfully.
# ✅ Augmented data for #image_000361.png created successfully.
# ✅ Augmented data for #image_000362.png created successfully.
# ✅ Augmented data for #image_000363.png created successfully.
# ✅ Augmented data for #image_000364.png created successfully.
# ✅ Augmented data for #image_000365.png created successfully.
# ✅ Augmented data for #image_000366.png created successfully.
# ✅ Augmented data for #image_000367.png created successfully.
# ✅ Augmented data for #image_000368.png created successfully.
# ✅ Augmented data for #image_000369.png created successfully.
# ✅ Augmented data for #image_000370.png created successfully.
# ✅ Augmented data for #image_000371.png created successfully.
# ✅ Augmented data for #image_000372.png created successfully.
# ✅ Augmented data for #image_000373.png created successfully.
# ✅ Augmented data for #image_000374.png created successfully.
# ✅ Augmented data for #image_000375.png created successfully.
# ✅ Augmented data for #image_000376.png created successfully.
# ✅ Augmented data for #image_000377.png created successfully.
# ✅ Augmented data for #image_000378.png created successfully.
# ✅ Augmented data for #image_000379.png created successfully.
# ✅ Augmented data for #image_000380.png created successfully.
# ✅ Augmented data for #image_000381.png created successfully.
# ✅ Augmented data for #image_000382.png created successfully.
# ✅ Augmented data for #image_000383.png created successfully.
# ✅ Augmented data for #image_000384.png created successfully.
# ✅ Augmented data for #image_000385.png created successfully.
# ✅ Augmented data for #image_000386.png created successfully.
# ✅ Augmented data for #image_000387.png created successfully.
# ✅ Augmented data for #image_000388.png created successfully.
# ✅ Augmented data for #image_000389.png created successfully.
# ✅ Augmented data for #image_000390.png created successfully.
# ✅ Augmented data for #image_000391.png created successfully.
# ✅ Augmented data for #image_000392.png created successfully.
# ✅ Augmented data for #image_000393.png created successfully.
# ✅ Augmented data for #image_000394.png created successfully.
# ✅ Augmented data for #image_000395.png created successfully.
# ✅ Augmented data for #image_000396.png created successfully.
# ✅ Augmented data for #image_000397.png created successfully.
# ✅ Augmented data for #image_000398.png created successfully.
# ✅ Augmented data for #image_000399.png created successfully.
# ✅ Augmented data for #image_000400.png created successfully.
# ✅ Augmented data for #image_000401.png created successfully.
# ✅ Augmented data for #image_000402.png created successfully.
# ✅ Augmented data for #image_000403.png created successfully.
# ✅ Augmented data for #image_000404.png created successfully.
# ✅ Augmented data for #image_000405.png created successfully.
# ✅ Augmented data for #image_000406.png created successfully.
# ✅ Augmented data for #image_000407.png created successfully.
# ✅ Augmented data for #image_000408.png created successfully.
# ✅ Augmented data for #image_000409.png created successfully.
# ✅ Augmented data for #image_000410.png created successfully.
# ✅ Augmented data for #image_000411.png created successfully.
# ✅ Augmented data for #image_000412.png created successfully.
# ✅ Augmented data for #image_000413.png created successfully.
# ✅ Augmented data for #image_000414.png created successfully.
# ✅ Augmented data for #image_000415.png created successfully.
# ✅ Augmented data for #image_000416.png created successfully.
# ✅ Augmented data for #image_000417.png created successfully.
# ✅ Augmented data for #image_000418.png created successfully.
# ✅ Augmented data for #image_000419.png created successfully.
# ✅ Augmented data for #image_000420.png created successfully.
# ✅ Augmented data for #image_000421.png created successfully.
# ✅ Augmented data for #image_000422.png created successfully.
# ✅ Augmented data for #image_000423.png created successfully.
# ✅ Augmented data for #image_000424.png created successfully.
# ✅ Augmented data for #image_000425.png created successfully.
# ✅ Augmented data for #image_000426.png created successfully.
# ✅ Augmented data for #image_000427.png created successfully.
# ✅ Augmented data for #image_000428.png created successfully.
# ✅ Augmented data for #image_000429.png created successfully.
# ✅ Augmented data for #image_000430.png created successfully.
# ✅ Augmented data for #image_000431.png created successfully.
# ✅ Augmented data for #image_000432.png created successfully.
# ✅ Augmented data for #image_000433.png created successfully.
# ✅ Augmented data for #image_000434.png created successfully.
# ✅ Augmented data for #image_000435.png created successfully.
# ✅ Augmented data for #image_000436.png created successfully.
# ✅ Augmented data for #image_000437.png created successfully.
# ✅ Augmented data for #image_000438.png created successfully.
# ✅ Augmented data for #image_000439.png created successfully.
# ✅ Augmented data for #image_000440.png created successfully.
# ✅ Augmented data for #image_000441.png created successfully.
# ✅ Augmented data for #image_000442.png created successfully.
# ✅ Augmented data for #image_000443.png created successfully.
# ✅ Augmented data for #image_000444.png created successfully.
# ✅ Augmented data for #image_000445.png created successfully.
# ✅ Augmented data for #image_000446.png created successfully.
# ✅ Augmented data for #image_000447.png created successfully.
# ✅ Augmented data for #image_000448.png created successfully.
# ✅ Augmented data for #image_000449.png created successfully.
# ✅ Augmented data for #image_000450.png created successfully.
# ✅ Augmented data for #image_000451.png created successfully.
# ✅ Augmented data for #image_000452.png created successfully.
# ✅ Augmented data for #image_000453.png created successfully.
# ✅ Augmented data for #image_000454.png created successfully.
# ✅ Augmented data for #image_000455.png created successfully.
# ✅ Augmented data for #image_000456.png created successfully.
# ✅ Augmented data for #image_000457.png created successfully.
# ✅ Augmented data for #image_000458.png created successfully.
# ✅ Augmented data for #image_000459.png created successfully.
# ✅ Augmented data for #image_000460.png created successfully.
# ✅ Augmented data for #image_000461.png created successfully.
# ✅ Augmented data for #image_000462.png created successfully.
# ✅ Augmented data for #image_000463.png created successfully.
# ✅ Augmented data for #image_000464.png created successfully.
# ✅ Augmented data for #image_000465.png created successfully.
# ✅ Augmented data for #image_000466.png created successfully.
# ✅ Augmented data for #image_000467.png created successfully.
# ✅ Augmented data for #image_000468.png created successfully.
# ✅ Augmented data for #image_000469.png created successfully.
# ✅ Augmented data for #image_000470.png created successfully.
# ✅ Augmented data for #image_000471.png created successfully.
# ✅ Augmented data for #image_000472.png created successfully.
# ✅ Augmented data for #image_000473.png created successfully.
# ✅ Augmented data for #image_000474.png created successfully.
# ✅ Augmented data for #image_000475.png created successfully.
# ✅ Augmented data for #image_000476.png created successfully.
# ✅ Augmented data for #image_000477.png created successfully.
# ✅ Augmented data for #image_000478.png created successfully.
# ✅ Augmented data for #image_000479.png created successfully.
# ✅ Augmented data for #image_000480.png created successfully.
# ✅ Augmented data for #image_000481.png created successfully.
# ✅ Augmented data for #image_000482.png created successfully.
# ✅ Augmented data for #image_000483.png created successfully.
# ✅ Augmented data for #image_000484.png created successfully.
# ✅ Augmented data for #image_000485.png created successfully.
# ✅ Augmented data for #image_000486.png created successfully.
# ✅ Augmented data for #image_000487.png created successfully.
# ✅ Augmented data for #image_000488.png created successfully.
# ✅ Augmented data for #image_000489.png created successfully.
# ✅ Augmented data for #image_000490.png created successfully.
# ✅ Augmented data for #image_000491.png created successfully.
# ✅ Augmented data for #image_000492.png created successfully.
# ✅ Augmented data for #image_000493.png created successfully.
# ✅ Augmented data for #image_000494.png created successfully.
# ✅ Augmented data for #image_000495.png created successfully.
# ✅ Augmented data for #text_000001.txt created successfully.
# ✅ Augmented data for #text_000002.txt created successfully.
# ✅ Augmented data for #text_000003.txt created successfully.
# ✅ Augmented data for #text_000004.txt created successfully.
# ✅ Augmented data for #text_000005.txt created successfully.
# ✅ Augmented data for #text_000006.txt created successfully.
# ✅ Augmented data for #text_000007.txt created successfully.
# ✅ Augmented data for #text_000008.txt created successfully.
# ✅ Augmented data for #text_000009.txt created successfully.
# ✅ Augmented data for #text_000010.txt created successfully.
# ✅ Augmented data for #text_000011.txt created successfully.
# ✅ Augmented data for #text_000012.txt created successfully.
# ✅ Augmented data for #text_000013.txt created successfully.
# ✅ Augmented data for #text_000014.txt created successfully.
# ✅ Augmented data for #text_000015.txt created successfully.
# ✅ Augmented data for #text_000016.txt created successfully.
# ✅ Augmented data for #text_000017.txt created successfully.
# ✅ Augmented data for #text_000018.txt created successfully.
# ✅ Augmented data for #text_000019.txt created successfully.
# ✅ Augmented data for #text_000020.txt created successfully.
# ✅ Augmented data for #text_000021.txt created successfully.
# ✅ Augmented data for #text_000022.txt created successfully.
# ✅ Augmented data for #text_000023.txt created successfully.
# ✅ Augmented data for #text_000024.txt created successfully.
# ✅ Augmented data for #text_000025.txt created successfully.
# ✅ Augmented data for #text_000026.txt created successfully.
# ✅ Augmented data for #text_000027.txt created successfully.
# ✅ Augmented data for #text_000028.txt created successfully.
# ✅ Augmented data for #text_000029.txt created successfully.
# ✅ Augmented data for #text_000030.txt created successfully.
# ✅ Augmented data for #text_000031.txt created successfully.
# ✅ Augmented data for #text_000032.txt created successfully.
# ✅ Augmented data for #text_000033.txt created successfully.
# ✅ Augmented data for #text_000034.txt created successfully.
# ✅ Augmented data for #text_000035.txt created successfully.
# ✅ Augmented data for #text_000036.txt created successfully.
# ✅ Augmented data for #text_000037.txt created successfully.
# ✅ Augmented data for #text_000038.txt created successfully.
# ✅ Augmented data for #text_000039.txt created successfully.
# ✅ Augmented data for #text_000040.txt created successfully.
# ✅ Augmented data for #text_000041.txt created successfully.
# ✅ Augmented data for #text_000042.txt created successfully.
# ✅ Augmented data for #text_000043.txt created successfully.
# ✅ Augmented data for #text_000044.txt created successfully.
# ✅ Augmented data for #text_000045.txt created successfully.
# ✅ Augmented data for #text_000046.txt created successfully.
# ✅ Augmented data for #text_000047.txt created successfully.
# ✅ Augmented data for #text_000048.txt created successfully.
# ✅ Augmented data for #text_000049.txt created successfully.
# ✅ Augmented data for #text_000050.txt created successfully.
# ✅ Augmented data for #text_000051.txt created successfully.
# ✅ Augmented data for #text_000052.txt created successfully.
# ✅ Augmented data for #text_000053.txt created successfully.
# ✅ Augmented data for #text_000054.txt created successfully.
# ✅ Augmented data for #text_000055.txt created successfully.
# ✅ Augmented data for #text_000056.txt created successfully.
# ✅ Augmented data for #text_000057.txt created successfully.
# ✅ Augmented data for #text_000058.txt created successfully.
# ✅ Augmented data for #text_000059.txt created successfully.
# ✅ Augmented data for #text_000060.txt created successfully.
# ✅ Augmented data for #text_000061.txt created successfully.
# ✅ Augmented data for #text_000062.txt created successfully.
# ✅ Augmented data for #text_000063.txt created successfully.
# ✅ Augmented data for #text_000064.txt created successfully.
# ✅ Augmented data for #text_000065.txt created successfully.
# ✅ Augmented data for #text_000066.txt created successfully.
# ✅ Augmented data for #text_000067.txt created successfully.
# ✅ Augmented data for #text_000068.txt created successfully.
# ✅ Augmented data for #text_000069.txt created successfully.
# ✅ Augmented data for #text_000070.txt created successfully.
# ✅ Augmented data for #text_000071.txt created successfully.
# ✅ Augmented data for #text_000072.txt created successfully.
# ✅ Augmented data for #text_000073.txt created successfully.
# ✅ Augmented data for #text_000074.txt created successfully.
# ✅ Augmented data for #text_000075.txt created successfully.
# ✅ Augmented data for #text_000076.txt created successfully.
# ✅ Augmented data for #text_000077.txt created successfully.
# ✅ Augmented data for #text_000078.txt created successfully.
# ✅ Augmented data for #text_000079.txt created successfully.
# ✅ Augmented data for #text_000080.txt created successfully.
# ✅ Augmented data for #text_000081.txt created successfully.
# ✅ Augmented data for #text_000082.txt created successfully.
# ✅ Augmented data for #text_000083.txt created successfully.
# ✅ Augmented data for #text_000084.txt created successfully.
# ✅ Augmented data for #text_000085.txt created successfully.
# ✅ Augmented data for #text_000086.txt created successfully.
# ✅ Augmented data for #text_000087.txt created successfully.
# ✅ Augmented data for #text_000088.txt created successfully.
# ✅ Augmented data for #text_000089.txt created successfully.
# ✅ Augmented data for #text_000090.txt created successfully.
# ✅ Augmented data for #text_000091.txt created successfully.
# ✅ Augmented data for #text_000092.txt created successfully.
# ✅ Augmented data for #text_000093.txt created successfully.
# ✅ Augmented data for #text_000094.txt created successfully.
# ✅ Augmented data for #text_000095.txt created successfully.
# ✅ Augmented data for #text_000096.txt created successfully.
# ✅ Augmented data for #text_000097.txt created successfully.
# ✅ Augmented data for #text_000098.txt created successfully.
# ✅ Augmented data for #text_000099.txt created successfully.
# ✅ Augmented data for #text_000100.txt created successfully.
# ✅ Augmented data for #text_000101.txt created successfully.
# ✅ Augmented data for #text_000102.txt created successfully.
# ✅ Augmented data for #text_000103.txt created successfully.
# ✅ Augmented data for #text_000104.txt created successfully.
# ✅ Augmented data for #text_000105.txt created successfully.
# ✅ Augmented data for #text_000106.txt created successfully.
# ✅ Augmented data for #text_000107.txt created successfully.
# ✅ Augmented data for #text_000108.txt created successfully.
# ✅ Augmented data for #text_000109.txt created successfully.
# ✅ Augmented data for #text_000110.txt created successfully.
# ✅ Augmented data for #text_000111.txt created successfully.
# ✅ Augmented data for #text_000112.txt created successfully.
# ✅ Augmented data for #text_000113.txt created successfully.
# ✅ Augmented data for #text_000114.txt created successfully.
# ✅ Augmented data for #text_000115.txt created successfully.
# ✅ Augmented data for #text_000116.txt created successfully.
# ✅ Augmented data for #text_000117.txt created successfully.
# ✅ Augmented data for #text_000118.txt created successfully.
# ✅ Augmented data for #text_000119.txt created successfully.
# ✅ Augmented data for #text_000120.txt created successfully.
# ✅ Augmented data for #text_000121.txt created successfully.
# ✅ Augmented data for #text_000122.txt created successfully.
# ✅ Augmented data for #text_000123.txt created successfully.
# ✅ Augmented data for #text_000124.txt created successfully.
# ✅ Augmented data for #text_000125.txt created successfully.
# ✅ Augmented data for #text_000126.txt created successfully.
# ✅ Augmented data for #text_000127.txt created successfully.
# ✅ Augmented data for #text_000128.txt created successfully.
# ✅ Augmented data for #text_000129.txt created successfully.
# ✅ Augmented data for #text_000130.txt created successfully.
# ✅ Augmented data for #text_000131.txt created successfully.
# ✅ Augmented data for #text_000132.txt created successfully.
# ✅ Augmented data for #text_000133.txt created successfully.
# ✅ Augmented data for #text_000134.txt created successfully.
# ✅ Augmented data for #text_000135.txt created successfully.
# ✅ Augmented data for #text_000136.txt created successfully.
# ✅ Augmented data for #text_000137.txt created successfully.
# ✅ Augmented data for #text_000138.txt created successfully.
# ✅ Augmented data for #text_000139.txt created successfully.
# ✅ Augmented data for #text_000140.txt created successfully.
# ✅ Augmented data for #text_000141.txt created successfully.
# ✅ Augmented data for #text_000142.txt created successfully.
# ✅ Augmented data for #text_000143.txt created successfully.
# ✅ Augmented data for #text_000144.txt created successfully.
# ✅ Augmented data for #text_000145.txt created successfully.
# ✅ Augmented data for #text_000146.txt created successfully.
# ✅ Augmented data for #text_000147.txt created successfully.
# ✅ Augmented data for #text_000148.txt created successfully.
# ✅ Augmented data for #text_000149.txt created successfully.
# ✅ Augmented data for #text_000150.txt created successfully.
# ✅ Augmented data for #text_000151.txt created successfully.
# ✅ Augmented data for #text_000152.txt created successfully.
# ✅ Augmented data for #text_000153.txt created successfully.
# ✅ Augmented data for #text_000154.txt created successfully.
# ✅ Augmented data for #text_000155.txt created successfully.
# ✅ Augmented data for #text_000156.txt created successfully.
# ✅ Augmented data for #text_000157.txt created successfully.
# ✅ Augmented data for #text_000158.txt created successfully.
# ✅ Augmented data for #text_000159.txt created successfully.
# ✅ Augmented data for #text_000160.txt created successfully.
# ✅ Augmented data for #text_000161.txt created successfully.
# ✅ Augmented data for #text_000162.txt created successfully.
# ✅ Augmented data for #text_000163.txt created successfully.
# ✅ Augmented data for #text_000164.txt created successfully.
# ✅ Augmented data for #text_000165.txt created successfully.
# ✅ Augmented data for #text_000166.txt created successfully.
# ✅ Augmented data for #text_000167.txt created successfully.
# ✅ Augmented data for #text_000168.txt created successfully.
# ✅ Augmented data for #text_000169.txt created successfully.
# ✅ Augmented data for #text_000170.txt created successfully.
# ✅ Augmented data for #text_000171.txt created successfully.
# ✅ Augmented data for #text_000172.txt created successfully.
# ✅ Augmented data for #text_000173.txt created successfully.
# ✅ Augmented data for #text_000174.txt created successfully.
# ✅ Augmented data for #text_000175.txt created successfully.
# ✅ Augmented data for #text_000176.txt created successfully.
# ✅ Augmented data for #text_000177.txt created successfully.
# ✅ Augmented data for #text_000178.txt created successfully.
# ✅ Augmented data for #text_000179.txt created successfully.
# ✅ Augmented data for #text_000180.txt created successfully.
# ✅ Augmented data for #text_000181.txt created successfully.
# ✅ Augmented data for #text_000182.txt created successfully.
# ✅ Augmented data for #text_000183.txt created successfully.
# ✅ Augmented data for #text_000184.txt created successfully.
# ✅ Augmented data for #text_000185.txt created successfully.
# ✅ Augmented data for #text_000186.txt created successfully.
# ✅ Augmented data for #text_000187.txt created successfully.
# ✅ Augmented data for #text_000188.txt created successfully.
# ✅ Augmented data for #text_000189.txt created successfully.
# ✅ Augmented data for #text_000190.txt created successfully.
# ✅ Augmented data for #text_000191.txt created successfully.
# ✅ Augmented data for #text_000192.txt created successfully.
# ✅ Augmented data for #text_000193.txt created successfully.
# ✅ Augmented data for #text_000194.txt created successfully.
# ✅ Augmented data for #text_000195.txt created successfully.
# ✅ Augmented data for #text_000196.txt created successfully.
# ✅ Augmented data for #text_000197.txt created successfully.
# ✅ Augmented data for #text_000198.txt created successfully.
# ✅ Augmented data for #text_000199.txt created successfully.
# ✅ Augmented data for #text_000200.txt created successfully.
# ✅ Augmented data for #text_000201.txt created successfully.
# ✅ Augmented data for #text_000202.txt created successfully.
# ✅ Augmented data for #text_000203.txt created successfully.
# ✅ Augmented data for #text_000204.txt created successfully.
# ✅ Augmented data for #text_000205.txt created successfully.
# ✅ Augmented data for #text_000206.txt created successfully.
# ✅ Augmented data for #text_000207.txt created successfully.
# ✅ Augmented data for #text_000208.txt created successfully.
# ✅ Augmented data for #text_000209.txt created successfully.
# ✅ Augmented data for #text_000210.txt created successfully.
# ✅ Augmented data for #text_000211.txt created successfully.
# ✅ Augmented data for #text_000212.txt created successfully.
# ✅ Augmented data for #text_000213.txt created successfully.
# ✅ Augmented data for #text_000214.txt created successfully.
# ✅ Augmented data for #text_000215.txt created successfully.
# ✅ Augmented data for #text_000216.txt created successfully.
# ✅ Augmented data for #text_000217.txt created successfully.
# ✅ Augmented data for #text_000218.txt created successfully.
# ✅ Augmented data for #text_000219.txt created successfully.
# ✅ Augmented data for #text_000220.txt created successfully.
# ✅ Augmented data for #text_000221.txt created successfully.
# ✅ Augmented data for #text_000222.txt created successfully.
# ✅ Augmented data for #text_000223.txt created successfully.
# ✅ Augmented data for #text_000224.txt created successfully.
# ✅ Augmented data for #text_000225.txt created successfully.
# ✅ Augmented data for #text_000226.txt created successfully.
# ✅ Augmented data for #text_000227.txt created successfully.
# ✅ Augmented data for #text_000228.txt created successfully.
# ✅ Augmented data for #text_000229.txt created successfully.
# ✅ Augmented data for #text_000230.txt created successfully.
# ✅ Augmented data for #text_000231.txt created successfully.
# ✅ Augmented data for #text_000232.txt created successfully.
# ✅ Augmented data for #text_000233.txt created successfully.
# ✅ Augmented data for #text_000234.txt created successfully.
# ✅ Augmented data for #text_000235.txt created successfully.
# ✅ Augmented data for #text_000236.txt created successfully.
# ✅ Augmented data for #text_000237.txt created successfully.
# ✅ Augmented data for #text_000238.txt created successfully.
# ✅ Augmented data for #text_000239.txt created successfully.
# ✅ Augmented data for #text_000240.txt created successfully.
# ✅ Augmented data for #text_000241.txt created successfully.
# ✅ Augmented data for #text_000242.txt created successfully.
# ✅ Augmented data for #text_000243.txt created successfully.
# ✅ Augmented data for #text_000244.txt created successfully.
# ✅ Augmented data for #text_000245.txt created successfully.
# ✅ Augmented data for #text_000246.txt created successfully.
# ✅ Augmented data for #text_000247.txt created successfully.
# ✅ Augmented data for #text_000248.txt created successfully.
# ✅ Augmented data for #text_000249.txt created successfully.
# ✅ Augmented data for #text_000250.txt created successfully.
# ✅ Augmented data for #text_000251.txt created successfully.
# ✅ Augmented data for #text_000252.txt created successfully.
# ✅ Augmented data for #text_000253.txt created successfully.
# ✅ Augmented data for #text_000254.txt created successfully.
# ✅ Augmented data for #text_000255.txt created successfully.
# ✅ Augmented data for #text_000256.txt created successfully.
# ✅ Augmented data for #text_000257.txt created successfully.
# ✅ Augmented data for #text_000258.txt created successfully.
# ✅ Augmented data for #text_000259.txt created successfully.
# ✅ Augmented data for #text_000260.txt created successfully.
# ✅ Augmented data for #text_000261.txt created successfully.
# ✅ Augmented data for #text_000262.txt created successfully.
# ✅ Augmented data for #text_000263.txt created successfully.
# ✅ Augmented data for #text_000264.txt created successfully.
# ✅ Augmented data for #text_000265.txt created successfully.
# ✅ Augmented data for #text_000266.txt created successfully.
# ✅ Augmented data for #text_000267.txt created successfully.
# ✅ Augmented data for #text_000268.txt created successfully.
# ✅ Augmented data for #text_000269.txt created successfully.
# ✅ Augmented data for #text_000270.txt created successfully.
# ✅ Augmented data for #text_000271.txt created successfully.
# ✅ Augmented data for #text_000272.txt created successfully.
# ✅ Augmented data for #text_000273.txt created successfully.
# ✅ Augmented data for #text_000274.txt created successfully.
# ✅ Augmented data for #text_000275.txt created successfully.
# ✅ Augmented data for #text_000276.txt created successfully.
# ✅ Augmented data for #text_000277.txt created successfully.
# ✅ Augmented data for #text_000278.txt created successfully.
# ✅ Augmented data for #text_000279.txt created successfully.
# ✅ Augmented data for #text_000280.txt created successfully.
# ✅ Augmented data for #text_000281.txt created successfully.
# ✅ Augmented data for #text_000282.txt created successfully.
# ✅ Augmented data for #text_000283.txt created successfully.
# ✅ Augmented data for #text_000284.txt created successfully.
# ✅ Augmented data for #text_000285.txt created successfully.
# ✅ Augmented data for #text_000286.txt created successfully.
# ✅ Augmented data for #text_000287.txt created successfully.
# ✅ Augmented data for #text_000288.txt created successfully.
# ✅ Augmented data for #text_000289.txt created successfully.
# ✅ Augmented data for #text_000290.txt created successfully.
# ✅ Augmented data for #text_000291.txt created successfully.
# ✅ Augmented data for #text_000292.txt created successfully.
# ✅ Augmented data for #text_000293.txt created successfully.
# ✅ Augmented data for #text_000294.txt created successfully.
# ✅ Augmented data for #text_000295.txt created successfully.
# ✅ Augmented data for #text_000296.txt created successfully.
# ✅ Augmented data for #text_000297.txt created successfully.
# ✅ Augmented data for #text_000298.txt created successfully.
# ✅ Augmented data for #text_000299.txt created successfully.
# ✅ Augmented data for #text_000300.txt created successfully.
# ✅ Augmented data for #text_000301.txt created successfully.
# ✅ Augmented data for #text_000302.txt created successfully.
# ✅ Augmented data for #text_000303.txt created successfully.
# ✅ Augmented data for #text_000304.txt created successfully.
# ✅ Augmented data for #text_000305.txt created successfully.
# ✅ Augmented data for #text_000306.txt created successfully.
# ✅ Augmented data for #text_000307.txt created successfully.
# ✅ Augmented data for #text_000308.txt created successfully.
# ✅ Augmented data for #text_000309.txt created successfully.
# ✅ Augmented data for #text_000310.txt created successfully.
# ✅ Augmented data for #text_000311.txt created successfully.
# ✅ Augmented data for #text_000312.txt created successfully.
# ✅ Augmented data for #text_000313.txt created successfully.
# ✅ Augmented data for #text_000314.txt created successfully.
# ✅ Augmented data for #text_000315.txt created successfully.
# ✅ Augmented data for #text_000316.txt created successfully.
# ✅ Augmented data for #text_000317.txt created successfully.
# ✅ Augmented data for #text_000318.txt created successfully.
# ✅ Augmented data for #text_000319.txt created successfully.
# ✅ Augmented data for #text_000320.txt created successfully.
# ✅ Augmented data for #text_000321.txt created successfully.
# ✅ Augmented data for #text_000322.txt created successfully.
# ✅ Augmented data for #text_000323.txt created successfully.
# ✅ Augmented data for #text_000324.txt created successfully.
# ✅ Augmented data for #text_000325.txt created successfully.
# ✅ Augmented data for #text_000326.txt created successfully.
# ✅ Augmented data for #text_000327.txt created successfully.
# ✅ Augmented data for #text_000328.txt created successfully.
# ✅ Augmented data for #text_000329.txt created successfully.
# ✅ Augmented data for #text_000330.txt created successfully.
# ✅ Augmented data for #text_000331.txt created successfully.
# ✅ Augmented data for #text_000332.txt created successfully.
# ✅ Augmented data for #text_000333.txt created successfully.
# ✅ Augmented data for #text_000334.txt created successfully.
# ✅ Augmented data for #text_000335.txt created successfully.
# ✅ Augmented data for #text_000336.txt created successfully.
# ✅ Augmented data for #text_000337.txt created successfully.
# ✅ Augmented data for #text_000338.txt created successfully.
# ✅ Augmented data for #text_000339.txt created successfully.
# ✅ Augmented data for #text_000340.txt created successfully.
# ✅ Augmented data for #text_000341.txt created successfully.
# ✅ Augmented data for #text_000342.txt created successfully.
# ✅ Augmented data for #text_000343.txt created successfully.
# ✅ Augmented data for #text_000344.txt created successfully.
# ✅ Augmented data for #text_000345.txt created successfully.
# ✅ Augmented data for #text_000346.txt created successfully.
# ✅ Augmented data for #text_000347.txt created successfully.
# ✅ Augmented data for #text_000348.txt created successfully.
# ✅ Augmented data for #text_000349.txt created successfully.
# ✅ Augmented data for #text_000350.txt created successfully.
# ✅ Augmented data for #text_000351.txt created successfully.
# ✅ Augmented data for #text_000352.txt created successfully.
# ✅ Augmented data for #text_000353.txt created successfully.
# ✅ Augmented data for #text_000354.txt created successfully.
# ✅ Augmented data for #text_000355.txt created successfully.
# ✅ Augmented data for #text_000356.txt created successfully.
# ✅ Augmented data for #text_000357.txt created successfully.
# ✅ Augmented data for #text_000358.txt created successfully.
# ✅ Augmented data for #text_000359.txt created successfully.
# ✅ Augmented data for #text_000360.txt created successfully.
# ✅ Augmented data for #text_000361.txt created successfully.
# ✅ Augmented data for #text_000362.txt created successfully.
# ✅ Augmented data for #text_000363.txt created successfully.
# ✅ Augmented data for #text_000364.txt created successfully.
# ✅ Augmented data for #text_000365.txt created successfully.
# ✅ Augmented data for #text_000366.txt created successfully.
# ✅ Augmented data for #text_000367.txt created successfully.
# ✅ Augmented data for #text_000368.txt created successfully.
# ✅ Augmented data for #text_000369.txt created successfully.
# ✅ Augmented data for #text_000370.txt created successfully.
# ✅ Augmented data for #text_000371.txt created successfully.
# ✅ Augmented data for #text_000372.txt created successfully.
# ✅ Augmented data for #text_000373.txt created successfully.
# ✅ Augmented data for #text_000374.txt created successfully.
# ✅ Augmented data for #text_000375.txt created successfully.
# ✅ Augmented data for #text_000376.txt created successfully.
# ✅ Augmented data for #text_000377.txt created successfully.
# ✅ Augmented data for #text_000378.txt created successfully.
# ✅ Augmented data for #text_000379.txt created successfully.
# ✅ Augmented data for #text_000380.txt created successfully.
# ✅ Augmented data for #text_000381.txt created successfully.
# ✅ Augmented data for #text_000382.txt created successfully.
# ✅ Augmented data for #text_000383.txt created successfully.
# ✅ Augmented data for #text_000384.txt created successfully.
# ✅ Augmented data for #text_000385.txt created successfully.
# ✅ Augmented data for #text_000386.txt created successfully.
# ✅ Augmented data for #text_000387.txt created successfully.
# ✅ Augmented data for #text_000388.txt created successfully.
# ✅ Augmented data for #text_000389.txt created successfully.
# ✅ Augmented data for #text_000390.txt created successfully.
# ✅ Augmented data for #text_000391.txt created successfully.
# ✅ Augmented data for #text_000392.txt created successfully.
# ✅ Augmented data for #text_000393.txt created successfully.
# ✅ Augmented data for #text_000394.txt created successfully.
# ✅ Augmented data for #text_000395.txt created successfully.
# ✅ Augmented data for #text_000396.txt created successfully.
# ✅ Augmented data for #text_000397.txt created successfully.
# ✅ Augmented data for #text_000398.txt created successfully.
# ✅ Augmented data for #text_000399.txt created successfully.
# ✅ Augmented data for #text_000400.txt created successfully.
# ✅ Augmented data for #text_000401.txt created successfully.
# ✅ Augmented data for #text_000402.txt created successfully.
# ✅ Augmented data for #text_000403.txt created successfully.
# ✅ Augmented data for #text_000404.txt created successfully.
# ✅ Augmented data for #text_000405.txt created successfully.
# ✅ Augmented data for #text_000406.txt created successfully.
# ✅ Augmented data for #text_000407.txt created successfully.
# ✅ Augmented data for #text_000408.txt created successfully.
# ✅ Augmented data for #text_000409.txt created successfully.
# ✅ Augmented data for #text_000410.txt created successfully.
# ✅ Augmented data for #text_000411.txt created successfully.
# ✅ Augmented data for #text_000412.txt created successfully.
# ✅ Augmented data for #text_000413.txt created successfully.
# ✅ Augmented data for #text_000414.txt created successfully.
# ✅ Augmented data for #text_000415.txt created successfully.
# ✅ Augmented data for #text_000416.txt created successfully.
# ✅ Augmented data for #text_000417.txt created successfully.
# ✅ Augmented data for #text_000418.txt created successfully.
# ✅ Augmented data for #text_000419.txt created successfully.
# ✅ Augmented data for #text_000420.txt created successfully.
# ✅ Augmented data for #text_000421.txt created successfully.
# ✅ Augmented data for #text_000422.txt created successfully.
# ✅ Augmented data for #text_000423.txt created successfully.
# ✅ Augmented data for #text_000424.txt created successfully.
# ✅ Augmented data for #text_000425.txt created successfully.
# ✅ Augmented data for #text_000426.txt created successfully.
# ✅ Augmented data for #text_000427.txt created successfully.
# ✅ Augmented data for #text_000428.txt created successfully.
# ✅ Augmented data for #text_000429.txt created successfully.
# ✅ Augmented data for #text_000430.txt created successfully.
# ✅ Augmented data for #text_000431.txt created successfully.
# ✅ Augmented data for #text_000432.txt created successfully.
# ✅ Augmented data for #text_000433.txt created successfully.
# ✅ Augmented data for #text_000434.txt created successfully.
# ✅ Augmented data for #text_000435.txt created successfully.
# ✅ Augmented data for #text_000436.txt created successfully.
# ✅ Augmented data for #text_000437.txt created successfully.
# ✅ Augmented data for #text_000438.txt created successfully.
# ✅ Augmented data for #text_000439.txt created successfully.
# ✅ Augmented data for #text_000440.txt created successfully.
# ✅ Augmented data for #text_000441.txt created successfully.
# ✅ Augmented data for #text_000442.txt created successfully.
# ✅ Augmented data for #text_000443.txt created successfully.
# ✅ Augmented data for #text_000444.txt created successfully.
# ✅ Augmented data for #text_000445.txt created successfully.
# ✅ Augmented data for #text_000446.txt created successfully.
# ✅ Augmented data for #text_000447.txt created successfully.
# ✅ Augmented data for #text_000448.txt created successfully.
# ✅ Augmented data for #text_000449.txt created successfully.
# ✅ Augmented data for #text_000450.txt created successfully.
# ✅ Augmented data for #text_000451.txt created successfully.
# ✅ Augmented data for #text_000452.txt created successfully.
# ✅ Augmented data for #text_000453.txt created successfully.
# ✅ Augmented data for #text_000454.txt created successfully.
# ✅ Augmented data for #text_000455.txt created successfully.
# ✅ Augmented data for #text_000456.txt created successfully.
# ✅ Augmented data for #text_000457.txt created successfully.
# ✅ Augmented data for #text_000458.txt created successfully.
# ✅ Augmented data for #text_000459.txt created successfully.
# ✅ Augmented data for #text_000460.txt created successfully.
# ✅ Augmented data for #text_000461.txt created successfully.
# ✅ Augmented data for #text_000462.txt created successfully.
# ✅ Augmented data for #text_000463.txt created successfully.
# ✅ Augmented data for #text_000464.txt created successfully.
# ✅ Augmented data for #text_000465.txt created successfully.
# ✅ Augmented data for #text_000466.txt created successfully.
# ✅ Augmented data for #text_000467.txt created successfully.
# ✅ Augmented data for #text_000468.txt created successfully.
# ✅ Augmented data for #text_000469.txt created successfully.
# ✅ Augmented data for #text_000470.txt created successfully.
# ✅ Augmented data for #text_000471.txt created successfully.
# ✅ Augmented data for #text_000472.txt created successfully.
# ✅ Augmented data for #text_000473.txt created successfully.
# ✅ Augmented data for #text_000474.txt created successfully.
# ✅ Augmented data for #text_000475.txt created successfully.
# ✅ Augmented data for #text_000476.txt created successfully.
# ✅ Augmented data for #text_000477.txt created successfully.
# ✅ Augmented data for #text_000478.txt created successfully.
# ✅ Augmented data for #text_000479.txt created successfully.
# ✅ Augmented data for #text_000480.txt created successfully.
# ✅ Augmented data for #text_000481.txt created successfully.
# ✅ Augmented data for #text_000482.txt created successfully.
# ✅ Augmented data for #text_000483.txt created successfully.
# ✅ Augmented data for #text_000484.txt created successfully.
# ✅ Augmented data for #text_000485.txt created successfully.
# ✅ Augmented data for #text_000486.txt created successfully.
# ✅ Augmented data for #text_000487.txt created successfully.
# ✅ Augmented data for #text_000488.txt created successfully.
# ✅ Augmented data for #text_000489.txt created successfully.
# ✅ Augmented data for #text_000490.txt created successfully.
# ✅ Augmented data for #text_000491.txt created successfully.
# ✅ Augmented data for #text_000492.txt created successfully.
# ✅ Augmented data for #text_000493.txt created successfully.
# ✅ Augmented data for #text_000494.txt created successfully.
# ✅ Augmented data for #text_000495.txt created successfully.
# ✅ All augmented image data have been successfully uploaded.
