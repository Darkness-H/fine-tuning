# %% [markdown]
# ## Image Homogenizer

# %%
# Importing useful dependencies
import io
import os
import boto3
from PIL import Image

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# This function scans a bucket folder, converts every non-PNG image it finds into PNG, uploads it back with the same name but .png extension, and deletes the original file.
def convert_images_to_png(bucket, prefix=""):
    paginator = s3.get_paginator("list_objects_v2")
    for page in paginator.paginate(Bucket=bucket, Prefix=prefix):
        for obj in page.get("Contents", []):

            key = obj["Key"]

            if obj['Size'] == 0 and key.endswith("/"): # skip the folder itself
                continue

            if os.path.splitext(key)[1].lower() == ".png": # skip png images
                continue

            # New key with .png extension
            new_key = os.path.splitext(key)[0] + ".png"

            # Download the image
            resp = s3.get_object(Bucket=bucket, Key=key)
            body = resp["Body"].read()
            
            # Convert to PNG
            img = Image.open(io.BytesIO(body))
            buf = io.BytesIO()
            img.save(buf, format="PNG")
            buf.seek(0)

            # Upload the image back as PNG (replace original with .png)
            s3.upload_fileobj(buf, Bucket=bucket, Key=new_key, ExtraArgs={"ContentType": "image/png"})

            # Delete the old image
            s3.delete_object(Bucket=bucket, Key=key)

            print(f"Replaced: {key} -> {new_key}")

# %%
# Change the format of images to PNG
convert_images_to_png(bucket = "formatted-zone", prefix = "images/")
# Out:
# Replaced: images/image_1766084882100.jpg -> images/image_1766084882100.png
# Replaced: images/image_1766084882226.jpg -> images/image_1766084882226.png
# Replaced: images/image_1766084882330.jpg -> images/image_1766084882330.png
# Replaced: images/image_1766084882467.jpg -> images/image_1766084882467.png
# Replaced: images/image_1766084882565.jpg -> images/image_1766084882565.png
# Replaced: images/image_1766084882703.jpg -> images/image_1766084882703.png
# Replaced: images/image_1766084882815.jpg -> images/image_1766084882815.png
# Replaced: images/image_1766084882933.jpg -> images/image_1766084882933.png
# Replaced: images/image_1766084883041.jpg -> images/image_1766084883041.png
# Replaced: images/image_1766084883195.jpg -> images/image_1766084883195.png
# Replaced: images/image_1766084883350.jpg -> images/image_1766084883350.png
# Replaced: images/image_1766084883519.jpg -> images/image_1766084883519.png
# Replaced: images/image_1766084883649.jpg -> images/image_1766084883649.png
# Replaced: images/image_1766084883770.jpg -> images/image_1766084883770.png
# Replaced: images/image_1766084883878.jpg -> images/image_1766084883878.png
# Replaced: images/image_1766084883986.jpg -> images/image_1766084883986.png
# Replaced: images/image_1766084884098.jpg -> images/image_1766084884098.png
# Replaced: images/image_1766084884226.jpg -> images/image_1766084884226.png
