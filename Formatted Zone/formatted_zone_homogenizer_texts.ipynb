# %% [markdown]
# ## Text Homogenizer

# %%
# Importing useful dependencies
import io
import os
import boto3
import chardet
import docx
import fitz
import zipfile
from bs4 import BeautifulSoup
from odf.opendocument import load
from odf.text import P
from odf.teletype import extractText as odf_text
from striprtf.striprtf import rtf_to_text
import re
import markdown

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# Define all function to extract text from other format

# Helper: normalize paragraph spacing
def _norm(s: str) -> str:
    """
    Normalize paragraph spacing in a text block.

    This helper function standardizes newline characters, removes leading/trailing
    whitespace, and ensures that paragraphs are separated by exactly one blank line.

    s          : str                   - Input text to normalize.
    """
    if not s:
        return ""
    s = s.replace("\r\n", "\n").replace("\r", "\n").strip()
    # Collapse 3 or more newlines into 2 (blank line between paragraphs)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s


def extract_from_docx(body: bytes) -> str:
    """
    Extract plain text from a DOCX document, preserving paragraph breaks.

    The function reads a DOCX file from raw bytes, collects non-empty paragraph
    texts in order, and joins them with a blank line between paragraphs.
    Final spacing is normalized via `_norm()`.

    This extracts `document.paragraphs` only.
    Text inside tables, headers/footers, text boxes/shapes, and comments is not included.

    body          : bytes                   - The raw bytes of a `.docx` file.
    """
    doc = docx.Document(io.BytesIO(body))

    # Gather non-empty paragraphs in order, trimming incidental whitespace.
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text and p.text.strip()]

    return _norm("\n\n".join(paragraphs))

def extract_from_pdf(body: bytes) -> str:
    """
    Extract plain text from a PDF by aggregating page text blocks.

    This approach uses PyMuPDF's block-level extraction to produce a more
    reliable paragraph grouping than line-by-line text.

    body          : bytes                   - The raw bytes of a `.pdf` file.
    """
    doc = fitz.open(stream=io.BytesIO(body), filetype="pdf")
    pages = []

    try:
        for i in range(len(doc)):

            # Each block is a tuple; index 0..4 commonly: (x0, y0, x1, y1, text, ...)
            blocks = doc.load_page(i).get_text("blocks")

            # Sort blocks by top (y0) then left (x0) to approximate natural reading order
            blocks.sort(key=lambda b: (b[1], b[0]))

            # Collect non-empty block texts; strip incidental whitespace
            txts = [b[4].strip() for b in blocks if b[4].strip()]
            # Separate blocks on the page with one blank line
            pages.append("\n\n".join(txts))

    finally:
        doc.close()


    return _norm("\n\n".join(pages))



def extract_from_zip(body: bytes) -> str:
    """
    Extract plain text from an EPUB or ZIP archive containing HTML/XHTML files.

    EPUB files are essentially ZIP archives with structured HTML content.
    This function scans the archive for all `.xhtml`, `.html`, or `.htm` files,
    extracts their readable text, and joins them in lexical order (sorted by
    filename) to approximate the book's original reading order.

    body          : bytes                   - Raw bytes of an EPUB or ZIP archive.

    """

    parts = []

    with zipfile.ZipFile(io.BytesIO(body)) as z:
        for name in sorted(z.namelist()):
            # Only process HTML/XHTML content files
            if name.lower().endswith((".xhtml", ".html", ".htm")):
                with z.open(name) as f:
                    # Parse HTML and extract visible text
                    soup = BeautifulSoup(f.read(), "html.parser")
                    text = soup.get_text("\n").strip()
                    if text:
                        parts.append(text)

    return _norm("\n\n".join(parts))


def extract_from_html(body: bytes) -> str:
    """
    Extract plain text from an HTML document while preserving structural line breaks.

    The function parses HTML content, strips away all markup, and retrieves only
    the visible text. A newline (`\\n`) is inserted between HTML elements to
    roughly preserve the visual separation of blocks (e.g., paragraphs, divs, headings).
    The resulting text is then normalized using `_norm()` to ensure clean paragraph spacing.

    body          : bytes                   -  Raw bytes of the HTML file or response content.
    """

    soup = BeautifulSoup(body, "html.parser")

    # Extract visible text from all tags, separating each block with a newline
    text = soup.get_text(separator="\n")

    return _norm(text)


def extract_from_odt(body: bytes) -> str:
    """
    Extract plain text from an OpenDocument Text (.odt) file, preserving paragraph breaks.

    This function opens an ODT document from raw bytes, iterates over all
    `<text:p>` paragraph elements, extracts their visible text using
    `teletype.extractText`, and joins non-empty paragraphs with a blank line.
    The final text is normalized via `_norm()` to ensure consistent spacing.

    body          : bytes                   -  Raw bytes of the `.odt` file.

    """

    # Open the ODT document directly from bytes
    doc = load(io.BytesIO(body))

    # Collect non-empty paragraph texts in order
    paragraphs = []
    for p in doc.getElementsByType(P):
        text = odf_text(p).strip()
        if text:
            paragraphs.append(text)

    return _norm("\n\n".join(paragraphs))


# RTF
def extract_from_rtf(body: bytes) -> str:
    """
    Extract plain text from an RTF document.

    The function tries to use `striprtf` (if installed) for robust RTF parsing.
    If `striprtf` is unavailable or parsing fails, it falls back to a simple
    heuristic that:
      - Replaces paragraph markers (e.g., ``\\par``) with blank lines,
      - Removes control words/groups and braces,
      - Leaves best-effort plain text.

    body          : bytes                   -  Raw bytes of the `.rtf` file.
    """
    try:
        # Preferred path: use striprtf if available
        text = rtf_to_text(body.decode("utf-8", errors="ignore"))

    # Fall through to heuristic cleanup
    except Exception:
        # Heuristic fallback: very rough RTF cleanup
        s = body.decode("utf-8", errors="ignore")

        # Replace paragraph control words with double newlines
        # \par and \pard → paragraph breaks
        s = re.sub(r"\\par[d]?", "\n\n", s)

        # Remove control groups like {\*\...} or {\fonttbl ...}, keep a space
        s = re.sub(r"{\\[^}]*}", " ", s)

        # Remove standalone control words (e.g., \b, \i, \fs24, \cf1, \u1234)
        s = re.sub(r"\\[a-zA-Z]+-?\d*", " ", s)

        # Remove remaining braces
        s = re.sub(r"[{}]", " ", s)
        text = s

    return _norm(text)


def extract_from_md(body: bytes) -> str:
    """
    Extract plain text from Markdown content by converting to HTML first.

    Converts Markdown to HTML using the standard 'markdown' module,
    then removes markup with BeautifulSoup, preserving paragraph spacing.

    body          : bytes                   -  Raw bytes of the `.md` file.
    """
    html = markdown.markdown(body.decode("utf-8", errors="ignore"))
    soup = BeautifulSoup(html, "html.parser")
    text = soup.get_text(separator="\n")
    return _norm(text)

# %%
# 1) map each extension to its extractor
EXT_MAP = {
    ".docx": extract_from_docx,
    ".pdf":  extract_from_pdf,
    ".epub": extract_from_zip,    # epub is a ZIP of XHTML/HTML
    ".zip":  extract_from_zip,
    ".html": extract_from_html,
    ".odt":  extract_from_odt,
    ".rtf":  extract_from_rtf,
    ".md":   extract_from_md,
}

def convert_and_replace(key, body):
    """
    Convert a supported document (PDF, DOCX, HTML, etc.) to plain text (.txt).

    This function performs content conversion only:
      - It detects the file extension,
      - Selects the correct extractor function from EXT_MAP,
      - Extracts plain text from the raw file bytes,
      - Returns both the converted text and the new filename.

    key             : str                   - Object key (path) within the bucket.
    body            : bytes                 - Raw file bytes to be converted.
    """

    # Determine the file extension and corresponding extractor function
    ext = os.path.splitext(key)[1].lower()
    extractor = EXT_MAP.get(ext)
    if extractor is None:
        return False, None, None

    try:
        content = extractor(body)
        name, _ = os.path.splitext(key)
        new_key = name + ".txt"
        return True, content, new_key
    except Exception as e:
        print(f"Failed to process {key}: {e}")
        return False, None, None

# %%
def convert_documents_to_txt(client, bucket, prefix=""):
    """
    Scan all objects under a given S3 prefix, normalize text encodings to UTF-8,
    and convert non-text documents (PDF, DOCX, HTML, etc.) into plain text (.txt).


    client          : obj                   - S3-compatible client (e.g., boto3.client("s3")).
    bucket          : str                   - Target S3/MinIO bucket.
    prefix          : str                   - Optional key prefix (acts like a folder path).

    """

    # Ensure path ends with '/'
    if prefix and not prefix.endswith("/"):
        prefix += "/"
    paginator = client.get_paginator("list_objects_v2")
    pages = paginator.paginate(Bucket=bucket, Prefix=prefix)

    for page in pages:
        for obj in page.get("Contents", []):

            if obj['Size'] == 0:  # Skip the folder itself (if the file size is 0)
                continue

            key = obj["Key"]

            try:
                # Get the file object from S3
                resp = client.get_object(Bucket=bucket, Key=key)
                body = resp["Body"].read()  # Read the file content

                # Case 1: plain text file (check encoding)
                if key.endswith(".txt"):
                    # Use chardet to detect the file encoding
                    result = chardet.detect(body)
                    current_encoding = result['encoding']
                    # Skip if the file is already in UTF-8 encoding
                    if current_encoding in ("utf-8", "ascii", None):
                        print(f"Already UTF-8 or ASCII: {key}")
                        continue

                    print(f"Converting {key} from {current_encoding} to UTF-8")

                    # Decode the content using the detected encoding and re-encode it in UTF-8
                    content = body.decode(current_encoding, errors='ignore')  # Ignore characters that can't be decoded
                    content = _norm(content)
                    # Upload the converted content back to S3 in UTF-8
                    client.put_object(
                        Bucket=bucket,
                        Key=key,  # Make sure the file key (path) is correct
                        Body=content.encode('utf-8'),
                        ContentType="text/plain"
                    )
                    print(f"Re-encoded {key} successfully")
                    
                else:
                    handled, content, new_key = convert_and_replace(key, body)
                    if handled:
                        client.put_object(
                            Bucket=bucket,
                            Key=new_key,
                            Body=content.encode("utf-8"),
                            ContentType="text/plain",
                        )
                        print(f"Converted {key} → {new_key}")

                    else:
                        print(f"Skipped unsupported extension: {key}")

            except Exception as e:
                print(f"Failed to process {key}: {e}")

# %%
convert_documents_to_txt(s3, bucket = "formatted-zone", prefix = "texts/")
# Out:
# Already UTF-8 or ASCII: texts/text_1766693607636.txt
# Already UTF-8 or ASCII: texts/text_1766693608716.txt
# Converting texts/text_1766693609250.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693609250.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693609462.txt
# Already UTF-8 or ASCII: texts/text_1766693609687.txt
# Converting texts/text_1766693609895.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693609895.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693610047.txt
# Already UTF-8 or ASCII: texts/text_1766693610195.txt
# Already UTF-8 or ASCII: texts/text_1766693610369.txt
# Already UTF-8 or ASCII: texts/text_1766693610480.txt
# Already UTF-8 or ASCII: texts/text_1766693610615.txt
# Already UTF-8 or ASCII: texts/text_1766693610897.txt
# Already UTF-8 or ASCII: texts/text_1766693611050.txt
# Already UTF-8 or ASCII: texts/text_1766693611211.txt
# Already UTF-8 or ASCII: texts/text_1766693611480.txt
# Already UTF-8 or ASCII: texts/text_1766693611624.txt
# Converting texts/text_1766693611863.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1766693611863.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693612147.txt
# Already UTF-8 or ASCII: texts/text_1766693612349.txt
# Already UTF-8 or ASCII: texts/text_1766693612519.txt
# Already UTF-8 or ASCII: texts/text_1766693612662.txt
# Already UTF-8 or ASCII: texts/text_1766693612812.txt
# Already UTF-8 or ASCII: texts/text_1766693612896.txt
# Already UTF-8 or ASCII: texts/text_1766693613038.txt
# Converting texts/text_1766693613188.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693613188.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693613430.txt
# Already UTF-8 or ASCII: texts/text_1766693613541.txt
# Already UTF-8 or ASCII: texts/text_1766693613766.txt
# Already UTF-8 or ASCII: texts/text_1766693613922.txt
# Already UTF-8 or ASCII: texts/text_1766693614085.txt
# Already UTF-8 or ASCII: texts/text_1766693614252.txt
# Already UTF-8 or ASCII: texts/text_1766693614337.txt
# Already UTF-8 or ASCII: texts/text_1766693614434.txt
# Already UTF-8 or ASCII: texts/text_1766693614530.txt
# Converting texts/text_1766693614701.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693614701.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693614910.txt
# Already UTF-8 or ASCII: texts/text_1766693615109.txt
# Already UTF-8 or ASCII: texts/text_1766693615263.txt
# Already UTF-8 or ASCII: texts/text_1766693615541.txt
# Already UTF-8 or ASCII: texts/text_1766693615676.txt
# Already UTF-8 or ASCII: texts/text_1766693615875.txt
# Converting texts/text_1766693616038.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693616038.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693616217.txt
# Converting texts/text_1766693616413.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693616413.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693616606.txt
# Already UTF-8 or ASCII: texts/text_1766693616850.txt
# Already UTF-8 or ASCII: texts/text_1766693617143.txt
# Already UTF-8 or ASCII: texts/text_1766693617406.txt
# Already UTF-8 or ASCII: texts/text_1766693617515.txt
# Already UTF-8 or ASCII: texts/text_1766693617798.txt
# Converting texts/text_1766693618039.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693618039.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693618288.txt
# Converting texts/text_1766693619389.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693619389.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693620755.txt
# Already UTF-8 or ASCII: texts/text_1766693621244.txt
# Already UTF-8 or ASCII: texts/text_1766693621472.txt
# Already UTF-8 or ASCII: texts/text_1766693621671.txt
# Already UTF-8 or ASCII: texts/text_1766693621932.txt
# Already UTF-8 or ASCII: texts/text_1766693622305.txt
# Already UTF-8 or ASCII: texts/text_1766693622522.txt
# Already UTF-8 or ASCII: texts/text_1766693622716.txt
# Already UTF-8 or ASCII: texts/text_1766693622800.txt
# Already UTF-8 or ASCII: texts/text_1766693623001.txt
# Converting texts/text_1766693623228.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693623228.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693623538.txt
# Already UTF-8 or ASCII: texts/text_1766693623656.txt
# Already UTF-8 or ASCII: texts/text_1766693623987.txt
# Already UTF-8 or ASCII: texts/text_1766693624223.txt
# Already UTF-8 or ASCII: texts/text_1766693624398.txt
# Converting texts/text_1766693624589.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693624589.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693624661.txt
# Already UTF-8 or ASCII: texts/text_1766693624774.txt
# Already UTF-8 or ASCII: texts/text_1766693625062.txt
# Already UTF-8 or ASCII: texts/text_1766693625235.txt
# Already UTF-8 or ASCII: texts/text_1766693625382.txt
# Already UTF-8 or ASCII: texts/text_1766693625498.txt
# Already UTF-8 or ASCII: texts/text_1766693625644.txt
# Already UTF-8 or ASCII: texts/text_1766693625795.txt
# Already UTF-8 or ASCII: texts/text_1766693625992.txt
# Already UTF-8 or ASCII: texts/text_1766693626292.txt
# Converting texts/text_1766693626485.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693626485.txt successfully
# Converting texts/text_1766693626729.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693626729.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693626834.txt
# Already UTF-8 or ASCII: texts/text_1766693627061.txt
# Already UTF-8 or ASCII: texts/text_1766693627372.txt
# Already UTF-8 or ASCII: texts/text_1766693627645.txt
# Converting texts/text_1766693627775.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1766693627775.txt successfully
# Already UTF-8 or ASCII: texts/text_1766693627914.txt
# Already UTF-8 or ASCII: texts/text_1766693628075.txt
# Already UTF-8 or ASCII: texts/text_1766693628143.txt
# Already UTF-8 or ASCII: texts/text_1766693628310.txt
# Already UTF-8 or ASCII: texts/text_1766693628499.txt
# Already UTF-8 or ASCII: texts/text_1766693628690.txt
# Already UTF-8 or ASCII: texts/text_1766693628851.txt
# Already UTF-8 or ASCII: texts/text_1766693629029.txt
# Already UTF-8 or ASCII: texts/text_1766693629208.txt
# Already UTF-8 or ASCII: texts/text_1766693629554.txt
# Already UTF-8 or ASCII: texts/text_1766693629639.txt
# Already UTF-8 or ASCII: texts/text_1766693629764.txt
# Already UTF-8 or ASCII: texts/text_1766693629935.txt
# Already UTF-8 or ASCII: texts/text_1767028950495.txt
# Already UTF-8 or ASCII: texts/text_1767028950614.txt
# Already UTF-8 or ASCII: texts/text_1767028950828.txt
# Already UTF-8 or ASCII: texts/text_1767028951043.txt
# Already UTF-8 or ASCII: texts/text_1767028951191.txt
# Already UTF-8 or ASCII: texts/text_1767028951535.txt
# Already UTF-8 or ASCII: texts/text_1767028951602.txt
# Converting texts/text_1767028951735.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767028951735.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028951930.txt
# Converting texts/text_1767028952034.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028952034.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028952305.txt
# Already UTF-8 or ASCII: texts/text_1767028952901.txt
# Converting texts/text_1767028953379.txt from Windows-1254 to UTF-8
# Re-encoded texts/text_1767028953379.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028954197.txt
# Converting texts/text_1767028954546.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767028954546.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028954778.txt
# Converting texts/text_1767028954929.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028954929.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028955050.txt
# Already UTF-8 or ASCII: texts/text_1767028955171.txt
# Already UTF-8 or ASCII: texts/text_1767028955298.txt
# Already UTF-8 or ASCII: texts/text_1767028955531.txt
# Already UTF-8 or ASCII: texts/text_1767028956271.txt
# Already UTF-8 or ASCII: texts/text_1767028956618.txt
# Already UTF-8 or ASCII: texts/text_1767028956817.txt
# Already UTF-8 or ASCII: texts/text_1767028957001.txt
# Already UTF-8 or ASCII: texts/text_1767028957215.txt
# Converting texts/text_1767028957374.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028957374.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028957553.txt
# Already UTF-8 or ASCII: texts/text_1767028957687.txt
# Already UTF-8 or ASCII: texts/text_1767028957924.txt
# Already UTF-8 or ASCII: texts/text_1767028958135.txt
# Already UTF-8 or ASCII: texts/text_1767028958346.txt
# Already UTF-8 or ASCII: texts/text_1767028958563.txt
# Already UTF-8 or ASCII: texts/text_1767028958892.txt
# Already UTF-8 or ASCII: texts/text_1767028959155.txt
# Already UTF-8 or ASCII: texts/text_1767028959373.txt
# Already UTF-8 or ASCII: texts/text_1767028959582.txt
# Already UTF-8 or ASCII: texts/text_1767028959890.txt
# Already UTF-8 or ASCII: texts/text_1767028960078.txt
# Converting texts/text_1767028960285.txt from MacRoman to UTF-8
# Re-encoded texts/text_1767028960285.txt successfully
# Converting texts/text_1767028960487.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767028960487.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028960731.txt
# Already UTF-8 or ASCII: texts/text_1767028960872.txt
# Already UTF-8 or ASCII: texts/text_1767028961140.txt
# Converting texts/text_1767028961439.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028961439.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028961566.txt
# Already UTF-8 or ASCII: texts/text_1767028961689.txt
# Already UTF-8 or ASCII: texts/text_1767028961835.txt
# Already UTF-8 or ASCII: texts/text_1767028962029.txt
# Already UTF-8 or ASCII: texts/text_1767028962376.txt
# Already UTF-8 or ASCII: texts/text_1767028962528.txt
# Already UTF-8 or ASCII: texts/text_1767028963265.txt
# Already UTF-8 or ASCII: texts/text_1767028963656.txt
# Already UTF-8 or ASCII: texts/text_1767028964472.txt
# Already UTF-8 or ASCII: texts/text_1767028964705.txt
# Already UTF-8 or ASCII: texts/text_1767028964826.txt
# Already UTF-8 or ASCII: texts/text_1767028964990.txt
# Already UTF-8 or ASCII: texts/text_1767028965141.txt
# Already UTF-8 or ASCII: texts/text_1767028965245.txt
# Already UTF-8 or ASCII: texts/text_1767028965469.txt
# Already UTF-8 or ASCII: texts/text_1767028966258.txt
# Already UTF-8 or ASCII: texts/text_1767028966552.txt
# Already UTF-8 or ASCII: texts/text_1767028966886.txt
# Already UTF-8 or ASCII: texts/text_1767028967141.txt
# Already UTF-8 or ASCII: texts/text_1767028967377.txt
# Already UTF-8 or ASCII: texts/text_1767028967542.txt
# Converting texts/text_1767028967704.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028967704.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028967995.txt
# Already UTF-8 or ASCII: texts/text_1767028968130.txt
# Already UTF-8 or ASCII: texts/text_1767028968199.txt
# Already UTF-8 or ASCII: texts/text_1767028968323.txt
# Already UTF-8 or ASCII: texts/text_1767028968500.txt
# Converting texts/text_1767028968694.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028968694.txt successfully
# Converting texts/text_1767028969023.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767028969023.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028969208.txt
# Already UTF-8 or ASCII: texts/text_1767028969569.txt
# Converting texts/text_1767028969897.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767028969897.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028970046.txt
# Already UTF-8 or ASCII: texts/text_1767028970293.txt
# Already UTF-8 or ASCII: texts/text_1767028970630.txt
# Already UTF-8 or ASCII: texts/text_1767028970954.txt
# Already UTF-8 or ASCII: texts/text_1767028971102.txt
# Already UTF-8 or ASCII: texts/text_1767028971282.txt
# Already UTF-8 or ASCII: texts/text_1767028971370.txt
# Already UTF-8 or ASCII: texts/text_1767028971503.txt
# Already UTF-8 or ASCII: texts/text_1767028971690.txt
# Already UTF-8 or ASCII: texts/text_1767028972014.txt
# Already UTF-8 or ASCII: texts/text_1767028972173.txt
# Already UTF-8 or ASCII: texts/text_1767028972449.txt
# Already UTF-8 or ASCII: texts/text_1767028973224.txt
# Already UTF-8 or ASCII: texts/text_1767028973632.txt
# Already UTF-8 or ASCII: texts/text_1767028974404.txt
# Converting texts/text_1767028974693.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028974693.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028974927.txt
# Already UTF-8 or ASCII: texts/text_1767028975128.txt
# Already UTF-8 or ASCII: texts/text_1767028975332.txt
# Already UTF-8 or ASCII: texts/text_1767028975553.txt
# Already UTF-8 or ASCII: texts/text_1767028976405.txt
# Already UTF-8 or ASCII: texts/text_1767028976658.txt
# Already UTF-8 or ASCII: texts/text_1767028976893.txt
# Already UTF-8 or ASCII: texts/text_1767028977142.txt
# Already UTF-8 or ASCII: texts/text_1767028977391.txt
# Already UTF-8 or ASCII: texts/text_1767028977570.txt
# Already UTF-8 or ASCII: texts/text_1767028977888.txt
# Already UTF-8 or ASCII: texts/text_1767028978155.txt
# Already UTF-8 or ASCII: texts/text_1767028978404.txt
# Already UTF-8 or ASCII: texts/text_1767028978713.txt
# Already UTF-8 or ASCII: texts/text_1767028979028.txt
# Already UTF-8 or ASCII: texts/text_1767028979243.txt
# Already UTF-8 or ASCII: texts/text_1767028979537.txt
# Already UTF-8 or ASCII: texts/text_1767028979837.txt
# Already UTF-8 or ASCII: texts/text_1767028980072.txt
# Already UTF-8 or ASCII: texts/text_1767028980291.txt
# Converting texts/text_1767028980540.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028980540.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028980823.txt
# Already UTF-8 or ASCII: texts/text_1767028981151.txt
# Already UTF-8 or ASCII: texts/text_1767028981377.txt
# Already UTF-8 or ASCII: texts/text_1767028981601.txt
# Already UTF-8 or ASCII: texts/text_1767028981911.txt
# Already UTF-8 or ASCII: texts/text_1767028982188.txt
# Already UTF-8 or ASCII: texts/text_1767028982380.txt
# Already UTF-8 or ASCII: texts/text_1767028982560.txt
# Converting texts/text_1767028983319.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028983319.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028983961.txt
# Already UTF-8 or ASCII: texts/text_1767028984506.txt
# Already UTF-8 or ASCII: texts/text_1767028984780.txt
# Already UTF-8 or ASCII: texts/text_1767028985040.txt
# Already UTF-8 or ASCII: texts/text_1767028985298.txt
# Already UTF-8 or ASCII: texts/text_1767028985517.txt
# Already UTF-8 or ASCII: texts/text_1767028986304.txt
# Already UTF-8 or ASCII: texts/text_1767028986681.txt
# Already UTF-8 or ASCII: texts/text_1767028986931.txt
# Already UTF-8 or ASCII: texts/text_1767028987147.txt
# Already UTF-8 or ASCII: texts/text_1767028987498.txt
# Already UTF-8 or ASCII: texts/text_1767028987747.txt
# Already UTF-8 or ASCII: texts/text_1767028988026.txt
# Already UTF-8 or ASCII: texts/text_1767028988276.txt
# Already UTF-8 or ASCII: texts/text_1767028988571.txt
# Already UTF-8 or ASCII: texts/text_1767028988868.txt
# Already UTF-8 or ASCII: texts/text_1767028989246.txt
# Already UTF-8 or ASCII: texts/text_1767028989584.txt
# Converting texts/text_1767028989803.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028989803.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028990039.txt
# Converting texts/text_1767028990269.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028990269.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028990525.txt
# Already UTF-8 or ASCII: texts/text_1767028990797.txt
# Already UTF-8 or ASCII: texts/text_1767028991056.txt
# Already UTF-8 or ASCII: texts/text_1767028991285.txt
# Converting texts/text_1767028991664.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028991664.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028992020.txt
# Already UTF-8 or ASCII: texts/text_1767028992522.txt
# Converting texts/text_1767028993503.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028993503.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028994500.txt
# Already UTF-8 or ASCII: texts/text_1767028994848.txt
# Already UTF-8 or ASCII: texts/text_1767028995045.txt
# Already UTF-8 or ASCII: texts/text_1767028995327.txt
# Already UTF-8 or ASCII: texts/text_1767028995874.txt
# Already UTF-8 or ASCII: texts/text_1767028996641.txt
# Converting texts/text_1767028996937.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028996937.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028997189.txt
# Already UTF-8 or ASCII: texts/text_1767028997551.txt
# Already UTF-8 or ASCII: texts/text_1767028997812.txt
# Already UTF-8 or ASCII: texts/text_1767028998336.txt
# Converting texts/text_1767028998667.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767028998667.txt successfully
# Already UTF-8 or ASCII: texts/text_1767028998881.txt
# Already UTF-8 or ASCII: texts/text_1767028999279.txt
# Already UTF-8 or ASCII: texts/text_1767028999711.txt
# Already UTF-8 or ASCII: texts/text_1767029000141.txt
# Already UTF-8 or ASCII: texts/text_1767029000378.txt
# Already UTF-8 or ASCII: texts/text_1767029000464.txt
# Converting texts/text_1767029000548.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029000548.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029000845.txt
# Converting texts/text_1767029001189.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029001189.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029001371.txt
# Converting texts/text_1767029001593.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029001593.txt successfully
# Converting texts/text_1767029001696.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029001696.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029001911.txt
# Already UTF-8 or ASCII: texts/text_1767029002075.txt
# Converting texts/text_1767029002371.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029002371.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029003057.txt
# Already UTF-8 or ASCII: texts/text_1767029003503.txt
# Already UTF-8 or ASCII: texts/text_1767029004364.txt
# Already UTF-8 or ASCII: texts/text_1767029004686.txt
# Already UTF-8 or ASCII: texts/text_1767029004964.txt
# Already UTF-8 or ASCII: texts/text_1767029005280.txt
# Already UTF-8 or ASCII: texts/text_1767029005444.txt
# Already UTF-8 or ASCII: texts/text_1767029006163.txt
# Already UTF-8 or ASCII: texts/text_1767029006517.txt
# Already UTF-8 or ASCII: texts/text_1767029006718.txt
# Already UTF-8 or ASCII: texts/text_1767029006935.txt
# Already UTF-8 or ASCII: texts/text_1767029007171.txt
# Already UTF-8 or ASCII: texts/text_1767029007443.txt
# Already UTF-8 or ASCII: texts/text_1767029007625.txt
# Converting texts/text_1767029007923.txt from MacRoman to UTF-8
# Re-encoded texts/text_1767029007923.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029008087.txt
# Converting texts/text_1767029008214.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029008214.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029008478.txt
# Already UTF-8 or ASCII: texts/text_1767029008626.txt
# Converting texts/text_1767029008865.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029008865.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029009094.txt
# Already UTF-8 or ASCII: texts/text_1767029009271.txt
# Already UTF-8 or ASCII: texts/text_1767029009383.txt
# Already UTF-8 or ASCII: texts/text_1767029009603.txt
# Already UTF-8 or ASCII: texts/text_1767029009694.txt
# Converting texts/text_1767029009935.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767029009935.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029010025.txt
# Already UTF-8 or ASCII: texts/text_1767029010243.txt
# Already UTF-8 or ASCII: texts/text_1767029010530.txt
# Already UTF-8 or ASCII: texts/text_1767029010673.txt
# Already UTF-8 or ASCII: texts/text_1767029010880.txt
# Already UTF-8 or ASCII: texts/text_1767029011005.txt
# Already UTF-8 or ASCII: texts/text_1767029011246.txt
# Already UTF-8 or ASCII: texts/text_1767029011522.txt
# Already UTF-8 or ASCII: texts/text_1767029011735.txt
# Already UTF-8 or ASCII: texts/text_1767029011939.txt
# Already UTF-8 or ASCII: texts/text_1767029012062.txt
# Already UTF-8 or ASCII: texts/text_1767029012286.txt
# Already UTF-8 or ASCII: texts/text_1767029012478.txt
# Converting texts/text_1767029012845.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029012845.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029013482.txt
# Already UTF-8 or ASCII: texts/text_1767029014264.txt
# Converting texts/text_1767029014606.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029014606.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029014815.txt
# Converting texts/text_1767029015070.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029015070.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029015264.txt
# Already UTF-8 or ASCII: texts/text_1767029015440.txt
# Already UTF-8 or ASCII: texts/text_1767029015690.txt
# Already UTF-8 or ASCII: texts/text_1767029016438.txt
# Already UTF-8 or ASCII: texts/text_1767029016723.txt
# Already UTF-8 or ASCII: texts/text_1767029016963.txt
# Already UTF-8 or ASCII: texts/text_1767029017196.txt
# Already UTF-8 or ASCII: texts/text_1767029017408.txt
# Already UTF-8 or ASCII: texts/text_1767029017588.txt
# Already UTF-8 or ASCII: texts/text_1767029017828.txt
# Converting texts/text_1767029018027.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029018027.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029018272.txt
# Already UTF-8 or ASCII: texts/text_1767029018519.txt
# Already UTF-8 or ASCII: texts/text_1767029018733.txt
# Already UTF-8 or ASCII: texts/text_1767029018949.txt
# Already UTF-8 or ASCII: texts/text_1767029019112.txt
# Already UTF-8 or ASCII: texts/text_1767029019230.txt
# Already UTF-8 or ASCII: texts/text_1767029019318.txt
# Already UTF-8 or ASCII: texts/text_1767029019553.txt
# Already UTF-8 or ASCII: texts/text_1767029019936.txt
# Already UTF-8 or ASCII: texts/text_1767029020018.txt
# Converting texts/text_1767029020160.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029020160.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029020334.txt
# Converting texts/text_1767029020536.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029020536.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029021009.txt
# Already UTF-8 or ASCII: texts/text_1767029021299.txt
# Already UTF-8 or ASCII: texts/text_1767029021588.txt
# Already UTF-8 or ASCII: texts/text_1767029021939.txt
# Already UTF-8 or ASCII: texts/text_1767029022068.txt
# Already UTF-8 or ASCII: texts/text_1767029022393.txt
# Already UTF-8 or ASCII: texts/text_1767029022609.txt
# Already UTF-8 or ASCII: texts/text_1767029023374.txt
# Already UTF-8 or ASCII: texts/text_1767029024049.txt
# Already UTF-8 or ASCII: texts/text_1767029024563.txt
# Already UTF-8 or ASCII: texts/text_1767029024754.txt
# Converting texts/text_1767029025120.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029025120.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029025319.txt
# Already UTF-8 or ASCII: texts/text_1767029025539.txt
# Already UTF-8 or ASCII: texts/text_1767029026275.txt
# Already UTF-8 or ASCII: texts/text_1767029026688.txt
# Converting texts/text_1767029026919.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767029026919.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029027149.txt
# Already UTF-8 or ASCII: texts/text_1767029027476.txt
# Already UTF-8 or ASCII: texts/text_1767029027797.txt
# Already UTF-8 or ASCII: texts/text_1767029028069.txt
# Already UTF-8 or ASCII: texts/text_1767029028210.txt
# Already UTF-8 or ASCII: texts/text_1767029028413.txt
# Already UTF-8 or ASCII: texts/text_1767029028590.txt
# Already UTF-8 or ASCII: texts/text_1767029028992.txt
# Already UTF-8 or ASCII: texts/text_1767029029250.txt
# Already UTF-8 or ASCII: texts/text_1767029029520.txt
# Already UTF-8 or ASCII: texts/text_1767029029930.txt
# Already UTF-8 or ASCII: texts/text_1767029030172.txt
# Already UTF-8 or ASCII: texts/text_1767029030462.txt
# Already UTF-8 or ASCII: texts/text_1767029030682.txt
# Already UTF-8 or ASCII: texts/text_1767029030797.txt
# Already UTF-8 or ASCII: texts/text_1767029030960.txt
# Already UTF-8 or ASCII: texts/text_1767029031226.txt
# Converting texts/text_1767029031365.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029031365.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029031554.txt
# Converting texts/text_1767029031892.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029031892.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029031984.txt
# Already UTF-8 or ASCII: texts/text_1767029032063.txt
# Already UTF-8 or ASCII: texts/text_1767029032141.txt
# Already UTF-8 or ASCII: texts/text_1767029032341.txt
# Already UTF-8 or ASCII: texts/text_1767029032452.txt
# Converting texts/text_1767029032573.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029032573.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029033443.txt
# Already UTF-8 or ASCII: texts/text_1767029034288.txt
# Already UTF-8 or ASCII: texts/text_1767029034839.txt
# Converting texts/text_1767029035047.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029035047.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029035157.txt
# Converting texts/text_1767029035307.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029035307.txt successfully
# Converting texts/text_1767029035552.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029035552.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029036287.txt
# Already UTF-8 or ASCII: texts/text_1767029036666.txt
# Converting texts/text_1767029036869.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029036869.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029037075.txt
# Already UTF-8 or ASCII: texts/text_1767029037254.txt
# Already UTF-8 or ASCII: texts/text_1767029037364.txt
# Already UTF-8 or ASCII: texts/text_1767029037485.txt
# Already UTF-8 or ASCII: texts/text_1767029037569.txt
# Already UTF-8 or ASCII: texts/text_1767029037686.txt
# Already UTF-8 or ASCII: texts/text_1767029037825.txt
# Already UTF-8 or ASCII: texts/text_1767029038061.txt
# Already UTF-8 or ASCII: texts/text_1767029038319.txt
# Already UTF-8 or ASCII: texts/text_1767029038377.txt
# Converting texts/text_1767029038495.txt from MacRoman to UTF-8
# Re-encoded texts/text_1767029038495.txt successfully
# Converting texts/text_1767029038668.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029038668.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029038886.txt
# Already UTF-8 or ASCII: texts/text_1767029039116.txt
# Already UTF-8 or ASCII: texts/text_1767029039349.txt
# Converting texts/text_1767029039482.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029039482.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029039694.txt
# Already UTF-8 or ASCII: texts/text_1767029040003.txt
# Already UTF-8 or ASCII: texts/text_1767029040230.txt
# Already UTF-8 or ASCII: texts/text_1767029040492.txt
# Already UTF-8 or ASCII: texts/text_1767029040735.txt
# Already UTF-8 or ASCII: texts/text_1767029040941.txt
# Already UTF-8 or ASCII: texts/text_1767029041219.txt
# Already UTF-8 or ASCII: texts/text_1767029041568.txt
# Already UTF-8 or ASCII: texts/text_1767029041856.txt
# Converting texts/text_1767029042161.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029042161.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029042373.txt
# Already UTF-8 or ASCII: texts/text_1767029042565.txt
# Already UTF-8 or ASCII: texts/text_1767029043294.txt
# Already UTF-8 or ASCII: texts/text_1767029043857.txt
# Already UTF-8 or ASCII: texts/text_1767029044481.txt
# Already UTF-8 or ASCII: texts/text_1767029044693.txt
# Already UTF-8 or ASCII: texts/text_1767029044912.txt
# Already UTF-8 or ASCII: texts/text_1767029045091.txt
# Already UTF-8 or ASCII: texts/text_1767029045289.txt
# Already UTF-8 or ASCII: texts/text_1767029045477.txt
# Already UTF-8 or ASCII: texts/text_1767029045905.txt
# Already UTF-8 or ASCII: texts/text_1767029046543.txt
# Already UTF-8 or ASCII: texts/text_1767029046825.txt
# Already UTF-8 or ASCII: texts/text_1767029047064.txt
# Converting texts/text_1767029047281.txt from MacRoman to UTF-8
# Re-encoded texts/text_1767029047281.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029047498.txt
# Converting texts/text_1767029047737.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029047737.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029047923.txt
# Converting texts/text_1767029048100.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767029048100.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029048300.txt
# Already UTF-8 or ASCII: texts/text_1767029048472.txt
# Already UTF-8 or ASCII: texts/text_1767029048653.txt
# Already UTF-8 or ASCII: texts/text_1767029048858.txt
# Already UTF-8 or ASCII: texts/text_1767029049094.txt
# Already UTF-8 or ASCII: texts/text_1767029049221.txt
# Already UTF-8 or ASCII: texts/text_1767029049337.txt
# Already UTF-8 or ASCII: texts/text_1767029049559.txt
# Already UTF-8 or ASCII: texts/text_1767029049762.txt
# Already UTF-8 or ASCII: texts/text_1767029049963.txt
# Already UTF-8 or ASCII: texts/text_1767029050148.txt
# Already UTF-8 or ASCII: texts/text_1767029050295.txt
# Already UTF-8 or ASCII: texts/text_1767029050480.txt
# Already UTF-8 or ASCII: texts/text_1767029050690.txt
# Already UTF-8 or ASCII: texts/text_1767029050851.txt
# Already UTF-8 or ASCII: texts/text_1767029051012.txt
# Already UTF-8 or ASCII: texts/text_1767029051087.txt
# Already UTF-8 or ASCII: texts/text_1767029051369.txt
# Already UTF-8 or ASCII: texts/text_1767029051471.txt
# Converting texts/text_1767029051796.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029051796.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029052047.txt
# Already UTF-8 or ASCII: texts/text_1767029052267.txt
# Already UTF-8 or ASCII: texts/text_1767029052441.txt
# Already UTF-8 or ASCII: texts/text_1767029052567.txt
# Already UTF-8 or ASCII: texts/text_1767029053047.txt
# Already UTF-8 or ASCII: texts/text_1767029053584.txt
# Already UTF-8 or ASCII: texts/text_1767029054403.txt
# Already UTF-8 or ASCII: texts/text_1767029054680.txt
# Already UTF-8 or ASCII: texts/text_1767029054873.txt
# Already UTF-8 or ASCII: texts/text_1767029055088.txt
# Already UTF-8 or ASCII: texts/text_1767029055264.txt
# Already UTF-8 or ASCII: texts/text_1767029055434.txt
# Already UTF-8 or ASCII: texts/text_1767029055847.txt
# Already UTF-8 or ASCII: texts/text_1767029056527.txt
# Already UTF-8 or ASCII: texts/text_1767029056806.txt
# Already UTF-8 or ASCII: texts/text_1767029057011.txt
# Converting texts/text_1767029057212.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1767029057212.txt successfully
# Converting texts/text_1767029057507.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029057507.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029057793.txt
# Already UTF-8 or ASCII: texts/text_1767029057968.txt
# Already UTF-8 or ASCII: texts/text_1767029058101.txt
# Already UTF-8 or ASCII: texts/text_1767029058281.txt
# Already UTF-8 or ASCII: texts/text_1767029058479.txt
# Converting texts/text_1767029058602.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1767029058602.txt successfully
# Already UTF-8 or ASCII: texts/text_1767029058829.txt
# Already UTF-8 or ASCII: texts/text_1767029058963.txt
# Already UTF-8 or ASCII: texts/text_1767029059217.txt
# Already UTF-8 or ASCII: texts/text_1767029059457.txt
# Already UTF-8 or ASCII: texts/text_1767029059598.txt
# Already UTF-8 or ASCII: texts/text_1767029059760.txt
