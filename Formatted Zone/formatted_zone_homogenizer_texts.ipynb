# %% [markdown]
# ## Text Homogenizer

# %%
# Importing useful dependencies
import io
import os
import boto3
import chardet
import docx
import fitz
import zipfile
from bs4 import BeautifulSoup
from odf.opendocument import load
from odf.text import P
from odf.teletype import extractText as odf_text
from striprtf.striprtf import rtf_to_text
import re
import markdown

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# Define all function to extract text from other format

# Helper: normalize paragraph spacing
def _norm(s: str) -> str:
    """
    Normalize paragraph spacing in a text block.

    This helper function standardizes newline characters, removes leading/trailing
    whitespace, and ensures that paragraphs are separated by exactly one blank line.

    s          : str                   - Input text to normalize.
    """
    if not s:
        return ""
    s = s.replace("\r\n", "\n").replace("\r", "\n").strip()
    # Collapse 3 or more newlines into 2 (blank line between paragraphs)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s


def extract_from_docx(body: bytes) -> str:
    """
    Extract plain text from a DOCX document, preserving paragraph breaks.

    The function reads a DOCX file from raw bytes, collects non-empty paragraph
    texts in order, and joins them with a blank line between paragraphs.
    Final spacing is normalized via `_norm()`.

    This extracts `document.paragraphs` only.
    Text inside tables, headers/footers, text boxes/shapes, and comments is not included.

    body          : bytes                   - The raw bytes of a `.docx` file.
    """
    doc = docx.Document(io.BytesIO(body))

    # Gather non-empty paragraphs in order, trimming incidental whitespace.
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text and p.text.strip()]

    return _norm("\n\n".join(paragraphs))

def extract_from_pdf(body: bytes) -> str:
    """
    Extract plain text from a PDF by aggregating page text blocks.

    This approach uses PyMuPDF's block-level extraction to produce a more
    reliable paragraph grouping than line-by-line text.

    body          : bytes                   - The raw bytes of a `.pdf` file.
    """
    doc = fitz.open(stream=io.BytesIO(body), filetype="pdf")
    pages = []

    try:
        for i in range(len(doc)):

            # Each block is a tuple; index 0..4 commonly: (x0, y0, x1, y1, text, ...)
            blocks = doc.load_page(i).get_text("blocks")

            # Sort blocks by top (y0) then left (x0) to approximate natural reading order
            blocks.sort(key=lambda b: (b[1], b[0]))

            # Collect non-empty block texts; strip incidental whitespace
            txts = [b[4].strip() for b in blocks if b[4].strip()]
            # Separate blocks on the page with one blank line
            pages.append("\n\n".join(txts))

    finally:
        doc.close()


    return _norm("\n\n".join(pages))



def extract_from_zip(body: bytes) -> str:
    """
    Extract plain text from an EPUB or ZIP archive containing HTML/XHTML files.

    EPUB files are essentially ZIP archives with structured HTML content.
    This function scans the archive for all `.xhtml`, `.html`, or `.htm` files,
    extracts their readable text, and joins them in lexical order (sorted by
    filename) to approximate the book's original reading order.

    body          : bytes                   - Raw bytes of an EPUB or ZIP archive.

    """

    parts = []

    with zipfile.ZipFile(io.BytesIO(body)) as z:
        for name in sorted(z.namelist()):
            # Only process HTML/XHTML content files
            if name.lower().endswith((".xhtml", ".html", ".htm")):
                with z.open(name) as f:
                    # Parse HTML and extract visible text
                    soup = BeautifulSoup(f.read(), "html.parser")
                    text = soup.get_text("\n").strip()
                    if text:
                        parts.append(text)

    return _norm("\n\n".join(parts))


def extract_from_html(body: bytes) -> str:
    """
    Extract plain text from an HTML document while preserving structural line breaks.

    The function parses HTML content, strips away all markup, and retrieves only
    the visible text. A newline (`\\n`) is inserted between HTML elements to
    roughly preserve the visual separation of blocks (e.g., paragraphs, divs, headings).
    The resulting text is then normalized using `_norm()` to ensure clean paragraph spacing.

    body          : bytes                   -  Raw bytes of the HTML file or response content.
    """

    soup = BeautifulSoup(body, "html.parser")

    # Extract visible text from all tags, separating each block with a newline
    text = soup.get_text(separator="\n")

    return _norm(text)


def extract_from_odt(body: bytes) -> str:
    """
    Extract plain text from an OpenDocument Text (.odt) file, preserving paragraph breaks.

    This function opens an ODT document from raw bytes, iterates over all
    `<text:p>` paragraph elements, extracts their visible text using
    `teletype.extractText`, and joins non-empty paragraphs with a blank line.
    The final text is normalized via `_norm()` to ensure consistent spacing.

    body          : bytes                   -  Raw bytes of the `.odt` file.

    """

    # Open the ODT document directly from bytes
    doc = load(io.BytesIO(body))

    # Collect non-empty paragraph texts in order
    paragraphs = []
    for p in doc.getElementsByType(P):
        text = odf_text(p).strip()
        if text:
            paragraphs.append(text)

    return _norm("\n\n".join(paragraphs))


# RTF
def extract_from_rtf(body: bytes) -> str:
    """
    Extract plain text from an RTF document.

    The function tries to use `striprtf` (if installed) for robust RTF parsing.
    If `striprtf` is unavailable or parsing fails, it falls back to a simple
    heuristic that:
      - Replaces paragraph markers (e.g., ``\\par``) with blank lines,
      - Removes control words/groups and braces,
      - Leaves best-effort plain text.

    body          : bytes                   -  Raw bytes of the `.rtf` file.
    """
    try:
        # Preferred path: use striprtf if available
        text = rtf_to_text(body.decode("utf-8", errors="ignore"))

    # Fall through to heuristic cleanup
    except Exception:
        # Heuristic fallback: very rough RTF cleanup
        s = body.decode("utf-8", errors="ignore")

        # Replace paragraph control words with double newlines
        # \par and \pard → paragraph breaks
        s = re.sub(r"\\par[d]?", "\n\n", s)

        # Remove control groups like {\*\...} or {\fonttbl ...}, keep a space
        s = re.sub(r"{\\[^}]*}", " ", s)

        # Remove standalone control words (e.g., \b, \i, \fs24, \cf1, \u1234)
        s = re.sub(r"\\[a-zA-Z]+-?\d*", " ", s)

        # Remove remaining braces
        s = re.sub(r"[{}]", " ", s)
        text = s

    return _norm(text)


def extract_from_md(body: bytes) -> str:
    """
    Extract plain text from Markdown content by converting to HTML first.

    Converts Markdown to HTML using the standard 'markdown' module,
    then removes markup with BeautifulSoup, preserving paragraph spacing.

    body          : bytes                   -  Raw bytes of the `.md` file.
    """
    html = markdown.markdown(body.decode("utf-8", errors="ignore"))
    soup = BeautifulSoup(html, "html.parser")
    text = soup.get_text(separator="\n")
    return _norm(text)

# %%
# 1) map each extension to its extractor
EXT_MAP = {
    ".docx": extract_from_docx,
    ".pdf":  extract_from_pdf,
    ".epub": extract_from_zip,    # epub is a ZIP of XHTML/HTML
    ".zip":  extract_from_zip,
    ".html": extract_from_html,
    ".odt":  extract_from_odt,
    ".rtf":  extract_from_rtf,
    ".md":   extract_from_md,
}

def convert_and_replace(key, body):
    """
    Convert a supported document (PDF, DOCX, HTML, etc.) to plain text (.txt).

    This function performs content conversion only:
      - It detects the file extension,
      - Selects the correct extractor function from EXT_MAP,
      - Extracts plain text from the raw file bytes,
      - Returns both the converted text and the new filename.

    key             : str                   - Object key (path) within the bucket.
    body            : bytes                 - Raw file bytes to be converted.
    """

    # Determine the file extension and corresponding extractor function
    ext = os.path.splitext(key)[1].lower()
    extractor = EXT_MAP.get(ext)
    if extractor is None:
        return False, None, None

    try:
        content = extractor(body)
        name, _ = os.path.splitext(key)
        new_key = name + ".txt"
        return True, content, new_key
    except Exception as e:
        print(f"Failed to process {key}: {e}")
        return False, None, None

# %%
def convert_documents_to_txt(client, bucket, prefix=""):
    """
    Scan all objects under a given S3 prefix, normalize text encodings to UTF-8,
    and convert non-text documents (PDF, DOCX, HTML, etc.) into plain text (.txt).


    client          : obj                   - S3-compatible client (e.g., boto3.client("s3")).
    bucket          : str                   - Target S3/MinIO bucket.
    prefix          : str                   - Optional key prefix (acts like a folder path).

    """

    # Ensure path ends with '/'
    if prefix and not prefix.endswith("/"):
        prefix += "/"
    paginator = client.get_paginator("list_objects_v2")
    pages = paginator.paginate(Bucket=bucket, Prefix=prefix)

    for page in pages:
        for obj in page.get("Contents", []):

            if obj['Size'] == 0:  # Skip the folder itself (if the file size is 0)
                continue

            key = obj["Key"]

            try:
                # Get the file object from S3
                resp = client.get_object(Bucket=bucket, Key=key)
                body = resp["Body"].read()  # Read the file content

                # Case 1: plain text file (check encoding)
                if key.endswith(".txt"):
                    # Use chardet to detect the file encoding
                    result = chardet.detect(body)
                    current_encoding = result['encoding']
                    # Skip if the file is already in UTF-8 encoding
                    if current_encoding in ("utf-8", "ascii", None):
                        print(f"Already UTF-8 or ASCII: {key}")
                        continue

                    print(f"Converting {key} from {current_encoding} to UTF-8")

                    # Decode the content using the detected encoding and re-encode it in UTF-8
                    content = body.decode(current_encoding, errors='ignore')  # Ignore characters that can't be decoded
                    content = _norm(content)
                    # Upload the converted content back to S3 in UTF-8
                    client.put_object(
                        Bucket=bucket,
                        Key=key,  # Make sure the file key (path) is correct
                        Body=content.encode('utf-8'),
                        ContentType="text/plain"
                    )
                    print(f"Re-encoded {key} successfully")
                    
                else:
                    handled, content, new_key = convert_and_replace(key, body)
                    if handled:
                        client.put_object(
                            Bucket=bucket,
                            Key=new_key,
                            Body=content.encode("utf-8"),
                            ContentType="text/plain",
                        )
                        print(f"Converted {key} → {new_key}")

                    else:
                        print(f"Skipped unsupported extension: {key}")

            except Exception as e:
                print(f"Failed to process {key}: {e}")

# %%
convert_documents_to_txt(s3, bucket = "formatted-zone", prefix = "texts/")
# Out:
# Already UTF-8 or ASCII: texts/text_1762966926656.txt
# Already UTF-8 or ASCII: texts/text_1762966926816.txt
# Converting texts/text_1762966926955.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966926955.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966927095.txt
# Converting texts/text_1762966927196.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966927196.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966927290.txt
# Already UTF-8 or ASCII: texts/text_1762966927370.txt
# Already UTF-8 or ASCII: texts/text_1762966927449.txt
# Already UTF-8 or ASCII: texts/text_1762966927532.txt
# Already UTF-8 or ASCII: texts/text_1762966927611.txt
# Already UTF-8 or ASCII: texts/text_1762966927710.txt
# Already UTF-8 or ASCII: texts/text_1762966927842.txt
# Already UTF-8 or ASCII: texts/text_1762966928008.txt
# Already UTF-8 or ASCII: texts/text_1762966928184.txt
# Already UTF-8 or ASCII: texts/text_1762966928320.txt
# Already UTF-8 or ASCII: texts/text_1762966928456.txt
# Already UTF-8 or ASCII: texts/text_1762966928575.txt
# Already UTF-8 or ASCII: texts/text_1762966928672.txt
# Already UTF-8 or ASCII: texts/text_1762966928759.txt
# Already UTF-8 or ASCII: texts/text_1762966928845.txt
# Already UTF-8 or ASCII: texts/text_1762966928944.txt
# Already UTF-8 or ASCII: texts/text_1762966929046.txt
# Already UTF-8 or ASCII: texts/text_1762966929154.txt
# Already UTF-8 or ASCII: texts/text_1762966929245.txt
# Converting texts/text_1762966929334.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966929334.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966929425.txt
# Already UTF-8 or ASCII: texts/text_1762966929540.txt
# Already UTF-8 or ASCII: texts/text_1762966929664.txt
# Already UTF-8 or ASCII: texts/text_1762966929779.txt
# Already UTF-8 or ASCII: texts/text_1762966929910.txt
# Already UTF-8 or ASCII: texts/text_1762966930013.txt
# Already UTF-8 or ASCII: texts/text_1762966930088.txt
# Already UTF-8 or ASCII: texts/text_1762966930166.txt
# Converting texts/text_1762966930239.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966930239.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966930322.txt
# Already UTF-8 or ASCII: texts/text_1762966930392.txt
# Already UTF-8 or ASCII: texts/text_1762966930473.txt
# Already UTF-8 or ASCII: texts/text_1762966930547.txt
# Already UTF-8 or ASCII: texts/text_1762966930625.txt
# Already UTF-8 or ASCII: texts/text_1762966930724.txt
# Already UTF-8 or ASCII: texts/text_1762966930795.txt
# Converting texts/text_1762966930873.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966930873.txt successfully
# Converting texts/text_1762966930998.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966930998.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966931102.txt
# Already UTF-8 or ASCII: texts/text_1762966931184.txt
# Already UTF-8 or ASCII: texts/text_1762966931269.txt
# Already UTF-8 or ASCII: texts/text_1762966931350.txt
# Already UTF-8 or ASCII: texts/text_1762966931429.txt
# Converting texts/text_1762966931526.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966931526.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966931640.txt
# Already UTF-8 or ASCII: texts/text_1762966931730.txt
# Already UTF-8 or ASCII: texts/text_1762966931811.txt
# Already UTF-8 or ASCII: texts/text_1762966931890.txt
# Already UTF-8 or ASCII: texts/text_1762966931966.txt
# Already UTF-8 or ASCII: texts/text_1762966932051.txt
# Already UTF-8 or ASCII: texts/text_1762966932149.txt
# Already UTF-8 or ASCII: texts/text_1762966932227.txt
# Already UTF-8 or ASCII: texts/text_1762966932296.txt
# Already UTF-8 or ASCII: texts/text_1762966932375.txt
# Already UTF-8 or ASCII: texts/text_1762966932474.txt
# Already UTF-8 or ASCII: texts/text_1762966932560.txt
# Converting texts/text_1762966932640.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966932640.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966932708.txt
# Converting texts/text_1762966932805.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966932805.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966932880.txt
# Already UTF-8 or ASCII: texts/text_1762966932958.txt
# Already UTF-8 or ASCII: texts/text_1762966933029.txt
# Already UTF-8 or ASCII: texts/text_1762966933105.txt
# Converting texts/text_1762966933185.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966933185.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966933257.txt
# Converting texts/text_1762966933336.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966933336.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966933407.txt
# Already UTF-8 or ASCII: texts/text_1762966933483.txt
# Already UTF-8 or ASCII: texts/text_1762966933555.txt
# Already UTF-8 or ASCII: texts/text_1762966933627.txt
# Already UTF-8 or ASCII: texts/text_1762966933702.txt
# Already UTF-8 or ASCII: texts/text_1762966933780.txt
# Already UTF-8 or ASCII: texts/text_1762966933856.txt
# Already UTF-8 or ASCII: texts/text_1762966933931.txt
# Already UTF-8 or ASCII: texts/text_1762966934007.txt
# Converting texts/text_1762966934079.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966934079.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966934157.txt
# Already UTF-8 or ASCII: texts/text_1762966934244.txt
# Already UTF-8 or ASCII: texts/text_1762966934316.txt
# Already UTF-8 or ASCII: texts/text_1762966934389.txt
# Already UTF-8 or ASCII: texts/text_1762966934460.txt
# Already UTF-8 or ASCII: texts/text_1762966934535.txt
# Already UTF-8 or ASCII: texts/text_1762966934605.txt
# Already UTF-8 or ASCII: texts/text_1762966934675.txt
# Already UTF-8 or ASCII: texts/text_1762966934745.txt
# Already UTF-8 or ASCII: texts/text_1762966934815.txt
# Already UTF-8 or ASCII: texts/text_1762966934914.txt
# Already UTF-8 or ASCII: texts/text_1762966935009.txt
# Converting texts/text_1762966935106.txt from MacRoman to UTF-8
# Re-encoded texts/text_1762966935106.txt successfully
# Converting texts/text_1762966935200.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966935200.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966935279.txt
# Already UTF-8 or ASCII: texts/text_1762966935351.txt
# Already UTF-8 or ASCII: texts/text_1762966935426.txt
# Already UTF-8 or ASCII: texts/text_1762966935504.txt
# Already UTF-8 or ASCII: texts/text_1762966935574.txt
# Already UTF-8 or ASCII: texts/text_1762966935650.txt
# Already UTF-8 or ASCII: texts/text_1762966935717.txt
# Already UTF-8 or ASCII: texts/text_1762966935792.txt
# Already UTF-8 or ASCII: texts/text_1762966935877.txt
# Already UTF-8 or ASCII: texts/text_1762966936017.txt
# Already UTF-8 or ASCII: texts/text_1762966936195.txt
# Already UTF-8 or ASCII: texts/text_1762966936443.txt
# Already UTF-8 or ASCII: texts/text_1762966936581.txt
# Already UTF-8 or ASCII: texts/text_1762966936726.txt
# Already UTF-8 or ASCII: texts/text_1762966936865.txt
# Already UTF-8 or ASCII: texts/text_1762966937006.txt
# Already UTF-8 or ASCII: texts/text_1762966937130.txt
# Already UTF-8 or ASCII: texts/text_1762966937223.txt
# Already UTF-8 or ASCII: texts/text_1762966937323.txt
# Already UTF-8 or ASCII: texts/text_1762966937411.txt
# Already UTF-8 or ASCII: texts/text_1762966937496.txt
# Already UTF-8 or ASCII: texts/text_1762966937574.txt
# Already UTF-8 or ASCII: texts/text_1762966937658.txt
# Already UTF-8 or ASCII: texts/text_1762966937735.txt
# Already UTF-8 or ASCII: texts/text_1762966937814.txt
# Already UTF-8 or ASCII: texts/text_1762966937903.txt
# Already UTF-8 or ASCII: texts/text_1762966938048.txt
# Already UTF-8 or ASCII: texts/text_1762966938214.txt
# Already UTF-8 or ASCII: texts/text_1762966938332.txt
# Already UTF-8 or ASCII: texts/text_1762966938458.txt
# Already UTF-8 or ASCII: texts/text_1762966938587.txt
# Already UTF-8 or ASCII: texts/text_1762966938675.txt
# Converting texts/text_1762966938750.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966938750.txt successfully
# Converting texts/text_1762966938840.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966938840.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966938924.txt
# Already UTF-8 or ASCII: texts/text_1762966939021.txt
# Already UTF-8 or ASCII: texts/text_1762966939118.txt
# Already UTF-8 or ASCII: texts/text_1762966939231.txt
# Already UTF-8 or ASCII: texts/text_1762966939314.txt
# Already UTF-8 or ASCII: texts/text_1762966939392.txt
# Already UTF-8 or ASCII: texts/text_1762966939475.txt
# Already UTF-8 or ASCII: texts/text_1762966939598.txt
# Already UTF-8 or ASCII: texts/text_1762966939713.txt
# Already UTF-8 or ASCII: texts/text_1762966939821.txt
# Already UTF-8 or ASCII: texts/text_1762966939898.txt
# Already UTF-8 or ASCII: texts/text_1762966939976.txt
# Converting texts/text_1762966940053.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966940053.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966940123.txt
# Already UTF-8 or ASCII: texts/text_1762966940200.txt
# Already UTF-8 or ASCII: texts/text_1762966940275.txt
# Already UTF-8 or ASCII: texts/text_1762966940347.txt
# Already UTF-8 or ASCII: texts/text_1762966940430.txt
# Converting texts/text_1762966940514.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966940514.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966940592.txt
# Already UTF-8 or ASCII: texts/text_1762966940669.txt
# Already UTF-8 or ASCII: texts/text_1762966940743.txt
# Already UTF-8 or ASCII: texts/text_1762966940819.txt
# Already UTF-8 or ASCII: texts/text_1762966940898.txt
# Already UTF-8 or ASCII: texts/text_1762966940972.txt
# Already UTF-8 or ASCII: texts/text_1762966941043.txt
# Already UTF-8 or ASCII: texts/text_1762966941116.txt
# Already UTF-8 or ASCII: texts/text_1762966941197.txt
# Already UTF-8 or ASCII: texts/text_1762966941277.txt
# Already UTF-8 or ASCII: texts/text_1762966941362.txt
# Already UTF-8 or ASCII: texts/text_1762966941435.txt
# Already UTF-8 or ASCII: texts/text_1762966941515.txt
# Already UTF-8 or ASCII: texts/text_1762966941591.txt
# Already UTF-8 or ASCII: texts/text_1762966941666.txt
# Already UTF-8 or ASCII: texts/text_1762966941748.txt
# Already UTF-8 or ASCII: texts/text_1762966941833.txt
# Already UTF-8 or ASCII: texts/text_1762966941909.txt
# Already UTF-8 or ASCII: texts/text_1762966941982.txt
# Already UTF-8 or ASCII: texts/text_1762966942072.txt
# Converting texts/text_1762966942146.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966942146.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966942221.txt
# Converting texts/text_1762966942299.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966942299.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966942375.txt
# Already UTF-8 or ASCII: texts/text_1762966942451.txt
# Already UTF-8 or ASCII: texts/text_1762966942527.txt
# Already UTF-8 or ASCII: texts/text_1762966942597.txt
# Already UTF-8 or ASCII: texts/text_1762966942687.txt
# Already UTF-8 or ASCII: texts/text_1762966942766.txt
# Already UTF-8 or ASCII: texts/text_1762966942834.txt
# Already UTF-8 or ASCII: texts/text_1762966942912.txt
# Already UTF-8 or ASCII: texts/text_1762966942993.txt
# Already UTF-8 or ASCII: texts/text_1762966943071.txt
# Converting texts/text_1762966943149.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966943149.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966943224.txt
# Already UTF-8 or ASCII: texts/text_1762966943302.txt
# Already UTF-8 or ASCII: texts/text_1762966943380.txt
# Already UTF-8 or ASCII: texts/text_1762966943472.txt
# Already UTF-8 or ASCII: texts/text_1762966943548.txt
# Converting texts/text_1762966943623.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966943623.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966943700.txt
# Already UTF-8 or ASCII: texts/text_1762966943766.txt
# Already UTF-8 or ASCII: texts/text_1762966943834.txt
# Already UTF-8 or ASCII: texts/text_1762966943907.txt
# Already UTF-8 or ASCII: texts/text_1762966943978.txt
# Already UTF-8 or ASCII: texts/text_1762966944050.txt
# Already UTF-8 or ASCII: texts/text_1762966944120.txt
# Already UTF-8 or ASCII: texts/text_1762966944201.txt
# Already UTF-8 or ASCII: texts/text_1762966944281.txt
# Already UTF-8 or ASCII: texts/text_1762966944354.txt
# Converting texts/text_1762966944426.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966944426.txt successfully
# Converting texts/text_1762966944510.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966944510.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966944605.txt
# Already UTF-8 or ASCII: texts/text_1762966944717.txt
# Already UTF-8 or ASCII: texts/text_1762966944861.txt
# Already UTF-8 or ASCII: texts/text_1762966945003.txt
# Converting texts/text_1762966945113.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966945113.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966945231.txt
# Already UTF-8 or ASCII: texts/text_1762966945359.txt
# Already UTF-8 or ASCII: texts/text_1762966945472.txt
# Already UTF-8 or ASCII: texts/text_1762966945597.txt
# Already UTF-8 or ASCII: texts/text_1762966945730.txt
# Already UTF-8 or ASCII: texts/text_1762966945861.txt
# Already UTF-8 or ASCII: texts/text_1762966946019.txt
# Already UTF-8 or ASCII: texts/text_1762966946190.txt
# Already UTF-8 or ASCII: texts/text_1762966946434.txt
# Already UTF-8 or ASCII: texts/text_1762966946620.txt
# Already UTF-8 or ASCII: texts/text_1762966946809.txt
# Already UTF-8 or ASCII: texts/text_1762966946982.txt
# Already UTF-8 or ASCII: texts/text_1762966947145.txt
# Already UTF-8 or ASCII: texts/text_1762966947288.txt
# Converting texts/text_1762966947411.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966947411.txt successfully
# Converting texts/text_1762966947550.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966947550.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966947694.txt
# Already UTF-8 or ASCII: texts/text_1762966947849.txt
# Converting texts/text_1762966948057.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966948057.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966948291.txt
# Already UTF-8 or ASCII: texts/text_1762966948446.txt
# Already UTF-8 or ASCII: texts/text_1762966948592.txt
# Already UTF-8 or ASCII: texts/text_1762966948722.txt
# Already UTF-8 or ASCII: texts/text_1762966948838.txt
# Already UTF-8 or ASCII: texts/text_1762966948952.txt
# Already UTF-8 or ASCII: texts/text_1762966949061.txt
# Already UTF-8 or ASCII: texts/text_1762966949166.txt
# Converting texts/text_1762966949288.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966949288.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966949377.txt
# Already UTF-8 or ASCII: texts/text_1762966949459.txt
# Already UTF-8 or ASCII: texts/text_1762966949541.txt
# Already UTF-8 or ASCII: texts/text_1762966949638.txt
# Already UTF-8 or ASCII: texts/text_1762966949751.txt
# Already UTF-8 or ASCII: texts/text_1762966949860.txt
# Already UTF-8 or ASCII: texts/text_1762966949987.txt
# Already UTF-8 or ASCII: texts/text_1762966950082.txt
# Already UTF-8 or ASCII: texts/text_1762966950162.txt
# Already UTF-8 or ASCII: texts/text_1762966950246.txt
# Already UTF-8 or ASCII: texts/text_1762966950326.txt
# Already UTF-8 or ASCII: texts/text_1762966950402.txt
# Already UTF-8 or ASCII: texts/text_1762966950479.txt
# Already UTF-8 or ASCII: texts/text_1762966950556.txt
# Already UTF-8 or ASCII: texts/text_1762966950641.txt
# Already UTF-8 or ASCII: texts/text_1762966950716.txt
# Already UTF-8 or ASCII: texts/text_1762966950803.txt
# Already UTF-8 or ASCII: texts/text_1762966950881.txt
# Converting texts/text_1762966950958.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966950958.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966951037.txt
# Converting texts/text_1762966951105.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966951105.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966951180.txt
# Already UTF-8 or ASCII: texts/text_1762966951255.txt
# Already UTF-8 or ASCII: texts/text_1762966951331.txt
# Already UTF-8 or ASCII: texts/text_1762966951407.txt
# Converting texts/text_1762966951483.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966951483.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966951562.txt
# Already UTF-8 or ASCII: texts/text_1762966951640.txt
# Converting texts/text_1762966951721.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966951721.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966951800.txt
# Already UTF-8 or ASCII: texts/text_1762966951882.txt
# Already UTF-8 or ASCII: texts/text_1762966951973.txt
# Already UTF-8 or ASCII: texts/text_1762966952060.txt
# Already UTF-8 or ASCII: texts/text_1762966952138.txt
# Already UTF-8 or ASCII: texts/text_1762966952220.txt
# Converting texts/text_1762966952293.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966952293.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966952370.txt
# Already UTF-8 or ASCII: texts/text_1762966952443.txt
# Already UTF-8 or ASCII: texts/text_1762966952519.txt
# Already UTF-8 or ASCII: texts/text_1762966952593.txt
# Converting texts/text_1762966952674.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966952674.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966952753.txt
# Already UTF-8 or ASCII: texts/text_1762966952829.txt
# Already UTF-8 or ASCII: texts/text_1762966952924.txt
# Already UTF-8 or ASCII: texts/text_1762966953052.txt
# Already UTF-8 or ASCII: texts/text_1762966953171.txt
# Already UTF-8 or ASCII: texts/text_1762966953274.txt
# Converting texts/text_1762966953385.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966953385.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966953464.txt
# Converting texts/text_1762966953537.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966953537.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966953614.txt
# Converting texts/text_1762966953689.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966953689.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966953763.txt
# Already UTF-8 or ASCII: texts/text_1762966953839.txt
# Already UTF-8 or ASCII: texts/text_1762966953916.txt
# Converting texts/text_1762966953999.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966953999.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966954087.txt
# Already UTF-8 or ASCII: texts/text_1762966954163.txt
# Already UTF-8 or ASCII: texts/text_1762966954233.txt
# Already UTF-8 or ASCII: texts/text_1762966954306.txt
# Already UTF-8 or ASCII: texts/text_1762966954387.txt
# Already UTF-8 or ASCII: texts/text_1762966954459.txt
# Already UTF-8 or ASCII: texts/text_1762966954538.txt
# Already UTF-8 or ASCII: texts/text_1762966954614.txt
# Already UTF-8 or ASCII: texts/text_1762966954684.txt
# Already UTF-8 or ASCII: texts/text_1762966954761.txt
# Already UTF-8 or ASCII: texts/text_1762966954841.txt
# Already UTF-8 or ASCII: texts/text_1762966954919.txt
# Already UTF-8 or ASCII: texts/text_1762966955013.txt
# Already UTF-8 or ASCII: texts/text_1762966955100.txt
# Converting texts/text_1762966955177.txt from MacRoman to UTF-8
# Re-encoded texts/text_1762966955177.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966955257.txt
# Converting texts/text_1762966955330.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966955330.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966955409.txt
# Already UTF-8 or ASCII: texts/text_1762966955490.txt
# Converting texts/text_1762966955561.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966955561.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966955651.txt
# Already UTF-8 or ASCII: texts/text_1762966955762.txt
# Already UTF-8 or ASCII: texts/text_1762966955868.txt
# Already UTF-8 or ASCII: texts/text_1762966955955.txt
# Already UTF-8 or ASCII: texts/text_1762966956112.txt
# Converting texts/text_1762966956365.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966956365.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966956529.txt
# Already UTF-8 or ASCII: texts/text_1762966956690.txt
# Already UTF-8 or ASCII: texts/text_1762966956854.txt
# Already UTF-8 or ASCII: texts/text_1762966957009.txt
# Already UTF-8 or ASCII: texts/text_1762966957139.txt
# Already UTF-8 or ASCII: texts/text_1762966957267.txt
# Already UTF-8 or ASCII: texts/text_1762966957354.txt
# Already UTF-8 or ASCII: texts/text_1762966957441.txt
# Already UTF-8 or ASCII: texts/text_1762966957531.txt
# Already UTF-8 or ASCII: texts/text_1762966957610.txt
# Already UTF-8 or ASCII: texts/text_1762966957689.txt
# Already UTF-8 or ASCII: texts/text_1762966957777.txt
# Already UTF-8 or ASCII: texts/text_1762966957900.txt
# Converting texts/text_1762966958056.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966958056.txt successfully
# Converting texts/text_1762966958241.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966958241.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966958365.txt
# Converting texts/text_1762966958509.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966958509.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966958673.txt
# Converting texts/text_1762966958816.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966958816.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966958954.txt
# Already UTF-8 or ASCII: texts/text_1762966959071.txt
# Already UTF-8 or ASCII: texts/text_1762966959164.txt
# Already UTF-8 or ASCII: texts/text_1762966959249.txt
# Already UTF-8 or ASCII: texts/text_1762966959323.txt
# Already UTF-8 or ASCII: texts/text_1762966959407.txt
# Already UTF-8 or ASCII: texts/text_1762966959480.txt
# Already UTF-8 or ASCII: texts/text_1762966959557.txt
# Already UTF-8 or ASCII: texts/text_1762966959633.txt
# Already UTF-8 or ASCII: texts/text_1762966959709.txt
# Converting texts/text_1762966959788.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966959788.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966959867.txt
# Already UTF-8 or ASCII: texts/text_1762966959942.txt
# Already UTF-8 or ASCII: texts/text_1762966960018.txt
# Already UTF-8 or ASCII: texts/text_1762966960096.txt
# Already UTF-8 or ASCII: texts/text_1762966960174.txt
# Already UTF-8 or ASCII: texts/text_1762966960263.txt
# Already UTF-8 or ASCII: texts/text_1762966960370.txt
# Already UTF-8 or ASCII: texts/text_1762966960449.txt
# Already UTF-8 or ASCII: texts/text_1762966960552.txt
# Already UTF-8 or ASCII: texts/text_1762966960629.txt
# Converting texts/text_1762966960709.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966960709.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966960781.txt
# Converting texts/text_1762966960859.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966960859.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966960946.txt
# Already UTF-8 or ASCII: texts/text_1762966961043.txt
# Already UTF-8 or ASCII: texts/text_1762966961134.txt
# Already UTF-8 or ASCII: texts/text_1762966961222.txt
# Already UTF-8 or ASCII: texts/text_1762966961298.txt
# Already UTF-8 or ASCII: texts/text_1762966961373.txt
# Already UTF-8 or ASCII: texts/text_1762966961451.txt
# Already UTF-8 or ASCII: texts/text_1762966961531.txt
# Already UTF-8 or ASCII: texts/text_1762966961605.txt
# Already UTF-8 or ASCII: texts/text_1762966961680.txt
# Already UTF-8 or ASCII: texts/text_1762966961756.txt
# Converting texts/text_1762966961832.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966961832.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966961907.txt
# Already UTF-8 or ASCII: texts/text_1762966961988.txt
# Already UTF-8 or ASCII: texts/text_1762966962071.txt
# Already UTF-8 or ASCII: texts/text_1762966962160.txt
# Already UTF-8 or ASCII: texts/text_1762966962261.txt
# Already UTF-8 or ASCII: texts/text_1762966962340.txt
# Already UTF-8 or ASCII: texts/text_1762966962423.txt
# Already UTF-8 or ASCII: texts/text_1762966962498.txt
# Already UTF-8 or ASCII: texts/text_1762966962571.txt
# Already UTF-8 or ASCII: texts/text_1762966962674.txt
# Already UTF-8 or ASCII: texts/text_1762966962766.txt
# Already UTF-8 or ASCII: texts/text_1762966962839.txt
# Already UTF-8 or ASCII: texts/text_1762966962918.txt
# Already UTF-8 or ASCII: texts/text_1762966962994.txt
# Already UTF-8 or ASCII: texts/text_1762966963065.txt
# Already UTF-8 or ASCII: texts/text_1762966963141.txt
# Already UTF-8 or ASCII: texts/text_1762966963215.txt
# Already UTF-8 or ASCII: texts/text_1762966963287.txt
# Already UTF-8 or ASCII: texts/text_1762966963361.txt
# Already UTF-8 or ASCII: texts/text_1762966963440.txt
# Already UTF-8 or ASCII: texts/text_1762966963509.txt
# Already UTF-8 or ASCII: texts/text_1762966963583.txt
# Converting texts/text_1762966963691.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966963691.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966963804.txt
# Converting texts/text_1762966963913.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966963913.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966963991.txt
# Converting texts/text_1762966964068.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966964068.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966964147.txt
# Already UTF-8 or ASCII: texts/text_1762966964222.txt
# Already UTF-8 or ASCII: texts/text_1762966964304.txt
# Converting texts/text_1762966964372.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966964372.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966964446.txt
# Already UTF-8 or ASCII: texts/text_1762966964522.txt
# Already UTF-8 or ASCII: texts/text_1762966964595.txt
# Converting texts/text_1762966964675.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966964675.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966964767.txt
# Converting texts/text_1762966964838.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966964838.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966964921.txt
# Already UTF-8 or ASCII: texts/text_1762966964993.txt
# Already UTF-8 or ASCII: texts/text_1762966965075.txt
# Converting texts/text_1762966965147.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966965147.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966965222.txt
# Already UTF-8 or ASCII: texts/text_1762966965295.txt
# Already UTF-8 or ASCII: texts/text_1762966965378.txt
# Already UTF-8 or ASCII: texts/text_1762966965458.txt
# Already UTF-8 or ASCII: texts/text_1762966965587.txt
# Already UTF-8 or ASCII: texts/text_1762966965716.txt
# Already UTF-8 or ASCII: texts/text_1762966965835.txt
# Converting texts/text_1762966965949.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966965949.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966966099.txt
# Already UTF-8 or ASCII: texts/text_1762966966275.txt
# Converting texts/text_1762966966490.txt from MacRoman to UTF-8
# Re-encoded texts/text_1762966966490.txt successfully
# Converting texts/text_1762966966643.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966966643.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966966787.txt
# Already UTF-8 or ASCII: texts/text_1762966966934.txt
# Already UTF-8 or ASCII: texts/text_1762966967064.txt
# Converting texts/text_1762966967170.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966967170.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966967265.txt
# Already UTF-8 or ASCII: texts/text_1762966967350.txt
# Already UTF-8 or ASCII: texts/text_1762966967441.txt
# Already UTF-8 or ASCII: texts/text_1762966967522.txt
# Already UTF-8 or ASCII: texts/text_1762966967609.txt
# Already UTF-8 or ASCII: texts/text_1762966967690.txt
# Already UTF-8 or ASCII: texts/text_1762966967771.txt
# Already UTF-8 or ASCII: texts/text_1762966967858.txt
# Already UTF-8 or ASCII: texts/text_1762966967951.txt
# Converting texts/text_1762966968133.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966968133.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966968289.txt
# Already UTF-8 or ASCII: texts/text_1762966968406.txt
# Already UTF-8 or ASCII: texts/text_1762966968527.txt
# Already UTF-8 or ASCII: texts/text_1762966968647.txt
# Already UTF-8 or ASCII: texts/text_1762966968735.txt
# Already UTF-8 or ASCII: texts/text_1762966968812.txt
# Already UTF-8 or ASCII: texts/text_1762966968900.txt
# Already UTF-8 or ASCII: texts/text_1762966969003.txt
# Already UTF-8 or ASCII: texts/text_1762966969119.txt
# Already UTF-8 or ASCII: texts/text_1762966969205.txt
# Already UTF-8 or ASCII: texts/text_1762966969284.txt
# Already UTF-8 or ASCII: texts/text_1762966969361.txt
# Already UTF-8 or ASCII: texts/text_1762966969442.txt
# Already UTF-8 or ASCII: texts/text_1762966969519.txt
# Already UTF-8 or ASCII: texts/text_1762966969617.txt
# Already UTF-8 or ASCII: texts/text_1762966969740.txt
# Already UTF-8 or ASCII: texts/text_1762966969857.txt
# Converting texts/text_1762966969965.txt from Windows-1254 to UTF-8
# Re-encoded texts/text_1762966969965.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966970032.txt
# Already UTF-8 or ASCII: texts/text_1762966970107.txt
# Converting texts/text_1762966970188.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966970188.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966970270.txt
# Converting texts/text_1762966970346.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966970346.txt successfully
# Converting texts/text_1762966970423.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966970423.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966970503.txt
# Already UTF-8 or ASCII: texts/text_1762966970603.txt
# Already UTF-8 or ASCII: texts/text_1762966970688.txt
# Already UTF-8 or ASCII: texts/text_1762966970769.txt
# Already UTF-8 or ASCII: texts/text_1762966970848.txt
# Already UTF-8 or ASCII: texts/text_1762966970921.txt
# Already UTF-8 or ASCII: texts/text_1762966971000.txt
# Already UTF-8 or ASCII: texts/text_1762966971079.txt
# Already UTF-8 or ASCII: texts/text_1762966971165.txt
# Converting texts/text_1762966971240.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966971240.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966971318.txt
# Already UTF-8 or ASCII: texts/text_1762966971394.txt
# Already UTF-8 or ASCII: texts/text_1762966971470.txt
# Already UTF-8 or ASCII: texts/text_1762966971545.txt
# Already UTF-8 or ASCII: texts/text_1762966971622.txt
# Already UTF-8 or ASCII: texts/text_1762966971694.txt
# Already UTF-8 or ASCII: texts/text_1762966971772.txt
# Already UTF-8 or ASCII: texts/text_1762966971845.txt
# Converting texts/text_1762966971918.txt from ISO-8859-1 to UTF-8
# Re-encoded texts/text_1762966971918.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966971998.txt
# Already UTF-8 or ASCII: texts/text_1762966972079.txt
# Converting texts/text_1762966972153.txt from Windows-1252 to UTF-8
# Re-encoded texts/text_1762966972153.txt successfully
# Already UTF-8 or ASCII: texts/text_1762966972226.txt
# Already UTF-8 or ASCII: texts/text_1762966972313.txt
# Already UTF-8 or ASCII: texts/text_1762966972391.txt
# Already UTF-8 or ASCII: texts/text_1762966972471.txt
# Already UTF-8 or ASCII: texts/text_1762966972547.txt
# Already UTF-8 or ASCII: texts/text_1762966972623.txt
# Already UTF-8 or ASCII: texts/text_1762966972697.txt
# Already UTF-8 or ASCII: texts/text_1762966972769.txt
# Already UTF-8 or ASCII: texts/text_1762966972856.txt
# Already UTF-8 or ASCII: texts/text_1762966972934.txt
# Already UTF-8 or ASCII: texts/text_1762966973014.txt
# Already UTF-8 or ASCII: texts/text_1762966973087.txt
# Converting texts/text_1762966973163.txt from MacRoman to UTF-8
# Re-encoded texts/text_1762966973163.txt successfully
