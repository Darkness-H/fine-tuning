# %% [markdown]
# ## Temporal landing

# %%
#!pip install datasets

# %%
# Importing useful dependencies
import io
import ast
import boto3
import requests
from datasets import load_dataset

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# We are going to use two datasets, one from: https://huggingface.co/datasets/FronkonGames/steam-games-dataset (123 MB)
ds1_raw = load_dataset("FronkonGames/steam-games-dataset")
# The other one from: https://huggingface.co/datasets/atalaydenknalbant/rawg-games-dataset (998 MB)
ds2_raw = load_dataset("atalaydenknalbant/rawg-games-dataset")

# Print the number of rows of each dataset
print(f"The dataset 1 contains {ds1_raw['train'].num_rows} rows")
print(f"The dataset 2 contains {ds2_raw['train'].num_rows} rows")
# Out:
# The dataset 1 contains 83560 rows
# The dataset 2 contains 889793 rows

# %%
# We are going to use the first 250 obs from each dataset for testing purposes
ds1 = ds1_raw['train'][0:250]
ds2 = ds2_raw['train'][0:250]

# Print the number of rows of each subdataset
print(f"The subdataset 1 contains {len(ds1['About the game'])} rows")
print(f"The subdataset 2 contains {len(ds2['description'])} rows")
# Out:
# The subdataset 1 contains 250 rows
# The subdataset 2 contains 250 rows

# %%
# We are interested on Text, Image and Video data
# We can find each of these data in the following columns
# ds1: "About the game" (Text), "Header image" (Image), "Screenshots" (Image), "Movies" (Video)
# ds2: "description" (Text), "background_image" (Image), "background_image_additional" (Image), "short_screenshots" (Image)
# By combing both datasets, we assume there will be duplicates of games

# %% [markdown]
# **Uploading Texts**

# %%
# This function uploads each game description from strings to the given bucket_name,
# saving them as separate text files (text_1.txt, text_2.txt, …).
def upload_strings_separately(bucket_name, client, strings, path="temporal-landing/", prefix="text"):
    for i, s in enumerate(strings, start=1):
        if not s: # skip empty strings or None
            continue
        object_name = f"{path}{prefix}_{i}.txt" # temporal-landing/text_1.txt, temporal-landing/text_2.txt ...
        client.put_object(
            Bucket=bucket_name,
            Key=object_name,
            Body=io.BytesIO(s.encode("utf-8")),
            ContentType="text/plain"
        )

        print(f"Uploaded: {object_name}")

# Uploading text files (combining both datasets)
upload_strings_separately("landing-zone", s3, strings = 
                          ds1['About the game'] +
                          ds2['description'],
                          path = "temporal-landing/")
# Out:
# Uploaded: temporal-landing/text_1.txt
# Uploaded: temporal-landing/text_2.txt
# Uploaded: temporal-landing/text_3.txt
# Uploaded: temporal-landing/text_4.txt
# Uploaded: temporal-landing/text_5.txt
# Uploaded: temporal-landing/text_6.txt
# Uploaded: temporal-landing/text_7.txt
# Uploaded: temporal-landing/text_8.txt
# Uploaded: temporal-landing/text_9.txt
# Uploaded: temporal-landing/text_10.txt
# Uploaded: temporal-landing/text_11.txt
# Uploaded: temporal-landing/text_12.txt
# Uploaded: temporal-landing/text_13.txt
# Uploaded: temporal-landing/text_14.txt
# Uploaded: temporal-landing/text_15.txt
# Uploaded: temporal-landing/text_16.txt
# Uploaded: temporal-landing/text_17.txt
# Uploaded: temporal-landing/text_18.txt
# Uploaded: temporal-landing/text_19.txt
# Uploaded: temporal-landing/text_20.txt
# Uploaded: temporal-landing/text_21.txt
# Uploaded: temporal-landing/text_22.txt
# Uploaded: temporal-landing/text_23.txt
# Uploaded: temporal-landing/text_24.txt
# Uploaded: temporal-landing/text_25.txt
# Uploaded: temporal-landing/text_26.txt
# Uploaded: temporal-landing/text_27.txt
# Uploaded: temporal-landing/text_28.txt
# Uploaded: temporal-landing/text_29.txt
# Uploaded: temporal-landing/text_30.txt
# Uploaded: temporal-landing/text_31.txt
# Uploaded: temporal-landing/text_32.txt
# Uploaded: temporal-landing/text_33.txt
# Uploaded: temporal-landing/text_34.txt
# Uploaded: temporal-landing/text_35.txt
# Uploaded: temporal-landing/text_36.txt
# Uploaded: temporal-landing/text_37.txt
# Uploaded: temporal-landing/text_38.txt
# Uploaded: temporal-landing/text_39.txt
# Uploaded: temporal-landing/text_40.txt
# Uploaded: temporal-landing/text_41.txt
# Uploaded: temporal-landing/text_42.txt
# Uploaded: temporal-landing/text_43.txt
# Uploaded: temporal-landing/text_44.txt
# Uploaded: temporal-landing/text_45.txt
# Uploaded: temporal-landing/text_46.txt
# Uploaded: temporal-landing/text_47.txt
# Uploaded: temporal-landing/text_48.txt
# Uploaded: temporal-landing/text_49.txt
# Uploaded: temporal-landing/text_50.txt
# Uploaded: temporal-landing/text_51.txt
# Uploaded: temporal-landing/text_52.txt
# Uploaded: temporal-landing/text_53.txt
# Uploaded: temporal-landing/text_54.txt
# Uploaded: temporal-landing/text_55.txt
# Uploaded: temporal-landing/text_56.txt
# Uploaded: temporal-landing/text_57.txt
# Uploaded: temporal-landing/text_58.txt
# Uploaded: temporal-landing/text_59.txt
# Uploaded: temporal-landing/text_60.txt
# Uploaded: temporal-landing/text_61.txt
# Uploaded: temporal-landing/text_62.txt
# Uploaded: temporal-landing/text_63.txt
# Uploaded: temporal-landing/text_64.txt
# Uploaded: temporal-landing/text_65.txt
# Uploaded: temporal-landing/text_66.txt
# Uploaded: temporal-landing/text_67.txt
# Uploaded: temporal-landing/text_68.txt
# Uploaded: temporal-landing/text_69.txt
# Uploaded: temporal-landing/text_70.txt
# Uploaded: temporal-landing/text_71.txt
# Uploaded: temporal-landing/text_72.txt
# Uploaded: temporal-landing/text_73.txt
# Uploaded: temporal-landing/text_74.txt
# Uploaded: temporal-landing/text_75.txt
# Uploaded: temporal-landing/text_76.txt
# Uploaded: temporal-landing/text_77.txt
# Uploaded: temporal-landing/text_78.txt
# Uploaded: temporal-landing/text_79.txt
# Uploaded: temporal-landing/text_80.txt
# Uploaded: temporal-landing/text_81.txt
# Uploaded: temporal-landing/text_82.txt
# Uploaded: temporal-landing/text_83.txt
# Uploaded: temporal-landing/text_84.txt
# Uploaded: temporal-landing/text_85.txt
# Uploaded: temporal-landing/text_86.txt
# Uploaded: temporal-landing/text_87.txt
# Uploaded: temporal-landing/text_88.txt
# Uploaded: temporal-landing/text_89.txt
# Uploaded: temporal-landing/text_90.txt
# Uploaded: temporal-landing/text_91.txt
# Uploaded: temporal-landing/text_92.txt
# Uploaded: temporal-landing/text_93.txt
# Uploaded: temporal-landing/text_94.txt
# Uploaded: temporal-landing/text_95.txt
# Uploaded: temporal-landing/text_96.txt
# Uploaded: temporal-landing/text_97.txt
# Uploaded: temporal-landing/text_98.txt
# Uploaded: temporal-landing/text_99.txt
# Uploaded: temporal-landing/text_100.txt
# Uploaded: temporal-landing/text_101.txt
# Uploaded: temporal-landing/text_102.txt
# Uploaded: temporal-landing/text_103.txt
# Uploaded: temporal-landing/text_104.txt
# Uploaded: temporal-landing/text_105.txt
# Uploaded: temporal-landing/text_107.txt
# Uploaded: temporal-landing/text_108.txt
# Uploaded: temporal-landing/text_109.txt
# Uploaded: temporal-landing/text_110.txt
# Uploaded: temporal-landing/text_111.txt
# Uploaded: temporal-landing/text_112.txt
# Uploaded: temporal-landing/text_113.txt
# Uploaded: temporal-landing/text_114.txt
# Uploaded: temporal-landing/text_115.txt
# Uploaded: temporal-landing/text_116.txt
# Uploaded: temporal-landing/text_117.txt
# Uploaded: temporal-landing/text_118.txt
# Uploaded: temporal-landing/text_119.txt
# Uploaded: temporal-landing/text_120.txt
# Uploaded: temporal-landing/text_121.txt
# Uploaded: temporal-landing/text_122.txt
# Uploaded: temporal-landing/text_123.txt
# Uploaded: temporal-landing/text_124.txt
# Uploaded: temporal-landing/text_125.txt
# Uploaded: temporal-landing/text_126.txt
# Uploaded: temporal-landing/text_127.txt
# Uploaded: temporal-landing/text_128.txt
# Uploaded: temporal-landing/text_129.txt
# Uploaded: temporal-landing/text_130.txt
# Uploaded: temporal-landing/text_131.txt
# Uploaded: temporal-landing/text_132.txt
# Uploaded: temporal-landing/text_133.txt
# Uploaded: temporal-landing/text_134.txt
# Uploaded: temporal-landing/text_135.txt
# Uploaded: temporal-landing/text_136.txt
# Uploaded: temporal-landing/text_137.txt
# Uploaded: temporal-landing/text_138.txt
# Uploaded: temporal-landing/text_139.txt
# Uploaded: temporal-landing/text_140.txt
# Uploaded: temporal-landing/text_141.txt
# Uploaded: temporal-landing/text_142.txt
# Uploaded: temporal-landing/text_143.txt
# Uploaded: temporal-landing/text_144.txt
# Uploaded: temporal-landing/text_145.txt
# Uploaded: temporal-landing/text_146.txt
# Uploaded: temporal-landing/text_147.txt
# Uploaded: temporal-landing/text_148.txt
# Uploaded: temporal-landing/text_149.txt
# Uploaded: temporal-landing/text_150.txt
# Uploaded: temporal-landing/text_151.txt
# Uploaded: temporal-landing/text_152.txt
# Uploaded: temporal-landing/text_153.txt
# Uploaded: temporal-landing/text_154.txt
# Uploaded: temporal-landing/text_155.txt
# Uploaded: temporal-landing/text_156.txt
# Uploaded: temporal-landing/text_157.txt
# Uploaded: temporal-landing/text_158.txt
# Uploaded: temporal-landing/text_159.txt
# Uploaded: temporal-landing/text_160.txt
# Uploaded: temporal-landing/text_161.txt
# Uploaded: temporal-landing/text_162.txt
# Uploaded: temporal-landing/text_163.txt
# Uploaded: temporal-landing/text_164.txt
# Uploaded: temporal-landing/text_165.txt
# Uploaded: temporal-landing/text_166.txt
# Uploaded: temporal-landing/text_167.txt
# Uploaded: temporal-landing/text_168.txt
# Uploaded: temporal-landing/text_169.txt
# Uploaded: temporal-landing/text_170.txt
# Uploaded: temporal-landing/text_171.txt
# Uploaded: temporal-landing/text_172.txt
# Uploaded: temporal-landing/text_173.txt
# Uploaded: temporal-landing/text_174.txt
# Uploaded: temporal-landing/text_175.txt
# Uploaded: temporal-landing/text_176.txt
# Uploaded: temporal-landing/text_177.txt
# Uploaded: temporal-landing/text_178.txt
# Uploaded: temporal-landing/text_179.txt
# Uploaded: temporal-landing/text_180.txt
# Uploaded: temporal-landing/text_182.txt
# Uploaded: temporal-landing/text_183.txt
# Uploaded: temporal-landing/text_184.txt
# Uploaded: temporal-landing/text_185.txt
# Uploaded: temporal-landing/text_186.txt
# Uploaded: temporal-landing/text_187.txt
# Uploaded: temporal-landing/text_188.txt
# Uploaded: temporal-landing/text_189.txt
# Uploaded: temporal-landing/text_190.txt
# Uploaded: temporal-landing/text_191.txt
# Uploaded: temporal-landing/text_192.txt
# Uploaded: temporal-landing/text_193.txt
# Uploaded: temporal-landing/text_194.txt
# Uploaded: temporal-landing/text_195.txt
# Uploaded: temporal-landing/text_196.txt
# Uploaded: temporal-landing/text_197.txt
# Uploaded: temporal-landing/text_198.txt
# Uploaded: temporal-landing/text_199.txt
# Uploaded: temporal-landing/text_200.txt
# Uploaded: temporal-landing/text_201.txt
# Uploaded: temporal-landing/text_202.txt
# Uploaded: temporal-landing/text_203.txt
# Uploaded: temporal-landing/text_204.txt
# Uploaded: temporal-landing/text_205.txt
# Uploaded: temporal-landing/text_206.txt
# Uploaded: temporal-landing/text_207.txt
# Uploaded: temporal-landing/text_208.txt
# Uploaded: temporal-landing/text_209.txt
# Uploaded: temporal-landing/text_210.txt
# Uploaded: temporal-landing/text_211.txt
# Uploaded: temporal-landing/text_212.txt
# Uploaded: temporal-landing/text_213.txt
# Uploaded: temporal-landing/text_214.txt
# Uploaded: temporal-landing/text_216.txt
# Uploaded: temporal-landing/text_217.txt
# Uploaded: temporal-landing/text_218.txt
# Uploaded: temporal-landing/text_219.txt
# Uploaded: temporal-landing/text_220.txt
# Uploaded: temporal-landing/text_222.txt
# Uploaded: temporal-landing/text_223.txt
# Uploaded: temporal-landing/text_224.txt
# Uploaded: temporal-landing/text_225.txt
# Uploaded: temporal-landing/text_226.txt
# Uploaded: temporal-landing/text_227.txt
# Uploaded: temporal-landing/text_228.txt
# Uploaded: temporal-landing/text_229.txt
# Uploaded: temporal-landing/text_230.txt
# Uploaded: temporal-landing/text_231.txt
# Uploaded: temporal-landing/text_232.txt
# Uploaded: temporal-landing/text_233.txt
# Uploaded: temporal-landing/text_234.txt
# Uploaded: temporal-landing/text_235.txt
# Uploaded: temporal-landing/text_236.txt
# Uploaded: temporal-landing/text_237.txt
# Uploaded: temporal-landing/text_238.txt
# Uploaded: temporal-landing/text_239.txt
# Uploaded: temporal-landing/text_240.txt
# Uploaded: temporal-landing/text_241.txt
# Uploaded: temporal-landing/text_242.txt
# Uploaded: temporal-landing/text_243.txt
# Uploaded: temporal-landing/text_244.txt
# Uploaded: temporal-landing/text_245.txt
# Uploaded: temporal-landing/text_246.txt
# Uploaded: temporal-landing/text_247.txt
# Uploaded: temporal-landing/text_248.txt
# Uploaded: temporal-landing/text_249.txt
# Uploaded: temporal-landing/text_250.txt
# Uploaded: temporal-landing/text_251.txt
# Uploaded: temporal-landing/text_252.txt
# Uploaded: temporal-landing/text_253.txt
# Uploaded: temporal-landing/text_254.txt
# Uploaded: temporal-landing/text_255.txt
# Uploaded: temporal-landing/text_256.txt
# Uploaded: temporal-landing/text_257.txt
# Uploaded: temporal-landing/text_258.txt
# Uploaded: temporal-landing/text_259.txt
# Uploaded: temporal-landing/text_260.txt
# Uploaded: temporal-landing/text_261.txt
# Uploaded: temporal-landing/text_262.txt
# Uploaded: temporal-landing/text_263.txt
# Uploaded: temporal-landing/text_264.txt
# Uploaded: temporal-landing/text_265.txt
# Uploaded: temporal-landing/text_266.txt
# Uploaded: temporal-landing/text_267.txt
# Uploaded: temporal-landing/text_268.txt
# Uploaded: temporal-landing/text_269.txt
# Uploaded: temporal-landing/text_270.txt
# Uploaded: temporal-landing/text_271.txt
# Uploaded: temporal-landing/text_272.txt
# Uploaded: temporal-landing/text_273.txt
# Uploaded: temporal-landing/text_274.txt
# Uploaded: temporal-landing/text_275.txt
# Uploaded: temporal-landing/text_276.txt
# Uploaded: temporal-landing/text_277.txt
# Uploaded: temporal-landing/text_278.txt
# Uploaded: temporal-landing/text_279.txt
# Uploaded: temporal-landing/text_280.txt
# Uploaded: temporal-landing/text_281.txt
# Uploaded: temporal-landing/text_282.txt
# Uploaded: temporal-landing/text_283.txt
# Uploaded: temporal-landing/text_284.txt
# Uploaded: temporal-landing/text_285.txt
# Uploaded: temporal-landing/text_286.txt
# Uploaded: temporal-landing/text_287.txt
# Uploaded: temporal-landing/text_288.txt
# Uploaded: temporal-landing/text_289.txt
# Uploaded: temporal-landing/text_290.txt
# Uploaded: temporal-landing/text_291.txt
# Uploaded: temporal-landing/text_292.txt
# Uploaded: temporal-landing/text_293.txt
# Uploaded: temporal-landing/text_294.txt
# Uploaded: temporal-landing/text_295.txt
# Uploaded: temporal-landing/text_296.txt
# Uploaded: temporal-landing/text_297.txt
# Uploaded: temporal-landing/text_298.txt
# Uploaded: temporal-landing/text_299.txt
# Uploaded: temporal-landing/text_300.txt
# Uploaded: temporal-landing/text_301.txt
# Uploaded: temporal-landing/text_302.txt
# Uploaded: temporal-landing/text_303.txt
# Uploaded: temporal-landing/text_304.txt
# Uploaded: temporal-landing/text_305.txt
# Uploaded: temporal-landing/text_306.txt
# Uploaded: temporal-landing/text_307.txt
# Uploaded: temporal-landing/text_308.txt
# Uploaded: temporal-landing/text_309.txt
# Uploaded: temporal-landing/text_310.txt
# Uploaded: temporal-landing/text_311.txt
# Uploaded: temporal-landing/text_312.txt
# Uploaded: temporal-landing/text_313.txt
# Uploaded: temporal-landing/text_314.txt
# Uploaded: temporal-landing/text_315.txt
# Uploaded: temporal-landing/text_316.txt
# Uploaded: temporal-landing/text_317.txt
# Uploaded: temporal-landing/text_318.txt
# Uploaded: temporal-landing/text_319.txt
# Uploaded: temporal-landing/text_320.txt
# Uploaded: temporal-landing/text_321.txt
# Uploaded: temporal-landing/text_322.txt
# Uploaded: temporal-landing/text_323.txt
# Uploaded: temporal-landing/text_324.txt
# Uploaded: temporal-landing/text_325.txt
# Uploaded: temporal-landing/text_326.txt
# Uploaded: temporal-landing/text_327.txt
# Uploaded: temporal-landing/text_328.txt
# Uploaded: temporal-landing/text_329.txt
# Uploaded: temporal-landing/text_330.txt
# Uploaded: temporal-landing/text_331.txt
# Uploaded: temporal-landing/text_332.txt
# Uploaded: temporal-landing/text_333.txt
# Uploaded: temporal-landing/text_334.txt
# Uploaded: temporal-landing/text_335.txt
# Uploaded: temporal-landing/text_336.txt
# Uploaded: temporal-landing/text_337.txt
# Uploaded: temporal-landing/text_338.txt
# Uploaded: temporal-landing/text_339.txt
# Uploaded: temporal-landing/text_340.txt
# Uploaded: temporal-landing/text_341.txt
# Uploaded: temporal-landing/text_342.txt
# Uploaded: temporal-landing/text_343.txt
# Uploaded: temporal-landing/text_344.txt
# Uploaded: temporal-landing/text_345.txt
# Uploaded: temporal-landing/text_346.txt
# Uploaded: temporal-landing/text_347.txt
# Uploaded: temporal-landing/text_348.txt
# Uploaded: temporal-landing/text_349.txt
# Uploaded: temporal-landing/text_350.txt
# Uploaded: temporal-landing/text_351.txt
# Uploaded: temporal-landing/text_352.txt
# Uploaded: temporal-landing/text_353.txt
# Uploaded: temporal-landing/text_354.txt
# Uploaded: temporal-landing/text_355.txt
# Uploaded: temporal-landing/text_356.txt
# Uploaded: temporal-landing/text_357.txt
# Uploaded: temporal-landing/text_358.txt
# Uploaded: temporal-landing/text_359.txt
# Uploaded: temporal-landing/text_360.txt
# Uploaded: temporal-landing/text_361.txt
# Uploaded: temporal-landing/text_362.txt
# Uploaded: temporal-landing/text_363.txt
# Uploaded: temporal-landing/text_364.txt
# Uploaded: temporal-landing/text_365.txt
# Uploaded: temporal-landing/text_366.txt
# Uploaded: temporal-landing/text_367.txt
# Uploaded: temporal-landing/text_368.txt
# Uploaded: temporal-landing/text_369.txt
# Uploaded: temporal-landing/text_370.txt
# Uploaded: temporal-landing/text_371.txt
# Uploaded: temporal-landing/text_372.txt
# Uploaded: temporal-landing/text_373.txt
# Uploaded: temporal-landing/text_374.txt
# Uploaded: temporal-landing/text_375.txt
# Uploaded: temporal-landing/text_376.txt
# Uploaded: temporal-landing/text_377.txt
# Uploaded: temporal-landing/text_378.txt
# Uploaded: temporal-landing/text_379.txt
# Uploaded: temporal-landing/text_380.txt
# Uploaded: temporal-landing/text_381.txt
# Uploaded: temporal-landing/text_382.txt
# Uploaded: temporal-landing/text_383.txt
# Uploaded: temporal-landing/text_384.txt
# Uploaded: temporal-landing/text_385.txt
# Uploaded: temporal-landing/text_386.txt
# Uploaded: temporal-landing/text_387.txt
# Uploaded: temporal-landing/text_388.txt
# Uploaded: temporal-landing/text_389.txt
# Uploaded: temporal-landing/text_390.txt
# Uploaded: temporal-landing/text_391.txt
# Uploaded: temporal-landing/text_392.txt
# Uploaded: temporal-landing/text_393.txt
# Uploaded: temporal-landing/text_394.txt
# Uploaded: temporal-landing/text_395.txt
# Uploaded: temporal-landing/text_396.txt
# Uploaded: temporal-landing/text_397.txt
# Uploaded: temporal-landing/text_398.txt
# Uploaded: temporal-landing/text_399.txt
# Uploaded: temporal-landing/text_400.txt
# Uploaded: temporal-landing/text_401.txt
# Uploaded: temporal-landing/text_402.txt
# Uploaded: temporal-landing/text_403.txt
# Uploaded: temporal-landing/text_404.txt
# Uploaded: temporal-landing/text_405.txt
# Uploaded: temporal-landing/text_406.txt
# Uploaded: temporal-landing/text_407.txt
# Uploaded: temporal-landing/text_408.txt
# Uploaded: temporal-landing/text_409.txt
# Uploaded: temporal-landing/text_410.txt
# Uploaded: temporal-landing/text_411.txt
# Uploaded: temporal-landing/text_412.txt
# Uploaded: temporal-landing/text_413.txt
# Uploaded: temporal-landing/text_414.txt
# Uploaded: temporal-landing/text_415.txt
# Uploaded: temporal-landing/text_416.txt
# Uploaded: temporal-landing/text_417.txt
# Uploaded: temporal-landing/text_418.txt
# Uploaded: temporal-landing/text_419.txt
# Uploaded: temporal-landing/text_420.txt
# Uploaded: temporal-landing/text_421.txt
# Uploaded: temporal-landing/text_422.txt
# Uploaded: temporal-landing/text_423.txt
# Uploaded: temporal-landing/text_424.txt
# Uploaded: temporal-landing/text_425.txt
# Uploaded: temporal-landing/text_426.txt
# Uploaded: temporal-landing/text_427.txt
# Uploaded: temporal-landing/text_428.txt
# Uploaded: temporal-landing/text_429.txt
# Uploaded: temporal-landing/text_430.txt
# Uploaded: temporal-landing/text_431.txt
# Uploaded: temporal-landing/text_432.txt
# Uploaded: temporal-landing/text_433.txt
# Uploaded: temporal-landing/text_434.txt
# Uploaded: temporal-landing/text_435.txt
# Uploaded: temporal-landing/text_436.txt
# Uploaded: temporal-landing/text_437.txt
# Uploaded: temporal-landing/text_438.txt
# Uploaded: temporal-landing/text_439.txt
# Uploaded: temporal-landing/text_440.txt
# Uploaded: temporal-landing/text_441.txt
# Uploaded: temporal-landing/text_442.txt
# Uploaded: temporal-landing/text_443.txt
# Uploaded: temporal-landing/text_444.txt
# Uploaded: temporal-landing/text_445.txt
# Uploaded: temporal-landing/text_446.txt
# Uploaded: temporal-landing/text_447.txt
# Uploaded: temporal-landing/text_448.txt
# Uploaded: temporal-landing/text_449.txt
# Uploaded: temporal-landing/text_450.txt
# Uploaded: temporal-landing/text_451.txt
# Uploaded: temporal-landing/text_452.txt
# Uploaded: temporal-landing/text_453.txt
# Uploaded: temporal-landing/text_454.txt
# Uploaded: temporal-landing/text_455.txt
# Uploaded: temporal-landing/text_456.txt
# Uploaded: temporal-landing/text_457.txt
# Uploaded: temporal-landing/text_458.txt
# Uploaded: temporal-landing/text_459.txt
# Uploaded: temporal-landing/text_460.txt
# Uploaded: temporal-landing/text_461.txt
# Uploaded: temporal-landing/text_462.txt
# Uploaded: temporal-landing/text_463.txt
# Uploaded: temporal-landing/text_464.txt
# Uploaded: temporal-landing/text_465.txt
# Uploaded: temporal-landing/text_466.txt
# Uploaded: temporal-landing/text_467.txt
# Uploaded: temporal-landing/text_468.txt
# Uploaded: temporal-landing/text_469.txt
# Uploaded: temporal-landing/text_470.txt
# Uploaded: temporal-landing/text_471.txt
# Uploaded: temporal-landing/text_472.txt
# Uploaded: temporal-landing/text_473.txt
# Uploaded: temporal-landing/text_474.txt
# Uploaded: temporal-landing/text_475.txt
# Uploaded: temporal-landing/text_476.txt
# Uploaded: temporal-landing/text_477.txt
# Uploaded: temporal-landing/text_478.txt
# Uploaded: temporal-landing/text_479.txt
# Uploaded: temporal-landing/text_480.txt
# Uploaded: temporal-landing/text_481.txt
# Uploaded: temporal-landing/text_482.txt
# Uploaded: temporal-landing/text_483.txt
# Uploaded: temporal-landing/text_484.txt
# Uploaded: temporal-landing/text_485.txt
# Uploaded: temporal-landing/text_486.txt
# Uploaded: temporal-landing/text_487.txt
# Uploaded: temporal-landing/text_488.txt
# Uploaded: temporal-landing/text_489.txt
# Uploaded: temporal-landing/text_490.txt
# Uploaded: temporal-landing/text_491.txt
# Uploaded: temporal-landing/text_492.txt
# Uploaded: temporal-landing/text_493.txt
# Uploaded: temporal-landing/text_494.txt
# Uploaded: temporal-landing/text_495.txt
# Uploaded: temporal-landing/text_496.txt
# Uploaded: temporal-landing/text_497.txt
# Uploaded: temporal-landing/text_498.txt
# Uploaded: temporal-landing/text_499.txt
# Uploaded: temporal-landing/text_500.txt

# %% [markdown]
# **Uploading Images**

# %%
# The fields "Screenshots" from ds1 and "short_screenshots" from ds2 need to be cleaned first.

# ds1
ds1ss = [] # Flatten into a clean list of URLs
for item in ds1['Screenshots']:
    if not item:
        continue
    ds1ss.extend([url.strip() for url in item.split(",") if url.strip()])

# ds2
ds2ss = [] # Extract image URLs
for elem in ds2['short_screenshots']:
    if not elem:
        continue
    records = elem.split('|') # Split the string by '|'
    for rec in records:
        # Convert string to dict safely
        d = ast.literal_eval(rec)
        ds2ss.append(d['image'])

# %%
# This function downloads URL in links as a stream and uploads it directly to the given bucket,
# saving the files with names like image_1.jpg, image_2.png, etc., while preserving their extensions.
def upload_media_from_links(bucket_name, client, links, path="temporal-landing/", prefix="image"):
    for i, url in enumerate(links, start=1):
        if not url:
            continue

        try:
            # Stream download to avoid loading full file in memory
            with requests.get(url, stream=True, timeout=120) as r:
    
                if r.status_code == 404:
                    print(f"Skipped (404 Not Found): {url}") # 404 -> skip
                    continue
                
                r.raise_for_status() # check for HTTP errors
                ext = url.split('.')[-1].split('?')[0] # get file extension
                object_name = f"{path}{prefix}_{i}.{ext}"
                # This streams the request directly to MinIO without creating a full BytesIO object
                client.upload_fileobj(
                    Fileobj=r.raw,
                    Bucket=bucket_name,
                    Key=object_name,
                    ExtraArgs={"ContentType": f"{prefix}/{ext}"}
                )
    
                print(f"Uploaded: {object_name}")
        except requests.exceptions.Timeout: # 
            print(f"Skipped (Timeout): {url}") # Timeout -> skip
        except requests.exceptions.HTTPError as e:
            print(f"HTTP error for {url}: {e}") # Other HTTP errors -> log + skip
        except Exception as e:
            print(f"Failed {url}: {e}") # Other exceptions -> log + skip

# %%
# Uploading image files (combining both datasets)
upload_media_from_links("landing-zone", s3, links = 
                         ds1['Header image'] + ds2['background_image'], # + ds2['background_image_additional'] + ds1ss + ds2ss,
                         path="temporal-landing/") # If this process is taking too long, we can just skip the screeshots
# Out:
