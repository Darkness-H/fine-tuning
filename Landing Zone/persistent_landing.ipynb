# %% [markdown]
# ## Persistent Landing

# %%
# Importing useful dependencies
import time
import boto3

# %%
# Setup S3 client for MinIO (MinIO implements Amazon S3 API)
s3 = boto3.client(
    "s3",
    endpoint_url="http://127.0.0.1:9000", # MinIO API endpoint
    aws_access_key_id="minioadmin", # User name
    aws_secret_access_key="minioadmin", # Password
)

# %%
# Create three sub-buckets inside persistent-landing, one per format
s3.put_object(Bucket="landing-zone", Key="persistent-landing/texts/") # Sub-bucket Text
s3.put_object(Bucket="landing-zone", Key="persistent-landing/images/") # Sub-bucket Image
s3.put_object(Bucket="landing-zone", Key="persistent-landing/videos/") # Sub-bucket Video
# Out:
# {'ResponseMetadata': {'RequestId': '188264D784A83FAC',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '188264D784A83FAC',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '2000',
#    'x-ratelimit-remaining': '2000',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Thu, 18 Dec 2025 19:08:00 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}

# %%
# This function checks an object's ContentType (via head_object) and classifies it as "texts", "images", or "videos"
# based on whether the type starts with text/, image/, or video/.
def classify_object_by_head(client, bucket, key):
    # ask S3 for ContentType
    head = client.head_object(Bucket=bucket, Key=key)
    ct = head.get("ContentType", "")
    if ct.startswith("text/"):
        return "texts"
    elif ct.startswith("image/"):
        return "images"
    elif ct.startswith("video/"):
        return "videos"

# %%
# This function moves all files from the source_prefix folder to the dest_prefix folder,
# classifying each file as text, image, or video (based on ContentType), renaming it with a timestamped filename (ingestion time),
# copying it to the appropriate subfolder (texts/, images/, videos/), and then deleting the original files in the source_prefix.
def move_files(client, bucket, source_prefix="temporal-landing/", dest_prefix="persistent-landing/"):
    
    paginator = client.get_paginator("list_objects_v2") # It returns objects in pages and not all at once.

    for page in paginator.paginate(Bucket=bucket, Prefix=source_prefix):
        for obj in page.get("Contents", []):
            
            src_key = obj["Key"]

            if obj['Size'] == 0 and src_key.endswith("/"):
                continue

            # classify
            category = classify_object_by_head(client, bucket, src_key)

            # get file extension
            ext = src_key.split('.')[-1].split('?')[0]

            # new filename = timestamp + original extension
            ts = int(time.time() * 1000)  # milliseconds
            new_filename = f"{category[0:-1]}_{ts}.{ext}"

            # build destination key
            dest_key = f"{dest_prefix}{category}/{new_filename}"

            # copy then delete
            client.copy_object(Bucket=bucket, CopySource={"Bucket": bucket, "Key": src_key}, Key=dest_key)
            client.delete_object(Bucket=bucket, Key=src_key)

            print(f"Moved: {src_key} -> {dest_key}")

# %%
# Moving files from Temporal Landing to Persistent Landing and removing temporal files
move_files(s3, "landing-zone", "temporal-landing/", "persistent-landing/")
# Out:
# Moved: temporal-landing/image_1.jpg -> persistent-landing/images/image_1766084882100.jpg
# Moved: temporal-landing/image_10.jpg -> persistent-landing/images/image_1766084882226.jpg
# Moved: temporal-landing/image_100.jpg -> persistent-landing/images/image_1766084882330.jpg
# Moved: temporal-landing/image_11.jpg -> persistent-landing/images/image_1766084882467.jpg
# Moved: temporal-landing/image_12.jpg -> persistent-landing/images/image_1766084882565.jpg
# Moved: temporal-landing/image_13.jpg -> persistent-landing/images/image_1766084882703.jpg
# Moved: temporal-landing/image_14.jpg -> persistent-landing/images/image_1766084882815.jpg
# Moved: temporal-landing/image_15.jpg -> persistent-landing/images/image_1766084882933.jpg
# Moved: temporal-landing/image_16.jpg -> persistent-landing/images/image_1766084883041.jpg
# Moved: temporal-landing/image_17.jpg -> persistent-landing/images/image_1766084883195.jpg
# Moved: temporal-landing/image_18.jpg -> persistent-landing/images/image_1766084883350.jpg
# Moved: temporal-landing/image_19.jpg -> persistent-landing/images/image_1766084883519.jpg
# Moved: temporal-landing/image_2.jpg -> persistent-landing/images/image_1766084883649.jpg
# Moved: temporal-landing/image_20.jpg -> persistent-landing/images/image_1766084883770.jpg
# Moved: temporal-landing/image_21.jpg -> persistent-landing/images/image_1766084883878.jpg
# Moved: temporal-landing/image_22.jpg -> persistent-landing/images/image_1766084883986.jpg
# Moved: temporal-landing/image_23.jpg -> persistent-landing/images/image_1766084884098.jpg
# Moved: temporal-landing/image_24.jpg -> persistent-landing/images/image_1766084884226.jpg
# Moved: temporal-landing/image_25.jpg -> persistent-landing/images/image_1766084884377.jpg
# Moved: temporal-landing/image_26.jpg -> persistent-landing/images/image_1766084884533.jpg
# Moved: temporal-landing/image_27.jpg -> persistent-landing/images/image_1766084884665.jpg
# Moved: temporal-landing/image_28.jpg -> persistent-landing/images/image_1766084884794.jpg
# Moved: temporal-landing/image_29.jpg -> persistent-landing/images/image_1766084884910.jpg
# Moved: temporal-landing/image_3.jpg -> persistent-landing/images/image_1766084885146.jpg
# Moved: temporal-landing/image_30.jpg -> persistent-landing/images/image_1766084885381.jpg
# Moved: temporal-landing/image_31.jpg -> persistent-landing/images/image_1766084885573.jpg
# Moved: temporal-landing/image_32.jpg -> persistent-landing/images/image_1766084885742.jpg
# Moved: temporal-landing/image_33.jpg -> persistent-landing/images/image_1766084885904.jpg
# Moved: temporal-landing/image_34.jpg -> persistent-landing/images/image_1766084886126.jpg
# Moved: temporal-landing/image_35.jpg -> persistent-landing/images/image_1766084886320.jpg
# Moved: temporal-landing/image_36.jpg -> persistent-landing/images/image_1766084886472.jpg
# Moved: temporal-landing/image_37.jpg -> persistent-landing/images/image_1766084886612.jpg
# Moved: temporal-landing/image_38.jpg -> persistent-landing/images/image_1766084886741.jpg
# Moved: temporal-landing/image_39.jpg -> persistent-landing/images/image_1766084886857.jpg
# Moved: temporal-landing/image_4.jpg -> persistent-landing/images/image_1766084886975.jpg
# Moved: temporal-landing/image_40.jpg -> persistent-landing/images/image_1766084887208.jpg
# Moved: temporal-landing/image_41.jpg -> persistent-landing/images/image_1766084887360.jpg
# Moved: temporal-landing/image_42.jpg -> persistent-landing/images/image_1766084887523.jpg
# Moved: temporal-landing/image_43.jpg -> persistent-landing/images/image_1766084887671.jpg
# Moved: temporal-landing/image_44.jpg -> persistent-landing/images/image_1766084887810.jpg
# Moved: temporal-landing/image_45.jpg -> persistent-landing/images/image_1766084887934.jpg
# Moved: temporal-landing/image_46.jpg -> persistent-landing/images/image_1766084888079.jpg
# Moved: temporal-landing/image_47.jpg -> persistent-landing/images/image_1766084888216.jpg
# Moved: temporal-landing/image_48.jpg -> persistent-landing/images/image_1766084888378.jpg
# Moved: temporal-landing/image_49.jpg -> persistent-landing/images/image_1766084888572.jpg
# Moved: temporal-landing/image_5.jpg -> persistent-landing/images/image_1766084888707.jpg
# Moved: temporal-landing/image_50.jpg -> persistent-landing/images/image_1766084888839.jpg
# Moved: temporal-landing/image_51.jpg -> persistent-landing/images/image_1766084888985.jpg
# Moved: temporal-landing/image_52.jpg -> persistent-landing/images/image_1766084889156.jpg
# Moved: temporal-landing/image_53.jpg -> persistent-landing/images/image_1766084889321.jpg
# Moved: temporal-landing/image_54.jpg -> persistent-landing/images/image_1766084889476.jpg
# Moved: temporal-landing/image_55.jpg -> persistent-landing/images/image_1766084889665.jpg
# Moved: temporal-landing/image_56.jpg -> persistent-landing/images/image_1766084889807.jpg
# Moved: temporal-landing/image_57.jpg -> persistent-landing/images/image_1766084889947.jpg
# Moved: temporal-landing/image_58.jpg -> persistent-landing/images/image_1766084890119.jpg
# Moved: temporal-landing/image_59.jpg -> persistent-landing/images/image_1766084890305.jpg
# Moved: temporal-landing/image_6.jpg -> persistent-landing/images/image_1766084890452.jpg
# Moved: temporal-landing/image_60.jpg -> persistent-landing/images/image_1766084890595.jpg
# Moved: temporal-landing/image_61.jpg -> persistent-landing/images/image_1766084890840.jpg
# Moved: temporal-landing/image_62.jpg -> persistent-landing/images/image_1766084891004.jpg
# Moved: temporal-landing/image_63.jpg -> persistent-landing/images/image_1766084891154.jpg
# Moved: temporal-landing/image_64.jpg -> persistent-landing/images/image_1766084891311.jpg
# Moved: temporal-landing/image_65.jpg -> persistent-landing/images/image_1766084891463.jpg
# Moved: temporal-landing/image_66.jpg -> persistent-landing/images/image_1766084891616.jpg
# Moved: temporal-landing/image_67.jpg -> persistent-landing/images/image_1766084891758.jpg
# Moved: temporal-landing/image_68.jpg -> persistent-landing/images/image_1766084891964.jpg
# Moved: temporal-landing/image_69.jpg -> persistent-landing/images/image_1766084892138.jpg
# Moved: temporal-landing/image_7.jpg -> persistent-landing/images/image_1766084892319.jpg
# Moved: temporal-landing/image_70.jpg -> persistent-landing/images/image_1766084892457.jpg
# Moved: temporal-landing/image_71.jpg -> persistent-landing/images/image_1766084892662.jpg
# Moved: temporal-landing/image_72.jpg -> persistent-landing/images/image_1766084892862.jpg
# Moved: temporal-landing/image_73.jpg -> persistent-landing/images/image_1766084893066.jpg
# Moved: temporal-landing/image_74.jpg -> persistent-landing/images/image_1766084893235.jpg
# Moved: temporal-landing/image_75.jpg -> persistent-landing/images/image_1766084893410.jpg
# Moved: temporal-landing/image_76.jpg -> persistent-landing/images/image_1766084893599.jpg
# Moved: temporal-landing/image_77.jpg -> persistent-landing/images/image_1766084893815.jpg
# Moved: temporal-landing/image_78.jpg -> persistent-landing/images/image_1766084893993.jpg
# Moved: temporal-landing/image_79.jpg -> persistent-landing/images/image_1766084894175.jpg
# Moved: temporal-landing/image_8.jpg -> persistent-landing/images/image_1766084894329.jpg
# Moved: temporal-landing/image_80.jpg -> persistent-landing/images/image_1766084894461.jpg
# Moved: temporal-landing/image_81.jpg -> persistent-landing/images/image_1766084894619.jpg
# Moved: temporal-landing/image_82.jpg -> persistent-landing/images/image_1766084894799.jpg
# Moved: temporal-landing/image_83.jpg -> persistent-landing/images/image_1766084894933.jpg
# Moved: temporal-landing/image_84.jpg -> persistent-landing/images/image_1766084895326.jpg
# Moved: temporal-landing/image_85.jpg -> persistent-landing/images/image_1766084895651.jpg
# Moved: temporal-landing/image_86.jpg -> persistent-landing/images/image_1766084895877.jpg
# Moved: temporal-landing/image_87.jpg -> persistent-landing/images/image_1766084896091.jpg
# Moved: temporal-landing/image_88.jpg -> persistent-landing/images/image_1766084896398.jpg
# Moved: temporal-landing/image_89.jpg -> persistent-landing/images/image_1766084896668.jpg
# Moved: temporal-landing/image_9.jpg -> persistent-landing/images/image_1766084896919.jpg
# Moved: temporal-landing/image_90.jpg -> persistent-landing/images/image_1766084897177.jpg
# Moved: temporal-landing/image_91.jpg -> persistent-landing/images/image_1766084897620.jpg
# Moved: temporal-landing/image_92.jpg -> persistent-landing/images/image_1766084897823.jpg
# Moved: temporal-landing/image_93.jpg -> persistent-landing/images/image_1766084898004.jpg
# Moved: temporal-landing/image_94.jpg -> persistent-landing/images/image_1766084898193.jpg
# Moved: temporal-landing/image_95.jpg -> persistent-landing/images/image_1766084898398.jpg
# Moved: temporal-landing/image_96.jpg -> persistent-landing/images/image_1766084898728.jpg
# Moved: temporal-landing/image_97.jpg -> persistent-landing/images/image_1766084898884.jpg
# Moved: temporal-landing/image_98.jpg -> persistent-landing/images/image_1766084899064.jpg
# Moved: temporal-landing/image_99.jpg -> persistent-landing/images/image_1766084899214.jpg
# Moved: temporal-landing/text_1.txt -> persistent-landing/texts/text_1766084899361.txt
# Moved: temporal-landing/text_10.txt -> persistent-landing/texts/text_1766084899491.txt
# Moved: temporal-landing/text_100.txt -> persistent-landing/texts/text_1766084899633.txt
# Moved: temporal-landing/text_11.txt -> persistent-landing/texts/text_1766084899745.txt
# Moved: temporal-landing/text_12.txt -> persistent-landing/texts/text_1766084899841.txt
# Moved: temporal-landing/text_13.txt -> persistent-landing/texts/text_1766084899933.txt
# Moved: temporal-landing/text_14.txt -> persistent-landing/texts/text_1766084900018.txt
# Moved: temporal-landing/text_15.txt -> persistent-landing/texts/text_1766084900129.txt
# Moved: temporal-landing/text_16.txt -> persistent-landing/texts/text_1766084900246.txt
# Moved: temporal-landing/text_17.txt -> persistent-landing/texts/text_1766084900385.txt
# Moved: temporal-landing/text_18.txt -> persistent-landing/texts/text_1766084900508.txt
# Moved: temporal-landing/text_19.txt -> persistent-landing/texts/text_1766084900641.txt
# Moved: temporal-landing/text_2.txt -> persistent-landing/texts/text_1766084900771.txt
# Moved: temporal-landing/text_20.txt -> persistent-landing/texts/text_1766084900888.txt
# Moved: temporal-landing/text_21.txt -> persistent-landing/texts/text_1766084901003.txt
# Moved: temporal-landing/text_22.txt -> persistent-landing/texts/text_1766084901134.txt
# Moved: temporal-landing/text_23.txt -> persistent-landing/texts/text_1766084901280.txt
# Moved: temporal-landing/text_24.txt -> persistent-landing/texts/text_1766084901402.txt
# Moved: temporal-landing/text_25.txt -> persistent-landing/texts/text_1766084901520.txt
# Moved: temporal-landing/text_26.txt -> persistent-landing/texts/text_1766084901641.txt
# Moved: temporal-landing/text_27.txt -> persistent-landing/texts/text_1766084901764.txt
# Moved: temporal-landing/text_28.txt -> persistent-landing/texts/text_1766084901881.txt
# Moved: temporal-landing/text_29.txt -> persistent-landing/texts/text_1766084901994.txt
# Moved: temporal-landing/text_3.txt -> persistent-landing/texts/text_1766084902128.txt
# Moved: temporal-landing/text_30.txt -> persistent-landing/texts/text_1766084902234.txt
# Moved: temporal-landing/text_31.txt -> persistent-landing/texts/text_1766084902343.txt
# Moved: temporal-landing/text_32.txt -> persistent-landing/texts/text_1766084902442.txt
# Moved: temporal-landing/text_33.txt -> persistent-landing/texts/text_1766084902543.txt
# Moved: temporal-landing/text_34.txt -> persistent-landing/texts/text_1766084902644.txt
# Moved: temporal-landing/text_35.txt -> persistent-landing/texts/text_1766084902755.txt
# Moved: temporal-landing/text_36.txt -> persistent-landing/texts/text_1766084902856.txt
# Moved: temporal-landing/text_37.txt -> persistent-landing/texts/text_1766084902964.txt
# Moved: temporal-landing/text_38.txt -> persistent-landing/texts/text_1766084903078.txt
# Moved: temporal-landing/text_39.txt -> persistent-landing/texts/text_1766084903176.txt
# Moved: temporal-landing/text_4.txt -> persistent-landing/texts/text_1766084903302.txt
# Moved: temporal-landing/text_40.txt -> persistent-landing/texts/text_1766084903408.txt
# Moved: temporal-landing/text_41.txt -> persistent-landing/texts/text_1766084903547.txt
# Moved: temporal-landing/text_42.txt -> persistent-landing/texts/text_1766084903660.txt
# Moved: temporal-landing/text_43.txt -> persistent-landing/texts/text_1766084903755.txt
# Moved: temporal-landing/text_44.txt -> persistent-landing/texts/text_1766084903873.txt
# Moved: temporal-landing/text_45.txt -> persistent-landing/texts/text_1766084904051.txt
# Moved: temporal-landing/text_46.txt -> persistent-landing/texts/text_1766084904191.txt
# Moved: temporal-landing/text_47.txt -> persistent-landing/texts/text_1766084904323.txt
# Moved: temporal-landing/text_48.txt -> persistent-landing/texts/text_1766084904489.txt
# Moved: temporal-landing/text_49.txt -> persistent-landing/texts/text_1766084904639.txt
# Moved: temporal-landing/text_5.txt -> persistent-landing/texts/text_1766084904760.txt
# Moved: temporal-landing/text_50.txt -> persistent-landing/texts/text_1766084904882.txt
# Moved: temporal-landing/text_51.txt -> persistent-landing/texts/text_1766084905005.txt
# Moved: temporal-landing/text_52.txt -> persistent-landing/texts/text_1766084905272.txt
# Moved: temporal-landing/text_53.txt -> persistent-landing/texts/text_1766084905497.txt
# Moved: temporal-landing/text_54.txt -> persistent-landing/texts/text_1766084905656.txt
# Moved: temporal-landing/text_55.txt -> persistent-landing/texts/text_1766084905816.txt
# Moved: temporal-landing/text_56.txt -> persistent-landing/texts/text_1766084905998.txt
# Moved: temporal-landing/text_57.txt -> persistent-landing/texts/text_1766084906177.txt
# Moved: temporal-landing/text_58.txt -> persistent-landing/texts/text_1766084906334.txt
# Moved: temporal-landing/text_59.txt -> persistent-landing/texts/text_1766084906492.txt
# Moved: temporal-landing/text_6.txt -> persistent-landing/texts/text_1766084906654.txt
# Moved: temporal-landing/text_60.txt -> persistent-landing/texts/text_1766084906823.txt
# Moved: temporal-landing/text_61.txt -> persistent-landing/texts/text_1766084906976.txt
# Moved: temporal-landing/text_62.txt -> persistent-landing/texts/text_1766084907219.txt
# Moved: temporal-landing/text_63.txt -> persistent-landing/texts/text_1766084907357.txt
# Moved: temporal-landing/text_64.txt -> persistent-landing/texts/text_1766084907502.txt
# Moved: temporal-landing/text_65.txt -> persistent-landing/texts/text_1766084907643.txt
# Moved: temporal-landing/text_66.txt -> persistent-landing/texts/text_1766084907800.txt
# Moved: temporal-landing/text_67.txt -> persistent-landing/texts/text_1766084907960.txt
# Moved: temporal-landing/text_68.txt -> persistent-landing/texts/text_1766084908124.txt
# Moved: temporal-landing/text_69.txt -> persistent-landing/texts/text_1766084908265.txt
# Moved: temporal-landing/text_7.txt -> persistent-landing/texts/text_1766084908409.txt
# Moved: temporal-landing/text_70.txt -> persistent-landing/texts/text_1766084908541.txt
# Moved: temporal-landing/text_71.txt -> persistent-landing/texts/text_1766084908697.txt
# Moved: temporal-landing/text_72.txt -> persistent-landing/texts/text_1766084908806.txt
# Moved: temporal-landing/text_73.txt -> persistent-landing/texts/text_1766084908946.txt
# Moved: temporal-landing/text_74.txt -> persistent-landing/texts/text_1766084909082.txt
# Moved: temporal-landing/text_75.txt -> persistent-landing/texts/text_1766084909222.txt
# Moved: temporal-landing/text_76.txt -> persistent-landing/texts/text_1766084909357.txt
# Moved: temporal-landing/text_77.txt -> persistent-landing/texts/text_1766084909571.txt
# Moved: temporal-landing/text_78.txt -> persistent-landing/texts/text_1766084909721.txt
# Moved: temporal-landing/text_79.txt -> persistent-landing/texts/text_1766084909847.txt
# Moved: temporal-landing/text_8.txt -> persistent-landing/texts/text_1766084909989.txt
# Moved: temporal-landing/text_80.txt -> persistent-landing/texts/text_1766084910119.txt
# Moved: temporal-landing/text_81.txt -> persistent-landing/texts/text_1766084910249.txt
# Moved: temporal-landing/text_82.txt -> persistent-landing/texts/text_1766084910379.txt
# Moved: temporal-landing/text_83.txt -> persistent-landing/texts/text_1766084910501.txt
# Moved: temporal-landing/text_84.txt -> persistent-landing/texts/text_1766084910618.txt
# Moved: temporal-landing/text_85.txt -> persistent-landing/texts/text_1766084910734.txt
# Moved: temporal-landing/text_86.txt -> persistent-landing/texts/text_1766084910854.txt
# Moved: temporal-landing/text_87.txt -> persistent-landing/texts/text_1766084910990.txt
# Moved: temporal-landing/text_88.txt -> persistent-landing/texts/text_1766084911135.txt
# Moved: temporal-landing/text_89.txt -> persistent-landing/texts/text_1766084911254.txt
# Moved: temporal-landing/text_9.txt -> persistent-landing/texts/text_1766084911368.txt
# Moved: temporal-landing/text_90.txt -> persistent-landing/texts/text_1766084911474.txt
# Moved: temporal-landing/text_91.txt -> persistent-landing/texts/text_1766084911589.txt
# Moved: temporal-landing/text_92.txt -> persistent-landing/texts/text_1766084911698.txt
# Moved: temporal-landing/text_93.txt -> persistent-landing/texts/text_1766084911803.txt
# Moved: temporal-landing/text_94.txt -> persistent-landing/texts/text_1766084911925.txt
# Moved: temporal-landing/text_95.txt -> persistent-landing/texts/text_1766084912054.txt
# Moved: temporal-landing/text_96.txt -> persistent-landing/texts/text_1766084912195.txt
# Moved: temporal-landing/text_97.txt -> persistent-landing/texts/text_1766084912320.txt
# Moved: temporal-landing/text_98.txt -> persistent-landing/texts/text_1766084912455.txt
# Moved: temporal-landing/text_99.txt -> persistent-landing/texts/text_1766084912574.txt
